# %% [markdown]
# ### Authors: Prof. Dr. Soumi Ray, Ravi Teja Kothuru and Abhay Srivastav
#
# ### Acknowledgements:
# I would like to thank my team mates Prof. Dr. Soumi Ray and Abhay Srivastav for their guidance and support throughout this project.
#
# **Title of the Project:** Comparative Analysis of Image-Based and Feature-Based Approaches for Pneumonia Detection in Chest X-rays
#
# **Description of the Project:** This project focuses on detecting pneumonia from chest X-ray images using Advanced Machine Learning and Deep Learning techniques (Rajpurkar et al., 2017; Wang et al., 2017). By leveraging a comprehensive dataset, including annotated images of pneumonia and normal cases, we aim to develop and compare image-based and feature-based approaches. Our goal is to identify the most effective method for accurate and interpretable pneumonia detection, contributing to improved patient outcomes through early diagnosis and treatment. This model will classify patients based on their chest X-ray images as either having pneumonia (1) or not having pneumonia (0).
#
# **Objectives of the Project:**
#
# - **Image Analysis:** Develop and evaluate deep learning models to classify chest X-rays directly. This approach leverages deep learning models, particularly Convolutional Neural Networks (CNNs), to perform end-to-end image classification. The models directly process raw chest X-ray images to classify them as normal or pneumonia.
#
# - **Feature Analysis:** Extract meaningful features from the images and use them to train and evaluate traditional machine learning models. In this approach, we first extract features from the chest X-ray images. These features are then used as inputs for traditional machine learning algorithms. The process includes steps such as feature extraction, selection, and transformation, followed by the application of machine learning techniques like Support Vector Machines (SVM), Random Forests.
#
# **Name of the Dataset:** The dataset used in this project is the Chest X-ray dataset considered from the Research paper named **Labeled Optical Coherence Tomography (OCT) and Chest X-Ray Images for Classification**.
#
# **Description of the Dataset:** The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy.
#
# **Dataset Source:**
#
# - https://data.mendeley.com/datasets/rscbjbr9sj/2
#
# **Type of the Dataset:**
#
# - X-ray Images
#
# **Description of Dataset:**
# The considered dataset has the following information for better reference:
# - Separate folders to train and validate/test the model.
# - Enough number of Chest X-ray images to train the model to detect and diagnose Pneumonia.
# - The target variable for classification is whether patient has pneumonia or not.
#
# **Goal of the Project using this Dataset:**
# The goal of this project is to conduct a comprehensive comparative analysis of image-based and feature-based approaches for pneumonia detection using chest X-ray images. By evaluating the performance, robustness, and interpretability of deep learning and traditional machine learning models, we aim to identify the most effective method for accurately classifying chest X-rays as normal or pneumonia. This comparison will provide valuable insights into the strengths and limitations of each approach, ultimately contributing to improved detection and diagnosis of pneumonia, which can enhance patient outcomes and survival rates.
#
# **Why did we choose this dataset?**
# We selected this dataset based on several factors. For more detailed information, please refer to the following:
# - The dataset is extensive, providing a large number of images suitable for evaluating and training deep learning models.
# - It aligns well with the project's objectives by offering a challenging and realistic scenario for developing an image classification model using deep learning, specifically for Chest X-ray images.
# - The dataset is annotated with images of two different diseases, enabling the development of a binary-class classification model.
# - It is publicly available, facilitating easy access for research and development purposes.
#
# **Size of dataset:**
# - Total images size = 1.27 GB
# - Dataset has 2 folders:
#   -  **Train:**
#         -  Normal (without Pneumonia) = 1349 images
#         -  Pneumonia = 3883 images
#   -  **Test:**
#         -  Normal (without Pneumonia) = 234 images
#         -  Pneumonia = 390 images
#
# **Expected Behaviors and Problem Handling:**
# - Classify Chest X-ray images with high accuracy.
# - Handle variations in image quality, resolution, and orientation.
# - Be robust to noise and artifacts in the images.
# - Provide interpretable results.
#
# **Issues to focus on:**
# - Improving model interpretability and explainability.
# - Optimizing model performance on a held-out test set.
# - Following AI Ethics and Data Safety practices.

# %% [markdown]
# # Import all the required files and libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pycaret.classification import *
import ssl
import seaborn as sns
import time

# Disable SSL certificate verification
ssl._create_default_https_context = ssl._create_unverified_context


# Automatically reload imported modules when their source code changes
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# Import python files from local to use the corresponding function
from extracted_features_classification import ExtractedFeaturesClassification
from pneumonia_detector_constants import pneumonia_detector_constants as pdconst

# %% [markdown]
# # Analyze all features and classify

# %% [markdown]
# ## Create an object of the ExtractedFeaturesClassification class

# %%
efc = ExtractedFeaturesClassification()

# %% [markdown]
# ## Read excel file into Dataframe

# %%
xls_file_name = efc.merge_excel_files()

print(f"Path to the merged excel file: {xls_file_name}")
# Out:
# Path to the merged excel file: /Users/ravkothu/Documents/Personal_items_at_Oracle/Master_Degree/University_of_San_Diego/Online_Masters/MS_in_Applied_AI/Subjects_and_Resources/AAI-501_Introduction_to_AI/AAI-501_Final_Team_Project/pneumonia_detection/image_information/images_features_merged.xlsx

# %%
excel_sheet_names = pdconst["excel_sheet_names"]

df_train_nrm = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[0])
df_train_pneu = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[1])
df_test_nrm = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[2])
df_test_pneu = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[3])

# %% [markdown]
# ## Add Target Column to all Dataframes

# %%
df_train_nrm, df_train_pneu, df_test_nrm, df_test_pneu = efc.add_target_column_to_dataframes(df_train_nrm, 
                                                                                             df_train_pneu, 
                                                                                             df_test_nrm, 
                                                                                             df_test_pneu)

# %% [markdown]
# ## Concatenate Dataframes and form train and test dataframes

# %%
df_train = efc.concatenate_dataframes(df_train_nrm, df_train_pneu)
df_test = efc.concatenate_dataframes(df_test_nrm, df_test_pneu)

# %%
# Identify columns to ignore (e.g., 'column_to_ignore1', 'column_to_ignore2')
columns_to_ignore = ['Image Filename']

# Drop the specified columns
filtered_df_train = df_train.drop(columns=columns_to_ignore)
filtered_df_test = df_test.drop(columns=columns_to_ignore)

# %% [markdown]
# ## Check Missing Values for safer side

# %%
missing_values_in_train_df = efc.check_missing_values_of_dataframe(filtered_df_train)

missing_values_in_test_df = efc.check_missing_values_of_dataframe(filtered_df_test)

print(f"Missing values in Train dataframe:\n{missing_values_in_train_df}")
print(f"\n\nMissing values in Test dataframe:\n{missing_values_in_test_df}")
# Out:
# Missing values in Train dataframe:
# Mean                     0
# Median                   0
# Standard Deviation       0
# Variance                 0
# Skewness                 0
#                         ..
# NGTDM_ClusterShade       0
# NGTDM_ClusterTendency    0
# NGTDM_Correlation        0
# NGTDM_Variance           0
# Pneumonia                0
# Length: 97, dtype: int64
#
#
# Missing values in Test dataframe:
# Mean                     0
# Median                   0
# Standard Deviation       0
# Variance                 0
# Skewness                 0
#                         ..
# NGTDM_ClusterShade       0
# NGTDM_ClusterTendency    0
# NGTDM_Correlation        0
# NGTDM_Variance           0
# Pneumonia                0
# Length: 97, dtype: int64

# %% [markdown]
# ## Plot Heatmap of all the features

# %%
from ipywidgets import widgets
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# Compute the correlation matrix
correlation_matrix = filtered_df_train.corr()

# Plot the heatmap
fig, ax = plt.subplots(figsize=(20, 16))  # Adjust size as needed
heatmap = sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt='.2f', linewidths=0.5, ax=ax)

# Rotate labels for better readability
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.title('Correlation Heatmap', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# # Perform PCA (Principal Component Analysis)

# %% [markdown]
# ## Train baseline models with provided dataframes using all the ML algorithms.
# ## Execute the required steps to compare multiple models, print classification report and return the best ML model for the passed dataframes.

# %% [markdown]
# ### PCA = 5

# %%
start_time = time.time()

best_model_for_pca5, pca5_result = efc.train_multiple_ml_models_with_pca(5, filtered_df_train)

end_time = time.time()

# Calculate the total time taken
total_time_seconds = end_time - start_time

# Convert the time to minutes and seconds
total_time_minutes = total_time_seconds // 60
total_time_seconds = total_time_seconds % 60

# Print the results
print(f"\nTotal time to execute: {int(total_time_minutes)} minutes and {total_time_seconds:.2f} seconds")
# Out:
# <style type="text/css">
# #T_79d3f_row8_col1, #T_79d3f_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_79d3f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79d3f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_79d3f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79d3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79d3f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_79d3f_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_79d3f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_79d3f_row1_col1" class="data row1 col1" >Pneumonia</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_79d3f_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_79d3f_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_79d3f_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_79d3f_row3_col1" class="data row3 col1" >(5232, 97)</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_79d3f_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_79d3f_row4_col1" class="data row4 col1" >(5232, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_79d3f_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_79d3f_row5_col1" class="data row5 col1" >(3662, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_79d3f_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_79d3f_row6_col1" class="data row6 col1" >(1570, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_79d3f_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_79d3f_row7_col1" class="data row7 col1" >96</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_79d3f_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_79d3f_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_79d3f_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_79d3f_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_79d3f_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_79d3f_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_79d3f_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_79d3f_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_79d3f_row12_col0" class="data row12 col0" >PCA</td>
#       <td id="T_79d3f_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_79d3f_row13_col0" class="data row13 col0" >PCA method</td>
#       <td id="T_79d3f_row13_col1" class="data row13 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_79d3f_row14_col0" class="data row14 col0" >PCA components</td>
#       <td id="T_79d3f_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_79d3f_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_79d3f_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_79d3f_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_79d3f_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_79d3f_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_79d3f_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_79d3f_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_79d3f_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_79d3f_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_79d3f_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_79d3f_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_79d3f_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_79d3f_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_79d3f_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_79d3f_row21_col1" class="data row21 col1" >10d5</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_a7433 th {
#   text-align: left;
# }
# #T_a7433_row0_col0, #T_a7433_row0_col2, #T_a7433_row0_col3, #T_a7433_row1_col0, #T_a7433_row1_col1, #T_a7433_row1_col3, #T_a7433_row1_col4, #T_a7433_row1_col5, #T_a7433_row1_col6, #T_a7433_row1_col7, #T_a7433_row2_col0, #T_a7433_row2_col1, #T_a7433_row2_col2, #T_a7433_row2_col3, #T_a7433_row2_col4, #T_a7433_row2_col5, #T_a7433_row2_col6, #T_a7433_row2_col7, #T_a7433_row3_col0, #T_a7433_row3_col1, #T_a7433_row3_col2, #T_a7433_row3_col3, #T_a7433_row3_col4, #T_a7433_row3_col5, #T_a7433_row3_col6, #T_a7433_row3_col7, #T_a7433_row4_col0, #T_a7433_row4_col1, #T_a7433_row4_col2, #T_a7433_row4_col3, #T_a7433_row4_col4, #T_a7433_row4_col5, #T_a7433_row4_col6, #T_a7433_row4_col7, #T_a7433_row5_col0, #T_a7433_row5_col1, #T_a7433_row5_col2, #T_a7433_row5_col3, #T_a7433_row5_col4, #T_a7433_row5_col5, #T_a7433_row5_col6, #T_a7433_row5_col7, #T_a7433_row6_col0, #T_a7433_row6_col1, #T_a7433_row6_col2, #T_a7433_row6_col3, #T_a7433_row6_col4, #T_a7433_row6_col5, #T_a7433_row6_col6, #T_a7433_row6_col7, #T_a7433_row7_col0, #T_a7433_row7_col1, #T_a7433_row7_col2, #T_a7433_row7_col3, #T_a7433_row7_col4, #T_a7433_row7_col5, #T_a7433_row7_col6, #T_a7433_row7_col7, #T_a7433_row8_col0, #T_a7433_row8_col1, #T_a7433_row8_col2, #T_a7433_row8_col3, #T_a7433_row8_col4, #T_a7433_row8_col5, #T_a7433_row8_col6, #T_a7433_row8_col7, #T_a7433_row9_col0, #T_a7433_row9_col1, #T_a7433_row9_col2, #T_a7433_row9_col3, #T_a7433_row9_col4, #T_a7433_row9_col5, #T_a7433_row9_col6, #T_a7433_row9_col7, #T_a7433_row10_col0, #T_a7433_row10_col1, #T_a7433_row10_col2, #T_a7433_row10_col3, #T_a7433_row10_col4, #T_a7433_row10_col5, #T_a7433_row10_col6, #T_a7433_row10_col7, #T_a7433_row11_col0, #T_a7433_row11_col1, #T_a7433_row11_col2, #T_a7433_row11_col3, #T_a7433_row11_col4, #T_a7433_row11_col5, #T_a7433_row11_col6, #T_a7433_row11_col7, #T_a7433_row12_col0, #T_a7433_row12_col1, #T_a7433_row12_col2, #T_a7433_row12_col3, #T_a7433_row12_col4, #T_a7433_row12_col5, #T_a7433_row12_col6, #T_a7433_row12_col7, #T_a7433_row13_col0, #T_a7433_row13_col1, #T_a7433_row13_col2, #T_a7433_row13_col3, #T_a7433_row13_col4, #T_a7433_row13_col5, #T_a7433_row13_col6, #T_a7433_row13_col7, #T_a7433_row14_col0, #T_a7433_row14_col1, #T_a7433_row14_col2, #T_a7433_row14_col4, #T_a7433_row14_col5, #T_a7433_row14_col6, #T_a7433_row14_col7 {
#   text-align: left;
# }
# #T_a7433_row0_col1, #T_a7433_row0_col4, #T_a7433_row0_col5, #T_a7433_row0_col6, #T_a7433_row0_col7, #T_a7433_row1_col2, #T_a7433_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a7433_row0_col8, #T_a7433_row1_col8, #T_a7433_row2_col8, #T_a7433_row3_col8, #T_a7433_row4_col8, #T_a7433_row5_col8, #T_a7433_row6_col8, #T_a7433_row10_col8, #T_a7433_row11_col8, #T_a7433_row12_col8, #T_a7433_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a7433_row7_col8, #T_a7433_row8_col8, #T_a7433_row9_col8, #T_a7433_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a7433">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7433_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a7433_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_a7433_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_a7433_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_a7433_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_a7433_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_a7433_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_a7433_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_a7433_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7433_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_a7433_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a7433_row0_col1" class="data row0 col1" >0.9394</td>
#       <td id="T_a7433_row0_col2" class="data row0 col2" >0.9798</td>
#       <td id="T_a7433_row0_col3" class="data row0 col3" >0.9570</td>
#       <td id="T_a7433_row0_col4" class="data row0 col4" >0.9613</td>
#       <td id="T_a7433_row0_col5" class="data row0 col5" >0.9590</td>
#       <td id="T_a7433_row0_col6" class="data row0 col6" >0.8424</td>
#       <td id="T_a7433_row0_col7" class="data row0 col7" >0.8430</td>
#       <td id="T_a7433_row0_col8" class="data row0 col8" >0.3080</td>
#     </tr>
#     <tr>
#       <th id="T_a7433_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_a7433_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_a7433_row1_col1" class="data row1 col1" >0.9391</td>
#       <td id="T_a7433_row1_col2" class="data row1 col2" >0.9800</td>
#       <td id="T_a7433_row1_col3" class="data row1 col3" >0.9569</td>
#       <td id="T_a7433_row1_col4" class="data row1 col4" >0.9610</td>
#       <td id="T_a7433_row1_col5" class="data row1 col5" >0.9588</td>
#       <td id="T_a7433_row1_col6" class="data row1 col6" >0.8417</td>
#       <td id="T_a7433_row1_col7" class="data row1 col7" >0.8426</td>
#       <td id="T_a7433_row1_col8" class="data row1 col8" >0.1180</td>
#     </tr>
#     <tr>
#       <th id="T_a7433_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_a7433_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_a7433_row2_col1" class="data row2 col1" >0.9372</td>
#       <td id="T_a7433_row2_col2" class="data row2 col2" >0.9791</td>
#       <td id="T_a7433_row2_col3" class="data row2 col3" >0.9573</td>
#       <td id="T_a7433_row2_col4" class="data row2 col4" >0.9582</td>
#       <td id="T_a7433_row2_col5" class="data row2 col5" >0.9576</td>
#       <td id="T_a7433_row2_col6" class="data row2 col6" >0.8361</td>
#       <td id="T_a7433_row2_col7" class="data row2 col7" >0.8369</td>
#       <td id="T_a7433_row2_col8" class="data row2 col8" >0.0800</td>
#     </tr>
#     <tr>
#       <th id="T_a7433_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_a7433_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_a7433_row3_col1" class="data row3 col1" >0.9366</td>
#       <td id="T_a7433_row3_col2" class="data row3 col2" >0.9768</td>
#       <td id="T_a7433_row3_col3" class="data row3 col3" >0.9562</td>
#       <td id="T_a7433_row3_col4" class="data row3 col4" >0.9584</td>
#       <td id="T_a7433_row3_col5" class="data row3 col5" >0.9572</td>
#       <td id="T_a7433_row3_col6" class="data row3 col6" >0.8351</td>
#       <td id="T_a7433_row3_col7" class="data row3 col7" >0.8357</td>
#       <td id="T_a7433_row3_col8" class="data row3 col8" >0.0780</td>
#     </tr>
#     <tr>
#       <th id="T_a7433_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_a7433_row4_col0" class="data row4 col0" >Extra Trees Classifier</td>
#       <td id="T_a7433_row4_col1" class="data row4 col1" >0.9366</td>
#       <td id="T_a7433_row4_col2" class="data row4 col2" >0.9790</td>
#       <td id="T_a7433_row4_col3" class="data row4 col3" >0.9566</td>
#       <td id="T_a7433_row4_col4" class="data row4 col4" >0.9581</td>
#       <td id="T_a7433_row4_col5" class="data row4 col5" >0.9573</td>
#       <td id="T_a7433_row4_col6" class="data row4 col6" >0.8348</td>
#       <td id="T_a7433_row4_col7" class="data row4 col7" >0.8352</td>
#       <td id="T_a7433_row4_col8" class="data row4 col8" >0.0680</td>
#     </tr>
#     <tr>
#       <th id="T_a7433_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_a7433_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_a7433_row5_col1" class="data row5 col1" >0.9309</td>
#       <td id="T_a7433_row5_col2" class="data row5 col2" >0.9757</td>
#       <td id="T_a7433_row5_col3" class="data row5 col3" >0.9544</td>
#       <td id="T_a7433_row5_col4" class="data row5 col4" >0.9527</td>
#       <td id=
# Total time to execute: 0 minutes and 15.40 seconds

# %%
best_model_for_pca5
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# #### Train and evaluate the performance of LGBM Classifier using cross validation as well as Hyperparameters

# %%
lightgbm_all_pca5 = create_model('lightgbm', boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
                            importance_type='split', learning_rate=0.1, max_depth=-1,
                            min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
                            n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
                            random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
                            subsample_for_bin=200000, subsample_freq=0, verbose=True)
# Out:
# <style type="text/css">
# #T_52e57_row10_col0, #T_52e57_row10_col1, #T_52e57_row10_col2, #T_52e57_row10_col3, #T_52e57_row10_col4, #T_52e57_row10_col5, #T_52e57_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_52e57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52e57_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_52e57_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_52e57_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_52e57_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_52e57_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_52e57_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_52e57_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_52e57_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_52e57_row0_col0" class="data row0 col0" >0.9455</td>
#       <td id="T_52e57_row0_col1" class="data row0 col1" >0.9881</td>
#       <td id="T_52e57_row0_col2" class="data row0 col2" >0.9596</td>
#       <td id="T_52e57_row0_col3" class="data row0 col3" >0.9667</td>
#       <td id="T_52e57_row0_col4" class="data row0 col4" >0.9631</td>
#       <td id="T_52e57_row0_col5" class="data row0 col5" >0.8589</td>
#       <td id="T_52e57_row0_col6" class="data row0 col6" >0.8590</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_52e57_row1_col0" class="data row1 col0" >0.9346</td>
#       <td id="T_52e57_row1_col1" class="data row1 col1" >0.9764</td>
#       <td id="T_52e57_row1_col2" class="data row1 col2" >0.9669</td>
#       <td id="T_52e57_row1_col3" class="data row1 col3" >0.9460</td>
#       <td id="T_52e57_row1_col4" class="data row1 col4" >0.9564</td>
#       <td id="T_52e57_row1_col5" class="data row1 col5" >0.8260</td>
#       <td id="T_52e57_row1_col6" class="data row1 col6" >0.8268</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_52e57_row2_col0" class="data row2 col0" >0.9317</td>
#       <td id="T_52e57_row2_col1" class="data row2 col1" >0.9772</td>
#       <td id="T_52e57_row2_col2" class="data row2 col2" >0.9412</td>
#       <td id="T_52e57_row2_col3" class="data row2 col3" >0.9660</td>
#       <td id="T_52e57_row2_col4" class="data row2 col4" >0.9534</td>
#       <td id="T_52e57_row2_col5" class="data row2 col5" >0.8253</td>
#       <td id="T_52e57_row2_col6" class="data row2 col6" >0.8263</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_52e57_row3_col0" class="data row3 col0" >0.9508</td>
#       <td id="T_52e57_row3_col1" class="data row3 col1" >0.9814</td>
#       <td id="T_52e57_row3_col2" class="data row3 col2" >0.9743</td>
#       <td id="T_52e57_row3_col3" class="data row3 col3" >0.9601</td>
#       <td id="T_52e57_row3_col4" class="data row3 col4" >0.9672</td>
#       <td id="T_52e57_row3_col5" class="data row3 col5" >0.8693</td>
#       <td id="T_52e57_row3_col6" class="data row3 col6" >0.8697</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_52e57_row4_col0" class="data row4 col0" >0.9399</td>
#       <td id="T_52e57_row4_col1" class="data row4 col1" >0.9840</td>
#       <td id="T_52e57_row4_col2" class="data row4 col2" >0.9669</td>
#       <td id="T_52e57_row4_col3" class="data row4 col3" >0.9529</td>
#       <td id="T_52e57_row4_col4" class="data row4 col4" >0.9599</td>
#       <td id="T_52e57_row4_col5" class="data row4 col5" >0.8403</td>
#       <td id="T_52e57_row4_col6" class="data row4 col6" >0.8407</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_52e57_row5_col0" class="data row5 col0" >0.9536</td>
#       <td id="T_52e57_row5_col1" class="data row5 col1" >0.9890</td>
#       <td id="T_52e57_row5_col2" class="data row5 col2" >0.9706</td>
#       <td id="T_52e57_row5_col3" class="data row5 col3" >0.9670</td>
#       <td id="T_52e57_row5_col4" class="data row5 col4" >0.9688</td>
#       <td id="T_52e57_row5_col5" class="data row5 col5" >0.8779</td>
#       <td id="T_52e57_row5_col6" class="data row5 col6" >0.8779</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_52e57_row6_col0" class="data row6 col0" >0.9098</td>
#       <td id="T_52e57_row6_col1" class="data row6 col1" >0.9725</td>
#       <td id="T_52e57_row6_col2" class="data row6 col2" >0.9228</td>
#       <td id="T_52e57_row6_col3" class="data row6 col3" >0.9544</td>
#       <td id="T_52e57_row6_col4" class="data row6 col4" >0.9383</td>
#       <td id="T_52e57_row6_col5" class="data row6 col5" >0.7710</td>
#       <td id="T_52e57_row6_col6" class="data row6 col6" >0.7725</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_52e57_row7_col0" class="data row7 col0" >0.9399</td>
#       <td id="T_52e57_row7_col1" class="data row7 col1" >0.9733</td>
#       <td id="T_52e57_row7_col2" class="data row7 col2" >0.9632</td>
#       <td id="T_52e57_row7_col3" class="data row7 col3" >0.9562</td>
#       <td id="T_52e57_row7_col4" class="data row7 col4" >0.9597</td>
#       <td id="T_52e57_row7_col5" class="data row7 col5" >0.8414</td>
#       <td id="T_52e57_row7_col6" class="data row7 col6" >0.8415</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_52e57_row8_col0" class="data row8 col0" >0.9508</td>
#       <td id="T_52e57_row8_col1" class="data row8 col1" >0.9803</td>
#       <td id="T_52e57_row8_col2" class="data row8 col2" >0.9594</td>
#       <td id="T_52e57_row8_col3" class="data row8 col3" >0.9738</td>
#       <td id="T_52e57_row8_col4" class="data row8 col4" >0.9665</td>
#       <td id="T_52e57_row8_col5" class="data row8 col5" >0.8738</td>
#       <td id="T_52e57_row8_col6" class="data row8 col6" >0.8741</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_52e57_row9_col0" class="data row9 col0" >0.9372</td>
#       <td id="T_52e57_row9_col1" class="data row9 col1" >0.9759</td>
#       <td id="T_52e57_row9_col2" class="data row9 col2" >0.9446</td>
#       <td id="T_52e57_row9_col3" class="data row9 col3" >0.9697</td>
#       <td id="T_52e57_row9_col4" class="data row9 col4" >0.9570</td>
#       <td id="T_52e57_row9_col5" class="data row9 col5" >0.8403</td>
#       <td id="T_52e57_row9_col6" class="data row9 col6" >0.8413</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_52e57_row10_col0" class="data row10 col0" >0.9394</td>
#       <td id="T_52e57_row10_col1" class="data row10 col1" >0.9798</td>
#       <td id="T_52e57_row10_col2" class="data row10 col2" >0.9570</td>
#       <td id="T_52e57_row10_col3" class="data row10 col3" >0.9613</td>
#       <td id="T_52e57_row10_col4" class="data row10 col4" >0.9590</td>
#       <td id="T_52e57_row10_col5" class="data row10 col5" >0.8424</td>
#       <td id="T_52e57_row10_col6" class="data row10 col6" >0.8430</td>
#     </tr>
#     <tr>
#       <th id="T_52e57_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_52e57_row11_col0" class="data row11 col0" >0.0121</td>
#       <td id="T_52e57_row11_col1" class="data row11 col1" >0.0055</td>
#       <td id="T_52e57_row11_col2" class="data row11 col2" >0.0152</td>
#       <td id="T_52e57_row11_col3" class="data row11 col3" >0.0083</td>
#       <td id="T_52e57_row11_col4

# %%
tuned_lightgbm_all_pca5 = tune_model(lightgbm_all_pca5)
# Out:
# <style type="text/css">
# #T_90bf6_row10_col0, #T_90bf6_row10_col1, #T_90bf6_row10_col2, #T_90bf6_row10_col3, #T_90bf6_row10_col4, #T_90bf6_row10_col5, #T_90bf6_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_90bf6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90bf6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_90bf6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_90bf6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_90bf6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_90bf6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_90bf6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_90bf6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90bf6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90bf6_row0_col0" class="data row0 col0" >0.9510</td>
#       <td id="T_90bf6_row0_col1" class="data row0 col1" >0.9884</td>
#       <td id="T_90bf6_row0_col2" class="data row0 col2" >0.9632</td>
#       <td id="T_90bf6_row0_col3" class="data row0 col3" >0.9704</td>
#       <td id="T_90bf6_row0_col4" class="data row0 col4" >0.9668</td>
#       <td id="T_90bf6_row0_col5" class="data row0 col5" >0.8730</td>
#       <td id="T_90bf6_row0_col6" class="data row0 col6" >0.8731</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90bf6_row1_col0" class="data row1 col0" >0.9428</td>
#       <td id="T_90bf6_row1_col1" class="data row1 col1" >0.9785</td>
#       <td id="T_90bf6_row1_col2" class="data row1 col2" >0.9669</td>
#       <td id="T_90bf6_row1_col3" class="data row1 col3" >0.9564</td>
#       <td id="T_90bf6_row1_col4" class="data row1 col4" >0.9616</td>
#       <td id="T_90bf6_row1_col5" class="data row1 col5" >0.8493</td>
#       <td id="T_90bf6_row1_col6" class="data row1 col6" >0.8495</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90bf6_row2_col0" class="data row2 col0" >0.9290</td>
#       <td id="T_90bf6_row2_col1" class="data row2 col1" >0.9769</td>
#       <td id="T_90bf6_row2_col2" class="data row2 col2" >0.9412</td>
#       <td id="T_90bf6_row2_col3" class="data row2 col3" >0.9624</td>
#       <td id="T_90bf6_row2_col4" class="data row2 col4" >0.9517</td>
#       <td id="T_90bf6_row2_col5" class="data row2 col5" >0.8177</td>
#       <td id="T_90bf6_row2_col6" class="data row2 col6" >0.8184</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90bf6_row3_col0" class="data row3 col0" >0.9454</td>
#       <td id="T_90bf6_row3_col1" class="data row3 col1" >0.9805</td>
#       <td id="T_90bf6_row3_col2" class="data row3 col2" >0.9743</td>
#       <td id="T_90bf6_row3_col3" class="data row3 col3" >0.9532</td>
#       <td id="T_90bf6_row3_col4" class="data row3 col4" >0.9636</td>
#       <td id="T_90bf6_row3_col5" class="data row3 col5" >0.8538</td>
#       <td id="T_90bf6_row3_col6" class="data row3 col6" >0.8546</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90bf6_row4_col0" class="data row4 col0" >0.9344</td>
#       <td id="T_90bf6_row4_col1" class="data row4 col1" >0.9792</td>
#       <td id="T_90bf6_row4_col2" class="data row4 col2" >0.9632</td>
#       <td id="T_90bf6_row4_col3" class="data row4 col3" >0.9493</td>
#       <td id="T_90bf6_row4_col4" class="data row4 col4" >0.9562</td>
#       <td id="T_90bf6_row4_col5" class="data row4 col5" >0.8258</td>
#       <td id="T_90bf6_row4_col6" class="data row4 col6" >0.8261</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90bf6_row5_col0" class="data row5 col0" >0.9508</td>
#       <td id="T_90bf6_row5_col1" class="data row5 col1" >0.9878</td>
#       <td id="T_90bf6_row5_col2" class="data row5 col2" >0.9596</td>
#       <td id="T_90bf6_row5_col3" class="data row5 col3" >0.9739</td>
#       <td id="T_90bf6_row5_col4" class="data row5 col4" >0.9667</td>
#       <td id="T_90bf6_row5_col5" class="data row5 col5" >0.8729</td>
#       <td id="T_90bf6_row5_col6" class="data row5 col6" >0.8733</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90bf6_row6_col0" class="data row6 col0" >0.9180</td>
#       <td id="T_90bf6_row6_col1" class="data row6 col1" >0.9733</td>
#       <td id="T_90bf6_row6_col2" class="data row6 col2" >0.9191</td>
#       <td id="T_90bf6_row6_col3" class="data row6 col3" >0.9690</td>
#       <td id="T_90bf6_row6_col4" class="data row6 col4" >0.9434</td>
#       <td id="T_90bf6_row6_col5" class="data row6 col5" >0.7953</td>
#       <td id="T_90bf6_row6_col6" class="data row6 col6" >0.7989</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90bf6_row7_col0" class="data row7 col0" >0.9372</td>
#       <td id="T_90bf6_row7_col1" class="data row7 col1" >0.9725</td>
#       <td id="T_90bf6_row7_col2" class="data row7 col2" >0.9596</td>
#       <td id="T_90bf6_row7_col3" class="data row7 col3" >0.9560</td>
#       <td id="T_90bf6_row7_col4" class="data row7 col4" >0.9578</td>
#       <td id="T_90bf6_row7_col5" class="data row7 col5" >0.8348</td>
#       <td id="T_90bf6_row7_col6" class="data row7 col6" >0.8348</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90bf6_row8_col0" class="data row8 col0" >0.9481</td>
#       <td id="T_90bf6_row8_col1" class="data row8 col1" >0.9806</td>
#       <td id="T_90bf6_row8_col2" class="data row8 col2" >0.9631</td>
#       <td id="T_90bf6_row8_col3" class="data row8 col3" >0.9667</td>
#       <td id="T_90bf6_row8_col4" class="data row8 col4" >0.9649</td>
#       <td id="T_90bf6_row8_col5" class="data row8 col5" >0.8654</td>
#       <td id="T_90bf6_row8_col6" class="data row8 col6" >0.8654</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90bf6_row9_col0" class="data row9 col0" >0.9344</td>
#       <td id="T_90bf6_row9_col1" class="data row9 col1" >0.9685</td>
#       <td id="T_90bf6_row9_col2" class="data row9 col2" >0.9373</td>
#       <td id="T_90bf6_row9_col3" class="data row9 col3" >0.9732</td>
#       <td id="T_90bf6_row9_col4" class="data row9 col4" >0.9549</td>
#       <td id="T_90bf6_row9_col5" class="data row9 col5" >0.8350</td>
#       <td id="T_90bf6_row9_col6" class="data row9 col6" >0.8370</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_90bf6_row10_col0" class="data row10 col0" >0.9391</td>
#       <td id="T_90bf6_row10_col1" class="data row10 col1" >0.9786</td>
#       <td id="T_90bf6_row10_col2" class="data row10 col2" >0.9547</td>
#       <td id="T_90bf6_row10_col3" class="data row10 col3" >0.9630</td>
#       <td id="T_90bf6_row10_col4" class="data row10 col4" >0.9588</td>
#       <td id="T_90bf6_row10_col5" class="data row10 col5" >0.8423</td>
#       <td id="T_90bf6_row10_col6" class="data row10 col6" >0.8431</td>
#     </tr>
#     <tr>
#       <th id="T_90bf6_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_90bf6_row11_col0" class="data row11 col0" >0.0100</td>
#       <td id="T_90bf6_row11_col1" class="data row11 col1" >0.0060</td>
#       <td id="T_90bf6_row11_col2" class="data row11 col2" >0.0160</td>
#       <td id="T_90bf6_row11_col3" class="data row11 col3" >0.0084</td>
#       <td id="T_90bf6_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# #### Analyze the performance of trained and tuned model on holdout set.
# #### Hyperparameters used to finetune the model

# %%
# Fetch the hyperparameters used in the tune_model method
hyperparameters = tuned_lightgbm_all_pca5.get_params()
hyperparameters
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': 123,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %%
pred_holdout = predict_model(tuned_lightgbm_all_pca5, data=df_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_9eb7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9eb7c_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_9eb7c_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_9eb7c_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_9eb7c_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_9eb7c_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_9eb7c_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_9eb7c_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_9eb7c_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9eb7c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9eb7c_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9eb7c_row0_col1" class="data row0 col1" >0.7452</td>
#       <td id="T_9eb7c_row0_col2" class="data row0 col2" >0.9261</td>
#       <td id="T_9eb7c_row0_col3" class="data row0 col3" >0.9821</td>
#       <td id="T_9eb7c_row0_col4" class="data row0 col4" >0.7159</td>
#       <td id="T_9eb7c_row0_col5" class="data row0 col5" >0.8281</td>
#       <td id="T_9eb7c_row0_col6" class="data row0 col6" >0.3795</td>
#       <td id="T_9eb7c_row0_col7" class="data row0 col7" >0.4603</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### AUC-ROC Curve

# %%
print("\nAUC-ROC Curve")
plot_model(tuned_lightgbm_all_pca5, plot='auc')
# Out:
# AUC-ROC Curve

# %% [markdown]
# #### Confusion Matrix

# %%
print("\nConfusion Matrix")
plot_model(tuned_lightgbm_all_pca5, plot='confusion_matrix')
# Out:
# Confusion Matrix

# %% [markdown]
# #### Precision Recall Curve

# %%
print("\nPrecision Recall Curve")
plot_model(tuned_lightgbm_all_pca5, plot='pr')
# Out:
# Precision Recall Curve

# %% [markdown]
# #### Decision Boundary

# %%
print("\n\nDecision Boundary\n")
plot_model(tuned_lightgbm_all_pca5, plot='boundary')
# Out:
# Decision Boundary

# %% [markdown]
# #### Learning Curve

# %%
print("\n\nLearning Curve\n")
plot_model(tuned_lightgbm_all_pca5, plot='learning')
# Out:
# Learning Curve

# %% [markdown]
# ### PCA = 10

# %%
start_time = time.time()

best_model_for_pca10, pca10_result = efc.train_multiple_ml_models_with_pca(10, filtered_df_train)

end_time = time.time()

# Calculate the total time taken
total_time_seconds = end_time - start_time

# Convert the time to minutes and seconds
total_time_minutes = total_time_seconds // 60
total_time_seconds = total_time_seconds % 60

# Print the results
print(f"\nTotal time to execute: {int(total_time_minutes)} minutes and {total_time_seconds:.2f} seconds")
# Out:
# <style type="text/css">
# #T_1e4f7_row8_col1, #T_1e4f7_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1e4f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e4f7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1e4f7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e4f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e4f7_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1e4f7_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e4f7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1e4f7_row1_col1" class="data row1 col1" >Pneumonia</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e4f7_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_1e4f7_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e4f7_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_1e4f7_row3_col1" class="data row3 col1" >(5232, 97)</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e4f7_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_1e4f7_row4_col1" class="data row4 col1" >(5232, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1e4f7_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_1e4f7_row5_col1" class="data row5 col1" >(3662, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1e4f7_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_1e4f7_row6_col1" class="data row6 col1" >(1570, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1e4f7_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_1e4f7_row7_col1" class="data row7 col1" >96</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1e4f7_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_1e4f7_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1e4f7_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_1e4f7_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1e4f7_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_1e4f7_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1e4f7_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_1e4f7_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1e4f7_row12_col0" class="data row12 col0" >PCA</td>
#       <td id="T_1e4f7_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1e4f7_row13_col0" class="data row13 col0" >PCA method</td>
#       <td id="T_1e4f7_row13_col1" class="data row13 col1" >linear</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1e4f7_row14_col0" class="data row14 col0" >PCA components</td>
#       <td id="T_1e4f7_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1e4f7_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_1e4f7_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1e4f7_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_1e4f7_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1e4f7_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_1e4f7_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1e4f7_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_1e4f7_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1e4f7_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_1e4f7_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1e4f7_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_1e4f7_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1e4f7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1e4f7_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_1e4f7_row21_col1" class="data row21 col1" >9473</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_3cb3d th {
#   text-align: left;
# }
# #T_3cb3d_row0_col0, #T_3cb3d_row0_col2, #T_3cb3d_row0_col3, #T_3cb3d_row0_col4, #T_3cb3d_row1_col0, #T_3cb3d_row1_col1, #T_3cb3d_row1_col3, #T_3cb3d_row1_col5, #T_3cb3d_row1_col6, #T_3cb3d_row1_col7, #T_3cb3d_row2_col0, #T_3cb3d_row2_col1, #T_3cb3d_row2_col2, #T_3cb3d_row2_col3, #T_3cb3d_row2_col4, #T_3cb3d_row2_col5, #T_3cb3d_row2_col6, #T_3cb3d_row2_col7, #T_3cb3d_row3_col0, #T_3cb3d_row3_col1, #T_3cb3d_row3_col2, #T_3cb3d_row3_col3, #T_3cb3d_row3_col4, #T_3cb3d_row3_col5, #T_3cb3d_row3_col6, #T_3cb3d_row3_col7, #T_3cb3d_row4_col0, #T_3cb3d_row4_col1, #T_3cb3d_row4_col2, #T_3cb3d_row4_col3, #T_3cb3d_row4_col4, #T_3cb3d_row4_col5, #T_3cb3d_row4_col6, #T_3cb3d_row4_col7, #T_3cb3d_row5_col0, #T_3cb3d_row5_col1, #T_3cb3d_row5_col2, #T_3cb3d_row5_col3, #T_3cb3d_row5_col4, #T_3cb3d_row5_col5, #T_3cb3d_row5_col6, #T_3cb3d_row5_col7, #T_3cb3d_row6_col0, #T_3cb3d_row6_col1, #T_3cb3d_row6_col2, #T_3cb3d_row6_col3, #T_3cb3d_row6_col4, #T_3cb3d_row6_col5, #T_3cb3d_row6_col6, #T_3cb3d_row6_col7, #T_3cb3d_row7_col0, #T_3cb3d_row7_col1, #T_3cb3d_row7_col2, #T_3cb3d_row7_col3, #T_3cb3d_row7_col4, #T_3cb3d_row7_col5, #T_3cb3d_row7_col6, #T_3cb3d_row7_col7, #T_3cb3d_row8_col0, #T_3cb3d_row8_col1, #T_3cb3d_row8_col2, #T_3cb3d_row8_col3, #T_3cb3d_row8_col4, #T_3cb3d_row8_col5, #T_3cb3d_row8_col6, #T_3cb3d_row8_col7, #T_3cb3d_row9_col0, #T_3cb3d_row9_col1, #T_3cb3d_row9_col2, #T_3cb3d_row9_col3, #T_3cb3d_row9_col4, #T_3cb3d_row9_col5, #T_3cb3d_row9_col6, #T_3cb3d_row9_col7, #T_3cb3d_row10_col0, #T_3cb3d_row10_col1, #T_3cb3d_row10_col2, #T_3cb3d_row10_col3, #T_3cb3d_row10_col4, #T_3cb3d_row10_col5, #T_3cb3d_row10_col6, #T_3cb3d_row10_col7, #T_3cb3d_row11_col0, #T_3cb3d_row11_col1, #T_3cb3d_row11_col2, #T_3cb3d_row11_col3, #T_3cb3d_row11_col4, #T_3cb3d_row11_col5, #T_3cb3d_row11_col6, #T_3cb3d_row11_col7, #T_3cb3d_row12_col0, #T_3cb3d_row12_col1, #T_3cb3d_row12_col2, #T_3cb3d_row12_col3, #T_3cb3d_row12_col4, #T_3cb3d_row12_col5, #T_3cb3d_row12_col6, #T_3cb3d_row12_col7, #T_3cb3d_row13_col0, #T_3cb3d_row13_col1, #T_3cb3d_row13_col2, #T_3cb3d_row13_col3, #T_3cb3d_row13_col4, #T_3cb3d_row13_col5, #T_3cb3d_row13_col6, #T_3cb3d_row13_col7, #T_3cb3d_row14_col0, #T_3cb3d_row14_col1, #T_3cb3d_row14_col2, #T_3cb3d_row14_col4, #T_3cb3d_row14_col5, #T_3cb3d_row14_col6, #T_3cb3d_row14_col7 {
#   text-align: left;
# }
# #T_3cb3d_row0_col1, #T_3cb3d_row0_col5, #T_3cb3d_row0_col6, #T_3cb3d_row0_col7, #T_3cb3d_row1_col2, #T_3cb3d_row1_col4, #T_3cb3d_row14_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3cb3d_row0_col8, #T_3cb3d_row1_col8, #T_3cb3d_row2_col8, #T_3cb3d_row3_col8, #T_3cb3d_row4_col8, #T_3cb3d_row5_col8, #T_3cb3d_row6_col8, #T_3cb3d_row7_col8, #T_3cb3d_row8_col8, #T_3cb3d_row9_col8, #T_3cb3d_row10_col8, #T_3cb3d_row11_col8, #T_3cb3d_row12_col8, #T_3cb3d_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3cb3d_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3cb3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3cb3d_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3cb3d_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3cb3d_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3cb3d_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3cb3d_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3cb3d_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3cb3d_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3cb3d_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_3cb3d_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3cb3d_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_3cb3d_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3cb3d_row0_col1" class="data row0 col1" >0.9626</td>
#       <td id="T_3cb3d_row0_col2" class="data row0 col2" >0.9886</td>
#       <td id="T_3cb3d_row0_col3" class="data row0 col3" >0.9779</td>
#       <td id="T_3cb3d_row0_col4" class="data row0 col4" >0.9720</td>
#       <td id="T_3cb3d_row0_col5" class="data row0 col5" >0.9749</td>
#       <td id="T_3cb3d_row0_col6" class="data row0 col6" >0.9016</td>
#       <td id="T_3cb3d_row0_col7" class="data row0 col7" >0.9020</td>
#       <td id="T_3cb3d_row0_col8" class="data row0 col8" >0.3310</td>
#     </tr>
#     <tr>
#       <th id="T_3cb3d_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_3cb3d_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_3cb3d_row1_col1" class="data row1 col1" >0.9596</td>
#       <td id="T_3cb3d_row1_col2" class="data row1 col2" >0.9887</td>
#       <td id="T_3cb3d_row1_col3" class="data row1 col3" >0.9735</td>
#       <td id="T_3cb3d_row1_col4" class="data row1 col4" >0.9722</td>
#       <td id="T_3cb3d_row1_col5" class="data row1 col5" >0.9728</td>
#       <td id="T_3cb3d_row1_col6" class="data row1 col6" >0.8942</td>
#       <td id="T_3cb3d_row1_col7" class="data row1 col7" >0.8946</td>
#       <td id="T_3cb3d_row1_col8" class="data row1 col8" >0.0580</td>
#     </tr>
#     <tr>
#       <th id="T_3cb3d_level0_row2" class="row_heading level0 row2" >xgboost</th>
#       <td id="T_3cb3d_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#       <td id="T_3cb3d_row2_col1" class="data row2 col1" >0.9579</td>
#       <td id="T_3cb3d_row2_col2" class="data row2 col2" >0.9876</td>
#       <td id="T_3cb3d_row2_col3" class="data row2 col3" >0.9746</td>
#       <td id="T_3cb3d_row2_col4" class="data row2 col4" >0.9690</td>
#       <td id="T_3cb3d_row2_col5" class="data row2 col5" >0.9717</td>
#       <td id="T_3cb3d_row2_col6" class="data row2 col6" >0.8895</td>
#       <td id="T_3cb3d_row2_col7" class="data row2 col7" >0.8900</td>
#       <td id="T_3cb3d_row2_col8" class="data row2 col8" >0.1040</td>
#     </tr>
#     <tr>
#       <th id="T_3cb3d_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_3cb3d_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_3cb3d_row3_col1" class="data row3 col1" >0.9577</td>
#       <td id="T_3cb3d_row3_col2" class="data row3 col2" >0.9856</td>
#       <td id="T_3cb3d_row3_col3" class="data row3 col3" >0.9746</td>
#       <td id="T_3cb3d_row3_col4" class="data row3 col4" >0.9687</td>
#       <td id="T_3cb3d_row3_col5" class="data row3 col5" >0.9716</td>
#       <td id="T_3cb3d_row3_col6" class="data row3 col6" >0.8887</td>
#       <td id="T_3cb3d_row3_col7" class="data row3 col7" >0.8892</td>
#       <td id="T_3cb3d_row3_col8" class="data row3 col8" >0.0970</td>
#     </tr>
#     <tr>
#       <th id="T_3cb3d_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_3cb3d_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3cb3d_row4_col1" class="data row4 col1" >0.9566</td>
#       <td id="T_3cb3d_row4_col2" class="data row4 col2" >0.9860</td>
#       <td id="T_3cb3d_row4_col3" class="data row4 col3" >0.9724</td>
#       <td id="T_3cb3d_row4_col4" class="data row4 col4" >0.9693</td>
#       <td id="T_3cb3d_row4_col5" class="data row4 col5" >0.9708</td>
#       <td id="T_3cb3d_row4_col6" class="data row4 col6" >0.8862</td>
#       <td id="T_3cb3d_row4_col7" class="data row4 col7" >0.8869</td>
#       <td id="T_3cb3d_row4_col8" class="data row4 col8" >0.2050</td>
#     </tr>
#     <tr>
#       <th id="T_3cb3d_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_3cb3d_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_3cb3d_row5_col1" class="data row5 col1" >0.9432</td>
#       <td id="T_3cb3d_row5_col2" class="data row5 col2" >0.9789</td>
#       <td id="T_3cb3d_row5_col3" class="data row5 col3" >0.9606</td>
#       <td id="T_3cb3d_row5_col4" class="data row5 col4" >0.9629</td>
#       <td id=
# Total time to execute: 0 minutes and 14.99 seconds

# %%
best_model_for_pca10
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# #### Train and evaluate the performance of LGBM Classifier using cross validation as well as Hyperparameters

# %%
lightgbm_all_pca10 = create_model('lightgbm', boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
                            importance_type='split', learning_rate=0.1, max_depth=-1,
                            min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
                            n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
                            random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
                            subsample_for_bin=200000, subsample_freq=0, verbose=True)
# Out:
# <style type="text/css">
# #T_848ad_row10_col0, #T_848ad_row10_col1, #T_848ad_row10_col2, #T_848ad_row10_col3, #T_848ad_row10_col4, #T_848ad_row10_col5, #T_848ad_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_848ad">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_848ad_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_848ad_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_848ad_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_848ad_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_848ad_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_848ad_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_848ad_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_848ad_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_848ad_row0_col0" class="data row0 col0" >0.9728</td>
#       <td id="T_848ad_row0_col1" class="data row0 col1" >0.9956</td>
#       <td id="T_848ad_row0_col2" class="data row0 col2" >0.9816</td>
#       <td id="T_848ad_row0_col3" class="data row0 col3" >0.9816</td>
#       <td id="T_848ad_row0_col4" class="data row0 col4" >0.9816</td>
#       <td id="T_848ad_row0_col5" class="data row0 col5" >0.9290</td>
#       <td id="T_848ad_row0_col6" class="data row0 col6" >0.9290</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_848ad_row1_col0" class="data row1 col0" >0.9564</td>
#       <td id="T_848ad_row1_col1" class="data row1 col1" >0.9883</td>
#       <td id="T_848ad_row1_col2" class="data row1 col2" >0.9816</td>
#       <td id="T_848ad_row1_col3" class="data row1 col3" >0.9604</td>
#       <td id="T_848ad_row1_col4" class="data row1 col4" >0.9709</td>
#       <td id="T_848ad_row1_col5" class="data row1 col5" >0.8840</td>
#       <td id="T_848ad_row1_col6" class="data row1 col6" >0.8848</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_848ad_row2_col0" class="data row2 col0" >0.9617</td>
#       <td id="T_848ad_row2_col1" class="data row2 col1" >0.9904</td>
#       <td id="T_848ad_row2_col2" class="data row2 col2" >0.9743</td>
#       <td id="T_848ad_row2_col3" class="data row2 col3" >0.9743</td>
#       <td id="T_848ad_row2_col4" class="data row2 col4" >0.9743</td>
#       <td id="T_848ad_row2_col5" class="data row2 col5" >0.8998</td>
#       <td id="T_848ad_row2_col6" class="data row2 col6" >0.8998</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_848ad_row3_col0" class="data row3 col0" >0.9617</td>
#       <td id="T_848ad_row3_col1" class="data row3 col1" >0.9879</td>
#       <td id="T_848ad_row3_col2" class="data row3 col2" >0.9890</td>
#       <td id="T_848ad_row3_col3" class="data row3 col3" >0.9607</td>
#       <td id="T_848ad_row3_col4" class="data row3 col4" >0.9746</td>
#       <td id="T_848ad_row3_col5" class="data row3 col5" >0.8969</td>
#       <td id="T_848ad_row3_col6" class="data row3 col6" >0.8985</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_848ad_row4_col0" class="data row4 col0" >0.9727</td>
#       <td id="T_848ad_row4_col1" class="data row4 col1" >0.9935</td>
#       <td id="T_848ad_row4_col2" class="data row4 col2" >0.9853</td>
#       <td id="T_848ad_row4_col3" class="data row4 col3" >0.9781</td>
#       <td id="T_848ad_row4_col4" class="data row4 col4" >0.9817</td>
#       <td id="T_848ad_row4_col5" class="data row4 col5" >0.9279</td>
#       <td id="T_848ad_row4_col6" class="data row4 col6" >0.9280</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_848ad_row5_col0" class="data row5 col0" >0.9699</td>
#       <td id="T_848ad_row5_col1" class="data row5 col1" >0.9919</td>
#       <td id="T_848ad_row5_col2" class="data row5 col2" >0.9816</td>
#       <td id="T_848ad_row5_col3" class="data row5 col3" >0.9780</td>
#       <td id="T_848ad_row5_col4" class="data row5 col4" >0.9798</td>
#       <td id="T_848ad_row5_col5" class="data row5 col5" >0.9210</td>
#       <td id="T_848ad_row5_col6" class="data row5 col6" >0.9210</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_848ad_row6_col0" class="data row6 col0" >0.9563</td>
#       <td id="T_848ad_row6_col1" class="data row6 col1" >0.9867</td>
#       <td id="T_848ad_row6_col2" class="data row6 col2" >0.9596</td>
#       <td id="T_848ad_row6_col3" class="data row6 col3" >0.9812</td>
#       <td id="T_848ad_row6_col4" class="data row6 col4" >0.9703</td>
#       <td id="T_848ad_row6_col5" class="data row6 col5" >0.8878</td>
#       <td id="T_848ad_row6_col6" class="data row6 col6" >0.8886</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_848ad_row7_col0" class="data row7 col0" >0.9536</td>
#       <td id="T_848ad_row7_col1" class="data row7 col1" >0.9823</td>
#       <td id="T_848ad_row7_col2" class="data row7 col2" >0.9816</td>
#       <td id="T_848ad_row7_col3" class="data row7 col3" >0.9570</td>
#       <td id="T_848ad_row7_col4" class="data row7 col4" >0.9691</td>
#       <td id="T_848ad_row7_col5" class="data row7 col5" >0.8753</td>
#       <td id="T_848ad_row7_col6" class="data row7 col6" >0.8764</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_848ad_row8_col0" class="data row8 col0" >0.9590</td>
#       <td id="T_848ad_row8_col1" class="data row8 col1" >0.9904</td>
#       <td id="T_848ad_row8_col2" class="data row8 col2" >0.9742</td>
#       <td id="T_848ad_row8_col3" class="data row8 col3" >0.9706</td>
#       <td id="T_848ad_row8_col4" class="data row8 col4" >0.9724</td>
#       <td id="T_848ad_row8_col5" class="data row8 col5" >0.8930</td>
#       <td id="T_848ad_row8_col6" class="data row8 col6" >0.8930</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_848ad_row9_col0" class="data row9 col0" >0.9617</td>
#       <td id="T_848ad_row9_col1" class="data row9 col1" >0.9789</td>
#       <td id="T_848ad_row9_col2" class="data row9 col2" >0.9705</td>
#       <td id="T_848ad_row9_col3" class="data row9 col3" >0.9777</td>
#       <td id="T_848ad_row9_col4" class="data row9 col4" >0.9741</td>
#       <td id="T_848ad_row9_col5" class="data row9 col5" >0.9012</td>
#       <td id="T_848ad_row9_col6" class="data row9 col6" >0.9013</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_848ad_row10_col0" class="data row10 col0" >0.9626</td>
#       <td id="T_848ad_row10_col1" class="data row10 col1" >0.9886</td>
#       <td id="T_848ad_row10_col2" class="data row10 col2" >0.9779</td>
#       <td id="T_848ad_row10_col3" class="data row10 col3" >0.9720</td>
#       <td id="T_848ad_row10_col4" class="data row10 col4" >0.9749</td>
#       <td id="T_848ad_row10_col5" class="data row10 col5" >0.9016</td>
#       <td id="T_848ad_row10_col6" class="data row10 col6" >0.9020</td>
#     </tr>
#     <tr>
#       <th id="T_848ad_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_848ad_row11_col0" class="data row11 col0" >0.0066</td>
#       <td id="T_848ad_row11_col1" class="data row11 col1" >0.0048</td>
#       <td id="T_848ad_row11_col2" class="data row11 col2" >0.0081</td>
#       <td id="T_848ad_row11_col3" class="data row11 col3" >0.0088</td>
#       <td id="T_848ad_row11_col4

# %%
tuned_lightgbm_all_pca10 = tune_model(lightgbm_all_pca10)
# Out:
# <style type="text/css">
# #T_b6add_row10_col0, #T_b6add_row10_col1, #T_b6add_row10_col2, #T_b6add_row10_col3, #T_b6add_row10_col4, #T_b6add_row10_col5, #T_b6add_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b6add">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6add_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b6add_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b6add_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b6add_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b6add_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b6add_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b6add_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6add_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6add_row0_col0" class="data row0 col0" >0.9700</td>
#       <td id="T_b6add_row0_col1" class="data row0 col1" >0.9956</td>
#       <td id="T_b6add_row0_col2" class="data row0 col2" >0.9743</td>
#       <td id="T_b6add_row0_col3" class="data row0 col3" >0.9851</td>
#       <td id="T_b6add_row0_col4" class="data row0 col4" >0.9797</td>
#       <td id="T_b6add_row0_col5" class="data row0 col5" >0.9227</td>
#       <td id="T_b6add_row0_col6" class="data row0 col6" >0.9229</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b6add_row1_col0" class="data row1 col0" >0.9537</td>
#       <td id="T_b6add_row1_col1" class="data row1 col1" >0.9848</td>
#       <td id="T_b6add_row1_col2" class="data row1 col2" >0.9779</td>
#       <td id="T_b6add_row1_col3" class="data row1 col3" >0.9603</td>
#       <td id="T_b6add_row1_col4" class="data row1 col4" >0.9690</td>
#       <td id="T_b6add_row1_col5" class="data row1 col5" >0.8772</td>
#       <td id="T_b6add_row1_col6" class="data row1 col6" >0.8777</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b6add_row2_col0" class="data row2 col0" >0.9508</td>
#       <td id="T_b6add_row2_col1" class="data row2 col1" >0.9887</td>
#       <td id="T_b6add_row2_col2" class="data row2 col2" >0.9669</td>
#       <td id="T_b6add_row2_col3" class="data row2 col3" >0.9669</td>
#       <td id="T_b6add_row2_col4" class="data row2 col4" >0.9669</td>
#       <td id="T_b6add_row2_col5" class="data row2 col5" >0.8712</td>
#       <td id="T_b6add_row2_col6" class="data row2 col6" >0.8712</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b6add_row3_col0" class="data row3 col0" >0.9645</td>
#       <td id="T_b6add_row3_col1" class="data row3 col1" >0.9876</td>
#       <td id="T_b6add_row3_col2" class="data row3 col2" >0.9890</td>
#       <td id="T_b6add_row3_col3" class="data row3 col3" >0.9642</td>
#       <td id="T_b6add_row3_col4" class="data row3 col4" >0.9764</td>
#       <td id="T_b6add_row3_col5" class="data row3 col5" >0.9046</td>
#       <td id="T_b6add_row3_col6" class="data row3 col6" >0.9058</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b6add_row4_col0" class="data row4 col0" >0.9617</td>
#       <td id="T_b6add_row4_col1" class="data row4 col1" >0.9930</td>
#       <td id="T_b6add_row4_col2" class="data row4 col2" >0.9706</td>
#       <td id="T_b6add_row4_col3" class="data row4 col3" >0.9778</td>
#       <td id="T_b6add_row4_col4" class="data row4 col4" >0.9742</td>
#       <td id="T_b6add_row4_col5" class="data row4 col5" >0.9005</td>
#       <td id="T_b6add_row4_col6" class="data row4 col6" >0.9006</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b6add_row5_col0" class="data row5 col0" >0.9672</td>
#       <td id="T_b6add_row5_col1" class="data row5 col1" >0.9885</td>
#       <td id="T_b6add_row5_col2" class="data row5 col2" >0.9706</td>
#       <td id="T_b6add_row5_col3" class="data row5 col3" >0.9851</td>
#       <td id="T_b6add_row5_col4" class="data row5 col4" >0.9778</td>
#       <td id="T_b6add_row5_col5" class="data row5 col5" >0.9153</td>
#       <td id="T_b6add_row5_col6" class="data row5 col6" >0.9157</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b6add_row6_col0" class="data row6 col0" >0.9508</td>
#       <td id="T_b6add_row6_col1" class="data row6 col1" >0.9856</td>
#       <td id="T_b6add_row6_col2" class="data row6 col2" >0.9485</td>
#       <td id="T_b6add_row6_col3" class="data row6 col3" >0.9847</td>
#       <td id="T_b6add_row6_col4" class="data row6 col4" >0.9663</td>
#       <td id="T_b6add_row6_col5" class="data row6 col5" >0.8755</td>
#       <td id="T_b6add_row6_col6" class="data row6 col6" >0.8776</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b6add_row7_col0" class="data row7 col0" >0.9563</td>
#       <td id="T_b6add_row7_col1" class="data row7 col1" >0.9822</td>
#       <td id="T_b6add_row7_col2" class="data row7 col2" >0.9853</td>
#       <td id="T_b6add_row7_col3" class="data row7 col3" >0.9571</td>
#       <td id="T_b6add_row7_col4" class="data row7 col4" >0.9710</td>
#       <td id="T_b6add_row7_col5" class="data row7 col5" >0.8822</td>
#       <td id="T_b6add_row7_col6" class="data row7 col6" >0.8837</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b6add_row8_col0" class="data row8 col0" >0.9645</td>
#       <td id="T_b6add_row8_col1" class="data row8 col1" >0.9879</td>
#       <td id="T_b6add_row8_col2" class="data row8 col2" >0.9815</td>
#       <td id="T_b6add_row8_col3" class="data row8 col3" >0.9708</td>
#       <td id="T_b6add_row8_col4" class="data row8 col4" >0.9761</td>
#       <td id="T_b6add_row8_col5" class="data row8 col5" >0.9066</td>
#       <td id="T_b6add_row8_col6" class="data row8 col6" >0.9068</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b6add_row9_col0" class="data row9 col0" >0.9536</td>
#       <td id="T_b6add_row9_col1" class="data row9 col1" >0.9773</td>
#       <td id="T_b6add_row9_col2" class="data row9 col2" >0.9594</td>
#       <td id="T_b6add_row9_col3" class="data row9 col3" >0.9774</td>
#       <td id="T_b6add_row9_col4" class="data row9 col4" >0.9683</td>
#       <td id="T_b6add_row9_col5" class="data row9 col5" >0.8812</td>
#       <td id="T_b6add_row9_col6" class="data row9 col6" >0.8817</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_b6add_row10_col0" class="data row10 col0" >0.9593</td>
#       <td id="T_b6add_row10_col1" class="data row10 col1" >0.9871</td>
#       <td id="T_b6add_row10_col2" class="data row10 col2" >0.9724</td>
#       <td id="T_b6add_row10_col3" class="data row10 col3" >0.9729</td>
#       <td id="T_b6add_row10_col4" class="data row10 col4" >0.9726</td>
#       <td id="T_b6add_row10_col5" class="data row10 col5" >0.8937</td>
#       <td id="T_b6add_row10_col6" class="data row10 col6" >0.8944</td>
#     </tr>
#     <tr>
#       <th id="T_b6add_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_b6add_row11_col0" class="data row11 col0" >0.0067</td>
#       <td id="T_b6add_row11_col1" class="data row11 col1" >0.0049</td>
#       <td id="T_b6add_row11_col2" class="data row11 col2" >0.0115</td>
#       <td id="T_b6add_row11_col3" class="data row11 col3" >0.0100</td>
#       <td id="T_b6add_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# #### Analyze the performance of trained and tuned model on holdout set.
# #### Hyperparameters used to finetune the model

# %%
# Fetch the hyperparameters used in the tune_model method
hyperparameters = tuned_lightgbm_all_pca10.get_params()
hyperparameters
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': 123,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %%
pred_holdout = predict_model(tuned_lightgbm_all_pca10, data=df_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_be673">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be673_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_be673_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_be673_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_be673_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_be673_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_be673_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_be673_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_be673_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be673_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be673_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_be673_row0_col1" class="data row0 col1" >0.7035</td>
#       <td id="T_be673_row0_col2" class="data row0 col2" >0.9193</td>
#       <td id="T_be673_row0_col3" class="data row0 col3" >0.9872</td>
#       <td id="T_be673_row0_col4" class="data row0 col4" >0.6814</td>
#       <td id="T_be673_row0_col5" class="data row0 col5" >0.8063</td>
#       <td id="T_be673_row0_col6" class="data row0 col6" >0.2563</td>
#       <td id="T_be673_row0_col7" class="data row0 col7" >0.3606</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### AUC-ROC Curve

# %%
print("\nAUC-ROC Curve")
plot_model(tuned_lightgbm_all_pca10, plot='auc')
# Out:
# AUC-ROC Curve

# %% [markdown]
# #### Confusion Matrix

# %%
print("\nConfusion Matrix")
plot_model(tuned_lightgbm_all_pca10, plot='confusion_matrix')
# Out:
# Confusion Matrix

# %% [markdown]
# #### Precision Recall Curve

# %%
print("\nPrecision Recall Curve")
plot_model(tuned_lightgbm_all_pca10, plot='pr')
# Out:
# Precision Recall Curve

# %% [markdown]
# #### Decision Boundary

# %%
print("\n\nDecision Boundary\n")
plot_model(tuned_lightgbm_all_pca10, plot='boundary')
# Out:
# Decision Boundary

# %% [markdown]
# #### Learning Curve

# %%
print("\n\nLearning Curve\n")
plot_model(tuned_lightgbm_all_pca10, plot='learning')
# Out:
# Learning Curve

# %%
model_file_name = 'all_features_pca5_lightgbm.pkl'
efc.save_trained_model(tuned_lightgbm_all_pca5, model_file_name)
# Out:
# Model is saved to:  ['/Users/ravkothu/Documents/Personal_items_at_Oracle/Master_Degree/University_of_San_Diego/Online_Masters/MS_in_Applied_AI/Subjects_and_Resources/AAI-501_Introduction_to_AI/AAI-501_Final_Team_Project/pneumonia_detection/trained_models/all_features_pca5_lightgbm.pkl']

# %%
model_file_name = 'all_features_pca10_lightgbm.pkl'
efc.save_trained_model(tuned_lightgbm_all_pca10, model_file_name)
# Out:
# Model is saved to:  ['/Users/ravkothu/Documents/Personal_items_at_Oracle/Master_Degree/University_of_San_Diego/Online_Masters/MS_in_Applied_AI/Subjects_and_Resources/AAI-501_Introduction_to_AI/AAI-501_Final_Team_Project/pneumonia_detection/trained_models/all_features_pca10_lightgbm.pkl']
