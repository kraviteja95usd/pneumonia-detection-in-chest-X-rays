# %% [markdown]
# ### Authors: Prof. Dr. Soumi Ray, Ravi Teja Kothuru and Abhay Srivastav
#
# ### Acknowledgements:
# I would like to thank my team mates Prof. Dr. Soumi Ray and Abhay Srivastav for their guidance and support throughout this project.
#
# **Title of the Project:** Comparative Analysis of Image-Based and Feature-Based Approaches for Pneumonia Detection in Chest X-rays
#
# **Description of the Project:** This project focuses on detecting pneumonia from chest X-ray images using Advanced Machine Learning and Deep Learning techniques (Rajpurkar et al., 2017; Wang et al., 2017). By leveraging a comprehensive dataset, including annotated images of pneumonia and normal cases, we aim to develop and compare image-based and feature-based approaches. Our goal is to identify the most effective method for accurate and interpretable pneumonia detection, contributing to improved patient outcomes through early diagnosis and treatment. This model will classify patients based on their chest X-ray images as either having pneumonia (1) or not having pneumonia (0).
#
# **Objectives of the Project:**
#
# - **Image Analysis:** Develop and evaluate deep learning models to classify chest X-rays directly. This approach leverages deep learning models, particularly Convolutional Neural Networks (CNNs), to perform end-to-end image classification. The models directly process raw chest X-ray images to classify them as normal or pneumonia.
#
# - **Feature Analysis:** Extract meaningful features from the images and use them to train and evaluate traditional machine learning models. In this approach, we first extract features from the chest X-ray images. These features are then used as inputs for traditional machine learning algorithms. The process includes steps such as feature extraction, selection, and transformation, followed by the application of machine learning techniques like Support Vector Machines (SVM), Random Forests.
#
# **Name of the Dataset:** The dataset used in this project is the Chest X-ray dataset considered from the Research paper named **Labeled Optical Coherence Tomography (OCT) and Chest X-Ray Images for Classification**.
#
# **Description of the Dataset:** The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy.
#
# **Dataset Source:**
#
# - https://data.mendeley.com/datasets/rscbjbr9sj/2
#
# **Type of the Dataset:**
#
# - X-ray Images
#
# **Description of Dataset:**
# The considered dataset has the following information for better reference:
# - Separate folders to train and validate/test the model.
# - Enough number of Chest X-ray images to train the model to detect and diagnose Pneumonia.
# - The target variable for classification is whether patient has pneumonia or not.
#
# **Goal of the Project using this Dataset:**
# The goal of this project is to conduct a comprehensive comparative analysis of image-based and feature-based approaches for pneumonia detection using chest X-ray images. By evaluating the performance, robustness, and interpretability of deep learning and traditional machine learning models, we aim to identify the most effective method for accurately classifying chest X-rays as normal or pneumonia. This comparison will provide valuable insights into the strengths and limitations of each approach, ultimately contributing to improved detection and diagnosis of pneumonia, which can enhance patient outcomes and survival rates.
#
# **Why did we choose this dataset?**
# We selected this dataset based on several factors. For more detailed information, please refer to the following:
# - The dataset is extensive, providing a large number of images suitable for evaluating and training deep learning models.
# - It aligns well with the project's objectives by offering a challenging and realistic scenario for developing an image classification model using deep learning, specifically for Chest X-ray images.
# - The dataset is annotated with images of two different diseases, enabling the development of a binary-class classification model.
# - It is publicly available, facilitating easy access for research and development purposes.
#
# **Size of dataset:**
# - Total images size = 1.27 GB
# - Dataset has 2 folders:
#   -  **Train:**
#     -  Normal (without Pneumonia) = 1349 images
#     -  Pneumonia = 3884 images
#   -  **Test:**
#     -  Normal (without Pneumonia) = 234 images
#     -  Pneumonia = 390 images
#
# **Expected Behaviors and Problem Handling:**
# - Classify Chest X-ray images with high accuracy.
# - Handle variations in image quality, resolution, and orientation.
# - Be robust to noise and artifacts in the images.
# - Provide interpretable results.
#
# **Issues to focus on:**
# - Improving model interpretability and explainability.
# - Optimizing model performance on a held-out test set.
# - Following AI Ethics and Data Safety practices.

# %% [markdown]
# # Import all the required files and libraries

# %%
import os
import ssl

# Disable SSL certificate verification
ssl._create_default_https_context = ssl._create_unverified_context

# Automatically reload imported modules when their source code changes
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# Import python files from local to use the corresponding function
from cxr_image_features_extraction import CxrImageFeatureExtraction

# %% [markdown]
# # Perform Chest X-ray Images Feature Extraction

# %% [markdown]
# ## Create an object of the Image Feature Extraction class

# %%
image_feature_extraction = CxrImageFeatureExtraction()

# %% [markdown]
# ## Fetch the absolute paths of the normalized image dataset

# %%
# Define the path to the dataset
dataset_path = image_feature_extraction.get_base_path_of_dataset() + "_nrm"
print(f"Normalized Dataset Path = {dataset_path}")

# Fetch train, test, NORMAL and PNEUMONIA folder names
train_folder_name = str(image_feature_extraction.train_test_image_dirs[0])
test_folder_name = str(image_feature_extraction.train_test_image_dirs[1])

normal_img_folder_name = str(image_feature_extraction.normal_pneumonia_image_dirs[0])
pneumonia_img_folder_name = str(image_feature_extraction.normal_pneumonia_image_dirs[1])

# Define the paths to the train and test datasets
# Train
train_normal = os.path.join(dataset_path, train_folder_name + "_nrm", normal_img_folder_name + "_nrm")
train_pneumonia = os.path.join(dataset_path, train_folder_name + "_nrm", pneumonia_img_folder_name + "_nrm")

# Test
test_normal = os.path.join(dataset_path, test_folder_name + "_nrm", normal_img_folder_name + "_nrm")
test_pneumonia = os.path.join(dataset_path, test_folder_name + "_nrm", pneumonia_img_folder_name + "_nrm")

# Print the paths to the train and test datasets
print("\nNormalized Train Images")
print("************************")
print(f"NORMAL = {train_normal}")
print(f"\nPNEUMONIA = {train_pneumonia}")

print("\n\nNormalized Test Images")
print("***************************")
print(f"NORMAL = {test_normal}")
print(f"\nPNEUMONIA = {test_pneumonia}")
# Out:
# Normalized Dataset Path = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm
#
# Normalized Train Images
# ************************
# NORMAL = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm
#
# PNEUMONIA = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm
#
#
# Normalized Test Images
# ***************************
# NORMAL = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm
#
# PNEUMONIA = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm

# %% [markdown]
# ## Convert all Normalized image folder absolute paths to a list

# %%
image_normalized_folders = [
    train_normal, train_pneumonia,
    test_normal, test_pneumonia
]

image_normalized_folders
# Out:
# ['/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm',
#  '/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm',
#  '/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm',
#  '/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm']

# %% [markdown]
# ### Extract First Order Features of all the images into an Excel file
#
# # First-Order Features Definitions and Formulas
#
# ## 1. Mean
# **Definition:** The average value of all pixel intensities in the image.
#
# **Formula:**
# $$ \text{Mean} = \frac{1}{N} \sum_{i=1}^{N} x_i $$
# where \( x_i \) is the pixel value and \( N \) is the total number of pixels.
#
# ## 2. Median
# **Definition:** The middle value of the sorted pixel intensities. If there is an even number of pixels, it is the average of the two middle values.
#
# **Formula:**
# If \( N \) is odd:
# $$ \text{Median} = x_{\left(\frac{N+1}{2}\right)} $$
# If \( N \) is even:
# $$ \text{Median} = \frac{x_{\left(\frac{N}{2}\right)} + x_{\left(\frac{N}{2}+1\right)}}{2} $$
#
# ## 3. Standard Deviation
# **Definition:** A measure of the spread or dispersion of pixel intensities from the mean.
#
# **Formula:**
# $$ \text{Standard Deviation} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} (x_i - \text{Mean})^2} $$
#
# ## 4. Variance
# **Definition:** The average of the squared differences from the mean, representing the spread of pixel intensities.
#
# **Formula:**
# $$ \text{Variance} = \frac{1}{N} \sum_{i=1}^{N} (x_i - \text{Mean})^2 $$
#
# ## 5. Skewness
# **Definition:** A measure of the asymmetry of the pixel intensity distribution around the mean.
#
# **Formula:**
# $$ \text{Skewness} = \frac{N}{(N-1)(N-2)} \sum_{i=1}^{N} \left(\frac{x_i - \text{Mean}}{\text{Standard Deviation}}\right)^3 $$
#
# ## 6. Kurtosis
# **Definition:** A measure of the "tailedness" of the pixel intensity distribution.
#
# **Formula:**
# $$ \text{Kurtosis} = \frac{N(N+1)}{(N-1)(N-2)(N-3)} \sum_{i=1}^{N} \left(\frac{x_i - \text{Mean}}{\text{Standard Deviation}}\right)^4 - \frac{3(N-1)^2}{(N-2)(N-3)} $$
#
# ## 7. Range
# **Definition:** The difference between the maximum and minimum pixel intensities in the image.
#
# **Formula:**
# $$ \text{Range} = \text{Max} - \text{Min} $$
#
# ## 8. Entropy
# **Definition:** A measure of the unpredictability or randomness of the pixel intensity values.
#
# **Formula:**
# $$ \text{Entropy} = -\sum_{i=1}^{k} p(x_i) \log_2 p(x_i) $$
# where \( p(x_i) \) is the probability of pixel intensity \( x_i \) and \( k \) is the number of unique pixel values.
#
# ## 9. Energy
# **Definition:** The sum of squared pixel values, indicating the overall intensity.
#
# **Formula:**
# $$ \text{Energy} = \sum_{i=1}^{N} x_i^2 $$
#
# ## 10. Uniformity
# **Definition:** A measure of the sum of squared normalized pixel values, indicating how similar the pixel values are.
#
# **Formula:**
# $$ \text{Uniformity} = \sum_{i=1}^{N} \left(\frac{x_i}{255}\right)^2 $$
#
# ## 11. Root Mean Square (RMS) Value
# **Definition:** The square root of the mean of the squared pixel values, providing a measure of pixel intensity magnitude.
#
# **Formula:**
# $$ \text{RMS} = \sqrt{\frac{1}{N} \sum_{i=1}^{N} x_i^2} $$
#
# ## 12. Maximum Pixel Value
# **Definition:** The highest pixel intensity value in the image.
#
# **Formula:**
# $$ \text{Max} = \max(x_i) $$
#
# ## 13. Minimum Pixel Value
# **Definition:** The lowest pixel intensity value in the image.
#
# **Formula:**
# $$ \text{Min} = \min(x_i) $$
#
# ## 14. Median Absolute Deviation (MAD)
# **Definition:** A measure of the variability of pixel intensities around the median, which is robust to outliers.
#
# **Formula:**
# $$ \text{MAD} = \text{Median}\left(\left|x_i - \text{Median}(x)\right|\right) $$
#
# ## 15. Interquartile Range (IQR)
# **Definition:** The range within which the central 50% of pixel values lie, representing the middle spread.
#
# **Formula:**
# $$ \text{IQR} = Q_3 - Q_1 $$
# where \( Q_3 \) is the third quartile and \( Q_1 \) is the first quartile of the pixel values.
#
# ## 16. Mean Absolute Deviation (MAD)
# **Definition:** The average of the absolute differences between each pixel value and the mean.
#
# **Formula:**
# $$ \text{Mean Absolute Deviation} = \frac{1}{N} \sum_{i=1}^{N} \left| x_i - \text{Mean} \right| $$

# %%
image_feature_extraction.update_first_order_features_to_excel_file(folders=image_normalized_folders)
# Out:
# Extracted First order features will be saved - /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_first_order_features.xlsx
#
#
# Extracting first-order features from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm
# Folder: train_nrm/NORMAL_nrm: 100%|████████████████████████████████████████████████| 1349/1349 [01:52<00:00, 11.98it/s]
# Extracting first-order features from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm
# Folder: train_nrm/PNEUMONIA_nrm: 100%|█████████████████████████████████████████████| 3883/3883 [02:33<00:00, 25.36it/s]
# Extracting first-order features from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm
# Folder: test_nrm/NORMAL_nrm: 100%|███████████████████████████████████████████████████| 234/234 [00:22<00:00, 10.53it/s]
# Extracting first-order features from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm
# Folder: test_nrm/PNEUMONIA_nrm: 100%|████████████████████████████████████████████████| 390/390 [00:13<00:00, 29.75it/s]
# All first-order features are extracted to the Excel file: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_first_order_features.xlsx
# Please check the Excel file for further analysis and interpretation

# %% [markdown]
# ### Extract Second Order GLCM Features of all the images and write into the existing Excel file
#
# # GLCM Features
#
# ## 1. Contrast
# $$
# \text{Contrast} = \sum_{i,j} (i - j)^2 \cdot P(i,j)
# $$
# **Definition**: Measure of intensity contrast between a pixel and its neighbor over the whole image.
#
# ## 2. Correlation
# $$
# \text{Correlation} = \frac{\sum_{i,j} (i \cdot j \cdot P(i,j) - \mu_x \cdot \mu_y)}{\sigma_x \cdot \sigma_y}
# $$
# **Definition**: Measure of how correlated a pixel is to its neighbor over the whole image.
#
# ## 3. Energy
# $$
# \text{Energy} = \sum_{i,j} P(i,j)^2
# $$
# **Definition**: Measure of the sum of squared elements in the GLCM.
#
# ## 4. Homogeneity
# $$
# \text{Homogeneity} = \sum_{i,j} \frac{P(i,j)}{1 + |i - j|}
# $$
# **Definition**: Measure of how close the distribution of elements in the GLCM is to the GLCM diagonal.
#
# ## 5. Dissimilarity
# $$
# \text{Dissimilarity} = \sum_{i,j} |i - j| \cdot P(i,j)
# $$
# **Definition**: Measure of the dissimilarity between a pixel and its neighbor.
#
# ## 6. Entropy
# $$
# \text{Entropy} = -\sum_{i} P(i) \log(P(i))
# $$
# **Definition**: Measure of randomness in the GLCM.
#
# ## 7. Auto-correlation
# $$
# \text{Auto-correlation} = \sum_{i,j} i \cdot j \cdot P(i,j)
# $$
# **Definition**: Measure of the correlation between a pixel and its neighbor.
#
# ## 8. Cluster Prominence
# $$
# \text{Cluster Prominence} = \sum_{i,j} (i + j - \mu_x - \mu_y)^4 \cdot P(i,j)
# $$
# **Definition**: Measure of the peakedness of the clusters in the GLCM.
#
# ## 9. Cluster Shade
# $$
# \text{Cluster Shade} = \sum_{i,j} (i + j - \mu_x - \mu_y)^3 \cdot P(i,j)
# $$
# **Definition**: Measure of the skewness of the clusters in the GLCM.
#
# ## 10. Maximum Probability
# $$
# \text{Maximum Probability} = \max(P(i,j))
# $$
# **Definition**: Measure of the maximum probability in the GLCM.
#
# ## 11. Sum of Squares (Variance)
# $$
# \text{Variance} = \frac{\sum_{i,j} (i - \mu)^2 \cdot P(i,j)}{\sum_{i,j} P(i,j)}
# $$
# **Definition**: Measure of the dispersion of elements in the GLCM.
#
# ## 12. Sum Average
# $$
# \text{Sum Average} = \sum_{i=2}^{2N} i \cdot P_{x+y}(i)
# $$
# **Definition**: Measure of the average of the sum of elements in the GLCM.
#
# ## 13. Sum Entropy
# $$
# \text{Sum Entropy} = -\sum_{i=2}^{2N} P_{x+y}(i) \log(P_{x+y}(i))
# $$
# **Definition**: Measure of the entropy of the sum of elements in the GLCM.
#
# ## 14. Sum Variance
# $$
# \text{Sum Variance} = \sum_{i=2}^{2N} (i - \text{Sum Average})^2 \cdot P_{x+y}(i)
# $$
# **Definition**: Measure of the variance of the sum of elements in the GLCM.
#
# ## 15. Difference Entropy
# $$
# \text{Difference Entropy} = -\sum_{i=0}^{N-1} P_{x-y}(i) \log(P_{x-y}(i))
# $$
# **Definition**: Measure of the entropy of the differences in the GLCM.
#
# ## 16. Difference Variance
# $$
# \text{Difference Variance} = \sum_{i=0}^{N-1} (i - \mu_{x-y})^2 \cdot P_{x-y}(i)
# $$
# **Definition**: Measure of the variance of the differences in the GLCM.

# %%
image_feature_extraction.update_second_order_glcm_features_to_excel_file(folders=image_normalized_folders)
# Out:
# Extracted GLCM features will be saved to - /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_glcm.xlsx
# Extracting second-order features GLCM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm
# Folder: train_nrm/NORMAL_nrm: 100%|████████████████████████████████████████████████| 1349/1349 [04:03<00:00,  5.54it/s]
# Extracting second-order features GLCM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm
# Folder: train_nrm/PNEUMONIA_nrm: 100%|█████████████████████████████████████████████| 3883/3883 [11:54<00:00,  5.43it/s]
# Extracting second-order features GLCM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm
# Folder: test_nrm/NORMAL_nrm: 100%|███████████████████████████████████████████████████| 234/234 [00:40<00:00,  5.73it/s]
# Extracting second-order features GLCM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm
# Folder: test_nrm/PNEUMONIA_nrm: 100%|████████████████████████████████████████████████| 390/390 [01:07<00:00,  5.82it/s]
# All first-order features are extracted to the Excel file: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_glcm.xlsx
# Please check the Excel file for further analysis and interpretation

# %% [markdown]
# ### Extract Second Order GLRLM Features of all the images and write into the existing Excel file
#
# 1. Short Run Emphasis (SRE)
#
# Definition: Measures the distribution of short runs in the image. Formula: $$\text{SRE} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j) \cdot j}$$ where $p(i,j)$ is the $(i,j)$th element of the GLRLM matrix, $G$ is the number of gray levels, and $R$ is the number of run lengths.
#
# 2. Long Run Emphasis (LRE)
#
# Definition: Measures the distribution of long runs in the image. Formula: $$\text{LRE} = \frac{\sum_{i=1}^{G} \sum_{j=R-1}^{R} p(i,j)}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 3. Gray Level Non-Uniformity (GLN)
#
# Definition: Measures the non-uniformity of gray levels in the image. Formula: $$\text{GLN} = \frac{\sum_{i=1}^{G} \left(\sum_{j=1}^{R} p(i,j)\right)^2}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 4. Run Length Non-Uniformity (RLN)
#
# Definition: Measures the non-uniformity of run lengths in the image. Formula: $$\text{RLN} = \frac{\sum_{j=1}^{R} \left(\sum_{i=1}^{G} p(i,j)\right)^2}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 5. Run Percentage (RP)
#
# Definition: Measures the percentage of runs in the image. Formula: $$\text{RP} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}{N}$$ where $N$ is the total number of pixels in the image.
#
# 6. Low Gray Level Run Emphasis (LGLRE)
#
# Definition: Measures the distribution of low gray level runs in the image. Formula: $$\text{LGLRE} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{R} \frac{p(i,j)}{i^2}}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 7. High Gray Level Run Emphasis (HGLRE)
#
# Definition: Measures the distribution of high gray level runs in the image. Formula: $$\text{HGLRE} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j) \cdot i^2}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 8. Short Run Low Gray Level Emphasis (SRLGLE)
#
# Definition: Measures the distribution of short runs with low gray levels in the image. Formula: $$\text{SRLGLE} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{2} \frac{p(i,j)}{i^2}}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 9. Short Run High Gray Level Emphasis (SRHGLE)
#
# Definition: Measures the distribution of short runs with high gray levels in the image. Formula: $$\text{SRHGLE} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{2} p(i,j) \cdot i^2}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 10. Long Run Low Gray Level Emphasis (LRLGLE)
#
# Definition: Measures the distribution of long runs with low gray levels in the image. Formula: $$\text{LRLGLE} = \frac{\sum_{i=1}^{G} \sum_{j=R-1}^{R} \frac{p(i,j)}{i^2}}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 11. Long Run High Gray Level Emphasis (LRHGLE)
#
# Definition: Measures the distribution of long runs with high gray levels in the image. Formula: $$\text{LRHGLE} = \frac{\sum_{i=1}^{G} \sum_{j=R-1}^{R} p(i,j) \cdot i^2}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$
#
# 12. Run Variance (RV)
#
# Definition: Measures the variance of run lengths in the image. Formula: $$\text{RV} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j) \cdot (j - \mu)^2}{\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j)}$$ where $\mu$ is the mean run length.
#
# 13. Run Entropy (RE)
#
# Definition: Measures the entropy of run lengths in the image. Formula: $$\text{RE} = -\sum_{i=1}^{G} \sum_{j=1}^{R} p(i,j) \cdot \log_2 p(i,j)$$
#
# 14. Difference Average (DA)
#
# Definition: Measures the average difference between gray levels in the image. Formula: $$\text{DA} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{G} p(i,j) \cdot |i-j|}{\sum_{i=1}^{G} \sum_{j=1}^{G} p(i,j)}$$
#
# 15. Difference Variance (DV)
#
# Definition: Measures the variance of differences between gray levels in the image. Formula: $$\text{DV} = \frac{\sum_{i=1}^{G} \sum_{j=1}^{G} p(i,j) \cdot (|i-j| - \mu)^2}{\sum_{i=1}^{G} \sum_{j=1}^{G} p(i,j)}$$ where $\mu$ is the mean difference.
#
# 16. Difference Entropy (DE)
#
# Definition: Measures the entropy of differences between gray levels in the image. Formula: $$\text{DE} = -\sum_{i=1}^{G} \sum_{j=1}^{G} p(i,j) \cdot \log_2 p(i,j)$$
#
# These features can be used to analyze the texture of an image and extract meaningful information from it.

# %%
image_feature_extraction.update_second_order_glrlm_features_to_excel_file(folders=image_normalized_folders)
# Out:
# Extracted GLRLM features will be saved to - /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_glrlm.xlsx
#
#
# Extracting second-order features GLRLM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm
# Folder: train_nrm/NORMAL_nrm:   0%|                                                           | 0/1349 [00:00<?, ?it/s]
# Folder: train_nrm/NORMAL_nrm:   1%|▌                                                 | 16/1349 [00:06<08:29,  2.61it/s]
# Folder: train_nrm/NORMAL_nrm:   2%|▉                                                 | 24/1349 [00:12<11:55,  1.85it/s]
# Folder: train_nrm/NORMAL_nrm:   2%|█▏                                                | 32/1349 [00:21<16:53,  1.30it/s]
# Folder: train_nrm/NORMAL_nrm:   3%|█▍                                                | 40/1349 [00:32<20:59,  1.04it/s]
# Folder: train_nrm/NORMAL_nrm:   4%|█▊                                                | 48/1349 [00:40<21:06,  1.03it/s]
# Folder: train_nrm/NORMAL_nrm:   4%|██                                                | 56/1349 [00:50<22:52,  1.06s/it]
# Folder: train_nrm/NORMAL_nrm:   5%|██▎                                               | 64/1349 [01:01<25:16,  1.18s/it]
# Folder: train_nrm/NORMAL_nrm:   5%|██▋                                               | 72/1349 [01:07<22:29,  1.06s/it]
# Folder: train_nrm/NORMAL_nrm:   6%|██▉                                               | 80/1349 [01:21<26:17,  1.24s/it]
# Folder: train_nrm/NORMAL_nrm:   7%|███▎                                              | 88/1349 [01:27<23:30,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:   7%|███▌                                              | 96/1349 [01:35<22:27,  1.08s/it]
# Folder: train_nrm/NORMAL_nrm:   8%|███▊                                             | 104/1349 [01:45<23:15,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:   8%|████                                             | 112/1349 [01:51<21:14,  1.03s/it]
# Folder: train_nrm/NORMAL_nrm:   9%|████▎                                            | 120/1349 [02:00<21:18,  1.04s/it]
# Folder: train_nrm/NORMAL_nrm:   9%|████▋                                            | 128/1349 [02:13<24:40,  1.21s/it]
# Folder: train_nrm/NORMAL_nrm:  10%|████▉                                            | 136/1349 [02:28<28:24,  1.41s/it]
# Folder: train_nrm/NORMAL_nrm:  11%|█████▏                                           | 144/1349 [02:38<27:24,  1.37s/it]
# Folder: train_nrm/NORMAL_nrm:  11%|█████▌                                           | 152/1349 [02:47<26:03,  1.31s/it]
# Folder: train_nrm/NORMAL_nrm:  12%|█████▊                                           | 160/1349 [02:55<23:43,  1.20s/it]
# Folder: train_nrm/NORMAL_nrm:  12%|██████                                           | 168/1349 [03:00<20:39,  1.05s/it]
# Folder: train_nrm/NORMAL_nrm:  13%|██████▍                                          | 176/1349 [03:11<22:19,  1.14s/it]
# Folder: train_nrm/NORMAL_nrm:  14%|██████▋                                          | 184/1349 [03:18<20:36,  1.06s/it]
# Folder: train_nrm/NORMAL_nrm:  14%|██████▉                                          | 192/1349 [03:28<21:18,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  15%|███████▎                                         | 200/1349 [03:38<22:05,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  15%|███████▌                                         | 208/1349 [03:46<20:44,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  16%|███████▊                                         | 216/1349 [03:58<22:50,  1.21s/it]
# Folder: train_nrm/NORMAL_nrm:  16%|███████▉                                         | 217/1349 [03:58<21:47,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  17%|████████▏                                        | 224/1349 [04:07<22:42,  1.21s/it]
# Folder: train_nrm/NORMAL_nrm:  17%|████████▍                                        | 232/1349 [04:17<22:41,  1.22s/it]
# Folder: train_nrm/NORMAL_nrm:  18%|████████▋                                        | 240/1349 [04:28<23:35,  1.28s/it]
# Folder: train_nrm/NORMAL_nrm:  18%|█████████                                        | 248/1349 [04:35<21:05,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  19%|█████████▎                                       | 256/1349 [04:42<19:36,  1.08s/it]
# Folder: train_nrm/NORMAL_nrm:  20%|█████████▌                                       | 264/1349 [04:52<20:14,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:  20%|█████████▉                                       | 272/1349 [05:04<22:30,  1.25s/it]
# Folder: train_nrm/NORMAL_nrm:  21%|██████████▏                                      | 280/1349 [05:16<23:33,  1.32s/it]
# Folder: train_nrm/NORMAL_nrm:  21%|██████████▍                                      | 288/1349 [05:24<21:49,  1.23s/it]
# Folder: train_nrm/NORMAL_nrm:  22%|██████████▊                                      | 296/1349 [05:31<19:28,  1.11s/it]
# Folder: train_nrm/NORMAL_nrm:  23%|███████████                                      | 304/1349 [05:46<23:02,  1.32s/it]
# Folder: train_nrm/NORMAL_nrm:  23%|███████████▎                                     | 312/1349 [05:58<24:02,  1.39s/it]
# Folder: train_nrm/NORMAL_nrm:  24%|███████████▌                                     | 320/1349 [06:07<22:37,  1.32s/it]
# Folder: train_nrm/NORMAL_nrm:  24%|███████████▉                                     | 328/1349 [06:16<21:25,  1.26s/it]
# Folder: train_nrm/NORMAL_nrm:  25%|████████████▏                                    | 336/1349 [06:28<22:04,  1.31s/it]
# Folder: train_nrm/NORMAL_nrm:  26%|████████████▍                                    | 344/1349 [06:40<22:50,  1.36s/it]
# Folder: train_nrm/NORMAL_nrm:  26%|████████████▊                                    | 352/1349 [06:49<21:47,  1.31s/it]
# Folder: train_nrm/NORMAL_nrm:  27%|█████████████                                    | 360/1349 [06:58<20:42,  1.26s/it]
# Folder: train_nrm/NORMAL_nrm:  27%|█████████████▎                                   | 368/1349 [07:09<21:22,  1.31s/it]
# Folder: train_nrm/NORMAL_nrm:  28%|█████████████▋                                   | 376/1349 [07:22<22:19,  1.38s/it]
# Folder: train_nrm/NORMAL_nrm:  28%|█████████████▉                                   | 384/1349 [07:34<23:02,  1.43s/it]
# Folder: train_nrm/NORMAL_nrm:  29%|██████████████▏                                  | 392/1349 [07:47<23:30,  1.47s/it]
# Folder: train_nrm/NORMAL_nrm:  30%|██████████████▌                                  | 400/1349 [07:56<21:48,  1.38s/it]
# Folder: train_nrm/NORMAL_nrm:  30%|██████████████▊                                  | 408/1349 [08:05<20:11,  1.29s/it]
# Folder: train_nrm/NORMAL_nrm:  31%|███████████████                                  | 416/1349 [08:18<21:36,  1.39s/it]
# Folder: train_nrm/NORMAL_nrm:  31%|███████████████▍                                 | 424/1349 [08:24<18:48,  1.22s/it]
# Folder: train_nrm/NORMAL_nrm:  32%|███████████████▋                                 | 432/1349 [08:30<16:35,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  33%|███████████████▉                                 | 440/1349 [08:40<16:57,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:  33%|████████████████▎                                | 448/1349 [08:50<17:15,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  34%|████████████████▌                                | 456/1349 [08:57<16:10,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  34%|████████████████▊                                | 464/1349 [09:07<16:23,  1.11s/it]
# Folder: train_nrm/NORMAL_nrm:  35%|█████████████████▏                               | 472/1349 [09:18<17:23,  1.19s/it]
# Folder: train_nrm/NORMAL_nrm:  36%|█████████████████▍                               | 480/1349 [09:27<16:56,  1.17s/it]
# Folder: train_nrm/NORMAL_nrm:  36%|█████████████████▋                               | 488/1349 [09:35<16:15,  1.13s/it]
# Folder: train_nrm/NORMAL_nrm:  37%|██████████████████                               | 496/1349 [09:44<16:02,  1.13s/it]
# Folder: train_nrm/NORMAL_nrm:  37%|██████████████████▎                              | 504/1349 [09:50<14:18,  1.02s/it]
# Folder: train_nrm/NORMAL_nrm:  38%|██████████████████▌                              | 512/1349 [10:01<15:50,  1.14s/it]
# Folder: train_nrm/NORMAL_nrm:  39%|██████████████████▉                              | 520/1349 [10:11<15:52,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  39%|███████████████████▏                             | 528/1349 [10:21<16:25,  1.20s/it]
# Folder: train_nrm/NORMAL_nrm:  40%|███████████████████▍                             | 536/1349 [10:34<17:44,  1.31s/it]
# Folder: train_nrm/NORMAL_nrm:  40%|███████████████████▊                             | 544/1349 [10:41<16:06,  1.20s/it]
# Folder: train_nrm/NORMAL_nrm:  41%|████████████████████                             | 552/1349 [10:48<14:34,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  42%|████████████████████▎                            | 560/1349 [10:57<14:31,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  42%|████████████████████▋                            | 568/1349 [11:08<15:06,  1.16s/it]
# Folder: train_nrm/NORMAL_nrm:  43%|████████████████████▉                            | 576/1349 [11:18<15:31,  1.21s/it]
# Folder: train_nrm/NORMAL_nrm:  43%|█████████████████████▏                           | 584/1349 [11:25<13:51,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  44%|█████████████████████▌                           | 592/1349 [11:31<12:48,  1.02s/it]
# Folder: train_nrm/NORMAL_nrm:  44%|█████████████████████▊                           | 600/1349 [11:40<12:53,  1.03s/it]
# Folder: train_nrm/NORMAL_nrm:  45%|██████████████████████                           | 608/1349 [11:45<11:09,  1.11it/s]
# Folder: train_nrm/NORMAL_nrm:  46%|██████████████████████▍                          | 616/1349 [11:57<13:25,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  46%|██████████████████████▋                          | 624/1349 [12:10<15:10,  1.26s/it]
# Folder: train_nrm/NORMAL_nrm:  47%|██████████████████████▉                          | 632/1349 [12:23<16:15,  1.36s/it]
# Folder: train_nrm/NORMAL_nrm:  47%|███████████████████████▏                         | 640/1349 [12:31<14:54,  1.26s/it]
# Folder: train_nrm/NORMAL_nrm:  48%|███████████████████████▌                         | 648/1349 [12:42<15:06,  1.29s/it]
# Folder: train_nrm/NORMAL_nrm:  49%|███████████████████████▊                         | 656/1349 [12:53<15:20,  1.33s/it]
# Folder: train_nrm/NORMAL_nrm:  49%|████████████████████████                         | 664/1349 [13:04<15:07,  1.32s/it]
# Folder: train_nrm/NORMAL_nrm:  50%|████████████████████████▍                        | 672/1349 [13:11<13:31,  1.20s/it]
# Folder: train_nrm/NORMAL_nrm:  50%|████████████████████████▋                        | 680/1349 [13:19<12:38,  1.13s/it]
# Folder: train_nrm/NORMAL_nrm:  51%|████████████████████████▉                        | 688/1349 [13:27<12:01,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  52%|█████████████████████████▎                       | 696/1349 [13:37<12:16,  1.13s/it]
# Folder: train_nrm/NORMAL_nrm:  52%|█████████████████████████▌                       | 704/1349 [13:45<11:52,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  53%|█████████████████████████▊                       | 712/1349 [13:59<13:33,  1.28s/it]
# Folder: train_nrm/NORMAL_nrm:  53%|██████████████████████████▏                      | 720/1349 [14:08<13:09,  1.25s/it]
# Folder: train_nrm/NORMAL_nrm:  54%|██████████████████████████▍                      | 728/1349 [14:19<13:07,  1.27s/it]
# Folder: train_nrm/NORMAL_nrm:  55%|██████████████████████████▋                      | 736/1349 [14:34<14:54,  1.46s/it]
# Folder: train_nrm/NORMAL_nrm:  55%|███████████████████████████                      | 744/1349 [14:44<14:02,  1.39s/it]
# Folder: train_nrm/NORMAL_nrm:  56%|███████████████████████████▎                     | 752/1349 [14:57<14:44,  1.48s/it]
# Folder: train_nrm/NORMAL_nrm:  56%|███████████████████████████▌                     | 760/1349 [15:08<14:10,  1.44s/it]
# Folder: train_nrm/NORMAL_nrm:  57%|███████████████████████████▉                     | 768/1349 [15:19<13:47,  1.42s/it]
# Folder: train_nrm/NORMAL_nrm:  58%|████████████████████████████▏                    | 776/1349 [15:28<12:40,  1.33s/it]
# Folder: train_nrm/NORMAL_nrm:  58%|████████████████████████████▍                    | 784/1349 [15:39<12:48,  1.36s/it]
# Folder: train_nrm/NORMAL_nrm:  59%|████████████████████████████▊                    | 792/1349 [15:53<13:30,  1.45s/it]
# Folder: train_nrm/NORMAL_nrm:  59%|█████████████████████████████                    | 800/1349 [15:59<11:30,  1.26s/it]
# Folder: train_nrm/NORMAL_nrm:  60%|█████████████████████████████▎                   | 808/1349 [16:08<10:48,  1.20s/it]
# Folder: train_nrm/NORMAL_nrm:  60%|█████████████████████████████▋                   | 816/1349 [16:15<09:56,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:  61%|█████████████████████████████▉                   | 824/1349 [16:24<09:56,  1.14s/it]
# Folder: train_nrm/NORMAL_nrm:  62%|██████████████████████████████▏                  | 832/1349 [16:36<10:29,  1.22s/it]
# Folder: train_nrm/NORMAL_nrm:  62%|██████████████████████████████▌                  | 840/1349 [16:42<09:13,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  63%|██████████████████████████████▊                  | 848/1349 [16:54<10:03,  1.21s/it]
# Folder: train_nrm/NORMAL_nrm:  63%|███████████████████████████████                  | 856/1349 [17:03<09:39,  1.17s/it]
# Folder: train_nrm/NORMAL_nrm:  64%|███████████████████████████████▍                 | 864/1349 [17:08<08:09,  1.01s/it]
# Folder: train_nrm/NORMAL_nrm:  65%|███████████████████████████████▋                 | 872/1349 [17:15<07:54,  1.01it/s]
# Folder: train_nrm/NORMAL_nrm:  65%|███████████████████████████████▉                 | 880/1349 [17:29<09:22,  1.20s/it]
# Folder: train_nrm/NORMAL_nrm:  66%|████████████████████████████████▎                | 888/1349 [17:38<09:10,  1.19s/it]
# Folder: train_nrm/NORMAL_nrm:  66%|████████████████████████████████▌                | 896/1349 [17:58<11:55,  1.58s/it]
# Folder: train_nrm/NORMAL_nrm:  67%|████████████████████████████████▊                | 904/1349 [18:10<11:21,  1.53s/it]
# Folder: train_nrm/NORMAL_nrm:  67%|████████████████████████████████▊                | 905/1349 [18:10<10:47,  1.46s/it]
# Folder: train_nrm/NORMAL_nrm:  68%|█████████████████████████████████▏               | 912/1349 [18:22<11:31,  1.58s/it]
# Folder: train_nrm/NORMAL_nrm:  68%|█████████████████████████████████▍               | 920/1349 [18:37<11:57,  1.67s/it]
# Folder: train_nrm/NORMAL_nrm:  69%|█████████████████████████████████▋               | 928/1349 [18:43<09:41,  1.38s/it]
# Folder: train_nrm/NORMAL_nrm:  69%|█████████████████████████████████▉               | 936/1349 [18:53<09:02,  1.31s/it]
# Folder: train_nrm/NORMAL_nrm:  70%|██████████████████████████████████▎              | 944/1349 [18:59<07:37,  1.13s/it]
# Folder: train_nrm/NORMAL_nrm:  71%|██████████████████████████████████▌              | 952/1349 [19:08<07:40,  1.16s/it]
# Folder: train_nrm/NORMAL_nrm:  71%|██████████████████████████████████▊              | 960/1349 [19:22<08:37,  1.33s/it]
# Folder: train_nrm/NORMAL_nrm:  72%|███████████████████████████████████▏             | 968/1349 [19:34<08:40,  1.37s/it]
# Folder: train_nrm/NORMAL_nrm:  72%|███████████████████████████████████▍             | 976/1349 [19:45<08:34,  1.38s/it]
# Folder: train_nrm/NORMAL_nrm:  73%|███████████████████████████████████▋             | 984/1349 [19:55<08:11,  1.35s/it]
# Folder: train_nrm/NORMAL_nrm:  74%|████████████████████████████████████             | 992/1349 [20:08<08:32,  1.43s/it]
# Folder: train_nrm/NORMAL_nrm:  74%|███████████████████████████████████▌            | 1000/1349 [20:19<08:12,  1.41s/it]
# Folder: train_nrm/NORMAL_nrm:  75%|███████████████████████████████████▊            | 1008/1349 [20:29<07:36,  1.34s/it]
# Folder: train_nrm/NORMAL_nrm:  75%|████████████████████████████████████▏           | 1016/1349 [20:39<07:20,  1.32s/it]
# Folder: train_nrm/NORMAL_nrm:  76%|████████████████████████████████████▍           | 1024/1349 [20:47<06:36,  1.22s/it]
# Folder: train_nrm/NORMAL_nrm:  77%|████████████████████████████████████▋           | 1032/1349 [20:55<06:07,  1.16s/it]
# Folder: train_nrm/NORMAL_nrm:  77%|█████████████████████████████████████           | 1040/1349 [21:03<05:48,  1.13s/it]
# Folder: train_nrm/NORMAL_nrm:  78%|█████████████████████████████████████▎          | 1048/1349 [21:13<05:51,  1.17s/it]
# Folder: train_nrm/NORMAL_nrm:  78%|█████████████████████████████████████▌          | 1056/1349 [21:22<05:38,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  79%|█████████████████████████████████████▊          | 1064/1349 [21:30<05:13,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  79%|██████████████████████████████████████▏         | 1072/1349 [21:45<06:11,  1.34s/it]
# Folder: train_nrm/NORMAL_nrm:  80%|██████████████████████████████████████▍         | 1080/1349 [21:55<05:46,  1.29s/it]
# Folder: train_nrm/NORMAL_nrm:  81%|██████████████████████████████████████▋         | 1088/1349 [22:04<05:22,  1.24s/it]
# Folder: train_nrm/NORMAL_nrm:  81%|██████████████████████████████████████▉         | 1096/1349 [22:14<05:22,  1.28s/it]
# Folder: train_nrm/NORMAL_nrm:  82%|███████████████████████████████████████▎        | 1104/1349 [22:20<04:33,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:  82%|███████████████████████████████████████▌        | 1112/1349 [22:29<04:21,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  83%|███████████████████████████████████████▊        | 1120/1349 [22:40<04:32,  1.19s/it]
# Folder: train_nrm/NORMAL_nrm:  84%|████████████████████████████████████████▏       | 1128/1349 [22:50<04:23,  1.19s/it]
# Folder: train_nrm/NORMAL_nrm:  84%|████████████████████████████████████████▍       | 1136/1349 [23:08<05:25,  1.53s/it]
# Folder: train_nrm/NORMAL_nrm:  85%|████████████████████████████████████████▋       | 1144/1349 [23:17<04:48,  1.41s/it]
# Folder: train_nrm/NORMAL_nrm:  85%|████████████████████████████████████████▉       | 1152/1349 [23:30<04:44,  1.44s/it]
# Folder: train_nrm/NORMAL_nrm:  86%|█████████████████████████████████████████▎      | 1160/1349 [23:37<04:06,  1.30s/it]
# Folder: train_nrm/NORMAL_nrm:  87%|█████████████████████████████████████████▌      | 1168/1349 [23:44<03:28,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  87%|█████████████████████████████████████████▊      | 1176/1349 [23:53<03:18,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  88%|██████████████████████████████████████████▏     | 1184/1349 [24:01<03:03,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:  88%|██████████████████████████████████████████▍     | 1192/1349 [24:10<02:53,  1.11s/it]
# Folder: train_nrm/NORMAL_nrm:  89%|██████████████████████████████████████████▋     | 1200/1349 [24:18<02:43,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  90%|██████████████████████████████████████████▉     | 1208/1349 [24:29<02:46,  1.18s/it]
# Folder: train_nrm/NORMAL_nrm:  90%|███████████████████████████████████████████▎    | 1216/1349 [24:39<02:37,  1.18s/it]
# Folder: train_nrm/NORMAL_nrm:  91%|███████████████████████████████████████████▌    | 1224/1349 [24:47<02:21,  1.14s/it]
# Folder: train_nrm/NORMAL_nrm:  91%|███████████████████████████████████████████▊    | 1232/1349 [24:53<01:58,  1.01s/it]
# Folder: train_nrm/NORMAL_nrm:  92%|████████████████████████████████████████████    | 1240/1349 [25:02<01:54,  1.05s/it]
# Folder: train_nrm/NORMAL_nrm:  93%|████████████████████████████████████████████▍   | 1248/1349 [25:13<01:55,  1.14s/it]
# Folder: train_nrm/NORMAL_nrm:  93%|████████████████████████████████████████████▋   | 1256/1349 [25:21<01:42,  1.11s/it]
# Folder: train_nrm/NORMAL_nrm:  94%|████████████████████████████████████████████▉   | 1264/1349 [25:30<01:33,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  94%|█████████████████████████████████████████████▎  | 1272/1349 [25:40<01:28,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  95%|█████████████████████████████████████████████▌  | 1280/1349 [25:51<01:24,  1.22s/it]
# Folder: train_nrm/NORMAL_nrm:  95%|█████████████████████████████████████████████▊  | 1288/1349 [25:57<01:06,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  96%|██████████████████████████████████████████████  | 1296/1349 [26:07<01:00,  1.15s/it]
# Folder: train_nrm/NORMAL_nrm:  97%|██████████████████████████████████████████████▍ | 1304/1349 [26:15<00:49,  1.10s/it]
# Folder: train_nrm/NORMAL_nrm:  97%|██████████████████████████████████████████████▋ | 1312/1349 [26:25<00:41,  1.12s/it]
# Folder: train_nrm/NORMAL_nrm:  98%|██████████████████████████████████████████████▉ | 1320/1349 [26:33<00:31,  1.09s/it]
# Folder: train_nrm/NORMAL_nrm:  98%|███████████████████████████████████████████████▎| 1328/1349 [26:41<00:22,  1.06s/it]
# Folder: train_nrm/NORMAL_nrm:  99%|███████████████████████████████████████████████▌| 1336/1349 [26:51<00:14,  1.14s/it]
# Folder: train_nrm/NORMAL_nrm: 100%|████████████████████████████████████████████████| 1349/1349 [26:57<00:00,  1.20s/it]
# Extracting second-order features GLRLM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm
# Folder: train_nrm/PNEUMONIA_nrm:   0%|                                                        | 0/3883 [00:00<?, ?it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   0%|▏                                              | 16/3883 [00:00<02:19, 27.81it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▎                                              | 24/3883 [00:02<07:40,  8.38it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▍                                              | 32/3883 [00:04<12:04,  5.32it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▍                                              | 40/3883 [00:08<18:53,  3.39it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▌                                              | 48/3883 [00:13<25:27,  2.51it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▋                                              | 56/3883 [00:16<25:24,  2.51it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▊                                              | 64/3883 [00:19<23:07,  2.75it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▊                                              | 72/3883 [00:21<21:44,  2.92it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▉                                              | 80/3883 [00:25<24:22,  2.60it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|█                                              | 88/3883 [00:30<28:02,  2.25it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|█▏                                             | 96/3883 [00:32<24:40,  2.56it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▏                                            | 104/3883 [00:34<22:57,  2.74it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▎                                            | 112/3883 [00:37<22:54,  2.74it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▍                                            | 120/3883 [00:39<21:39,  2.90it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▌                                            | 128/3883 [00:42<21:57,  2.85it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▌                                            | 136/3883 [00:45<20:38,  3.02it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▋                                            | 144/3883 [00:50<26:35,  2.34it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▊                                            | 152/3883 [00:53<25:49,  2.41it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▉                                            | 160/3883 [00:56<24:50,  2.50it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▉                                            | 168/3883 [00:59<23:58,  2.58it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██                                            | 176/3883 [01:03<26:40,  2.32it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▏                                           | 184/3883 [01:06<24:48,  2.49it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▎                                           | 192/3883 [01:08<22:53,  2.69it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▎                                           | 200/3883 [01:15<31:29,  1.95it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▍                                           | 208/3883 [01:18<29:43,  2.06it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▌                                           | 216/3883 [01:22<29:54,  2.04it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▋                                           | 224/3883 [01:27<31:36,  1.93it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▋                                           | 232/3883 [01:32<32:57,  1.85it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▊                                           | 240/3883 [01:35<30:49,  1.97it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▉                                           | 248/3883 [01:37<25:12,  2.40it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███                                           | 256/3883 [01:40<25:18,  2.39it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▏                                          | 264/3883 [01:43<24:49,  2.43it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▏                                          | 272/3883 [01:46<23:13,  2.59it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▎                                          | 280/3883 [01:49<23:12,  2.59it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▍                                          | 288/3883 [01:56<32:24,  1.85it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▌                                          | 296/3883 [02:00<30:24,  1.97it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▌                                          | 304/3883 [02:02<27:30,  2.17it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▋                                          | 312/3883 [02:06<27:39,  2.15it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▊                                          | 320/3883 [02:10<28:23,  2.09it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▉                                          | 328/3883 [02:13<25:11,  2.35it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|███▉                                          | 336/3883 [02:16<23:53,  2.47it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████                                          | 344/3883 [02:18<23:02,  2.56it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████▏                                         | 352/3883 [02:20<18:39,  3.15it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████▎                                         | 360/3883 [02:22<18:23,  3.19it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████▎                                         | 368/3883 [02:25<20:14,  2.89it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▍                                         | 376/3883 [02:28<19:22,  3.02it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▌                                         | 384/3883 [02:32<22:17,  2.62it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▋                                         | 392/3883 [02:36<24:12,  2.40it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▋                                         | 400/3883 [02:39<24:14,  2.40it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▊                                         | 408/3883 [02:42<23:15,  2.49it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▉                                         | 416/3883 [02:48<30:01,  1.92it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|█████                                         | 424/3883 [02:53<31:38,  1.82it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|█████                                         | 432/3883 [02:56<27:13,  2.11it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|█████▏                                        | 440/3883 [02:59<26:41,  2.15it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▎                                        | 448/3883 [03:02<24:43,  2.32it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▍                                        | 456/3883 [03:04<21:28,  2.66it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▍                                        | 464/3883 [03:06<18:49,  3.03it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▌                                        | 472/3883 [03:09<19:51,  2.86it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▋                                        | 480/3883 [03:11<17:57,  3.16it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▊                                        | 488/3883 [03:16<22:52,  2.47it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▉                                        | 496/3883 [03:19<22:57,  2.46it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▉                                        | 504/3883 [03:21<19:42,  2.86it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|██████                                        | 512/3883 [03:25<21:53,  2.57it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|██████▏                                       | 520/3883 [03:27<20:19,  2.76it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▎                                       | 528/3883 [03:30<19:18,  2.90it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▎                                       | 536/3883 [03:32<19:00,  2.93it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▍                                       | 544/3883 [03:36<20:25,  2.73it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▌                                       | 552/3883 [03:37<17:44,  3.13it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▋                                       | 560/3883 [03:41<19:17,  2.87it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▋                                       | 568/3883 [03:43<17:55,  3.08it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▊                                       | 576/3883 [03:46<19:02,  2.89it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▉                                       | 584/3883 [03:48<18:12,  3.02it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|███████                                       | 592/3883 [03:51<19:04,  2.88it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|███████                                       | 600/3883 [03:55<20:12,  2.71it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▏                                      | 608/3883 [03:57<19:17,  2.83it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▎                                      | 616/3883 [04:01<20:24,  2.67it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▍                                      | 624/3883 [04:03<18:31,  2.93it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▍                                      | 632/3883 [04:08<22:42,  2.39it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▌                                      | 640/3883 [04:10<21:09,  2.55it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▋                                      | 648/3883 [04:12<18:16,  2.95it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▊                                      | 656/3883 [04:16<21:55,  2.45it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▊                                      | 664/3883 [04:19<21:01,  2.55it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▉                                      | 672/3883 [04:21<18:30,  2.89it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|████████                                      | 680/3883 [04:25<20:34,  2.59it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|████████▏                                     | 688/3883 [04:28<21:16,  2.50it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|████████▏                                     | 696/3883 [04:30<18:52,  2.81it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|████████▎                                     | 704/3883 [04:35<21:56,  2.41it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|████████▍                                     | 712/3883 [04:38<21:58,  2.41it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▌                                     | 720/3883 [04:41<21:35,  2.44it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▌                                     | 728/3883 [04:44<20:32,  2.56it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▋                                     | 736/3883 [04:47<19:59,  2.62it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▊                                     | 744/3883 [04:50<20:24,  2.56it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▉                                     | 752/3883 [04:52<17:46,  2.94it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|█████████                                     | 760/3883 [04:55<18:03,  2.88it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|█████████                                     | 768/3883 [04:59<20:07,  2.58it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|█████████▏                                    | 776/3883 [05:02<20:19,  2.55it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|█████████▎                                    | 784/3883 [05:05<19:41,  2.62it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|█████████▍                                    | 792/3883 [05:09<21:46,  2.37it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▍                                    | 800/3883 [05:13<23:08,  2.22it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▌                                    | 808/3883 [05:16<21:17,  2.41it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▋                                    | 816/3883 [05:22<26:35,  1.92it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▊                                    | 824/3883 [05:27<28:43,  1.77it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▊                                    | 832/3883 [05:32<29:30,  1.72it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▉                                    | 840/3883 [05:38<31:51,  1.59it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|██████████                                    | 848/3883 [05:42<29:02,  1.74it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|██████████▏                                   | 856/3883 [05:44<24:28,  2.06it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|██████████▏                                   | 864/3883 [05:51<30:18,  1.66it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|██████████▎                                   | 872/3883 [05:57<31:40,  1.58it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▍                                   | 880/3883 [06:03<34:57,  1.43it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▌                                   | 888/3883 [06:06<30:05,  1.66it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▌                                   | 896/3883 [06:11<29:17,  1.70it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▋                                   | 904/3883 [06:13<24:54,  1.99it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▊                                   | 912/3883 [06:17<25:00,  1.98it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▉                                   | 920/3883 [06:22<26:38,  1.85it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▉                                   | 928/3883 [06:25<24:03,  2.05it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|███████████                                   | 936/3883 [06:28<21:30,  2.28it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|███████████▏                                  | 944/3883 [06:32<21:56,  2.23it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████▎                                  | 952/3883 [06:37<24:21,  2.01it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████▎                                  | 960/3883 [06:39<21:45,  2.24it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████▍                                  | 968/3883 [06:41<18:34,  2.62it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████▌                                  | 976/3883 [06:43<17:07,  2.83it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████▋                                  | 984/3883 [06:45<15:37,  3.09it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▊                                  | 992/3883 [06:48<14:49,  3.25it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▌                                 | 1000/3883 [06:50<14:25,  3.33it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▋                                 | 1008/3883 [06:52<13:05,  3.66it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▊                                 | 1016/3883 [06:54<13:39,  3.50it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▊                                 | 1024/3883 [06:58<15:53,  3.00it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▉                                 | 1032/3883 [06:59<14:24,  3.30it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|████████████                                 | 1040/3883 [07:05<18:58,  2.50it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|████████████▏                                | 1048/3883 [07:07<17:29,  2.70it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|████████████▏                                | 1056/3883 [07:08<14:50,  3.17it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|████████████▎                                | 1064/3883 [07:11<15:09,  3.10it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▍                                | 1072/3883 [07:14<15:55,  2.94it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▌                                | 1080/3883 [07:16<15:15,  3.06it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▌                                | 1088/3883 [07:19<15:50,  2.94it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▋                                | 1096/3883 [07:20<12:44,  3.65it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▊                                | 1104/3883 [07:23<12:49,  3.61it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▉                                | 1112/3883 [07:25<12:52,  3.59it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▉                                | 1120/3883 [07:29<15:37,  2.95it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|█████████████                                | 1128/3883 [07:34<19:01,  2.41it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|█████████████▏                               | 1136/3883 [07:40<24:21,  1.88it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|█████████████▎                               | 1144/3883 [07:44<23:03,  1.98it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████▎                               | 1152/3883 [07:49<24:50,  1.83it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████▍                               | 1160/3883 [07:52<23:08,  1.96it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████▌                               | 1168/3883 [07:54<19:56,  2.27it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████▋                               | 1176/3883 [07:57<19:17,  2.34it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████▋                               | 1184/3883 [08:00<17:18,  2.60it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▊                               | 1192/3883 [08:03<18:08,  2.47it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▉                               | 1200/3883 [08:08<20:01,  2.23it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▉                               | 1208/3883 [08:13<22:46,  1.96it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|██████████████                               | 1216/3883 [08:19<26:06,  1.70it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|██████████████▏                              | 1224/3883 [08:22<23:29,  1.89it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|██████████████▎                              | 1232/3883 [08:26<22:49,  1.94it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|██████████████▎                              | 1240/3883 [08:31<23:07,  1.90it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|██████████████▍                              | 1248/3883 [08:35<23:47,  1.85it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|██████████████▌                              | 1256/3883 [08:41<25:59,  1.68it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▋                              | 1264/3883 [08:44<22:47,  1.91it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▋                              | 1272/3883 [08:46<19:24,  2.24it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▊                              | 1280/3883 [08:49<18:38,  2.33it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▉                              | 1288/3883 [08:53<19:57,  2.17it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|███████████████                              | 1296/3883 [08:58<20:50,  2.07it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|███████████████                              | 1304/3883 [09:02<20:56,  2.05it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|███████████████▏                             | 1312/3883 [09:05<20:42,  2.07it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|███████████████▎                             | 1320/3883 [09:10<22:27,  1.90it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|███████████████▍                             | 1328/3883 [09:14<21:16,  2.00it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|███████████████▍                             | 1336/3883 [09:19<22:55,  1.85it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████▌                             | 1344/3883 [09:21<19:28,  2.17it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████▋                             | 1352/3883 [09:23<17:03,  2.47it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████▊                             | 1360/3883 [09:26<15:25,  2.73it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████▊                             | 1368/3883 [09:30<17:08,  2.44it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████▉                             | 1376/3883 [09:35<20:08,  2.07it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████                             | 1384/3883 [09:36<15:52,  2.62it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████▏                            | 1392/3883 [09:38<13:34,  3.06it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████▏                            | 1400/3883 [09:41<14:13,  2.91it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████▎                            | 1408/3883 [09:44<14:56,  2.76it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████▍                            | 1416/3883 [09:46<12:56,  3.18it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▌                            | 1424/3883 [09:48<12:47,  3.21it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▌                            | 1432/3883 [09:49<10:38,  3.84it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▋                            | 1440/3883 [09:50<09:30,  4.28it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▊                            | 1448/3883 [09:52<09:26,  4.30it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▊                            | 1456/3883 [09:55<10:37,  3.81it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|████████████████▉                            | 1464/3883 [09:58<12:30,  3.23it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|█████████████████                            | 1472/3883 [10:00<11:10,  3.60it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|█████████████████▏                           | 1480/3883 [10:01<09:36,  4.17it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|█████████████████▏                           | 1488/3883 [10:03<09:05,  4.39it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▎                           | 1496/3883 [10:06<10:41,  3.72it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▍                           | 1504/3883 [10:08<10:37,  3.73it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▌                           | 1512/3883 [10:12<13:57,  2.83it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▌                           | 1520/3883 [10:15<13:15,  2.97it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▋                           | 1528/3883 [10:17<13:04,  3.00it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|█████████████████▊                           | 1536/3883 [10:19<11:59,  3.26it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|█████████████████▉                           | 1544/3883 [10:22<12:00,  3.25it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|█████████████████▉                           | 1552/3883 [10:24<11:20,  3.43it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|██████████████████                           | 1560/3883 [10:27<13:20,  2.90it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|██████████████████▏                          | 1568/3883 [10:30<13:44,  2.81it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|██████████████████▎                          | 1576/3883 [10:37<19:37,  1.96it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|██████████████████▎                          | 1584/3883 [10:40<17:46,  2.16it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|██████████████████▍                          | 1592/3883 [10:42<15:10,  2.52it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|██████████████████▌                          | 1600/3883 [10:46<15:36,  2.44it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|██████████████████▋                          | 1608/3883 [10:48<14:35,  2.60it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|██████████████████▋                          | 1616/3883 [10:52<15:10,  2.49it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|██████████████████▊                          | 1624/3883 [10:56<16:12,  2.32it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|██████████████████▉                          | 1632/3883 [10:59<15:44,  2.38it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|███████████████████                          | 1640/3883 [11:01<14:16,  2.62it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|███████████████████                          | 1648/3883 [11:03<12:33,  2.97it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▏                         | 1656/3883 [11:07<13:43,  2.71it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▎                         | 1664/3883 [11:10<13:33,  2.73it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▍                         | 1672/3883 [11:12<13:13,  2.79it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▍                         | 1680/3883 [11:14<11:27,  3.20it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▌                         | 1688/3883 [11:16<10:18,  3.55it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  44%|███████████████████▋                         | 1696/3883 [11:18<09:59,  3.65it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  44%|███████████████████▋                         | 1704/3883 [11:20<10:25,  3.49it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  44%|███████████████████▊                         | 1712/3883 [11:23<10:50,  3.34it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  44%|███████████████████▉                         | 1720/3883 [11:25<10:05,  3.57it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  45%|████████████████████                         | 1728/3883 [11:26<09:03,  3.96it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  45%|████████████████████                         | 1736/3883 [11:28<08:10,  4.38it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  45%|████████████████████▏                        | 1744/3883 [11:29<07:53,  4.52it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  45%|████████████████████▎                        | 1752/3883 [11:32<08:23,  4.23it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  45%|████████████████████▍                        | 1760/3883 [11:34<09:04,  3.90it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  46%|████████████████████▍                        | 1768/3883 [11:36<08:28,  4.16it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  46%|████████████████████▌                        | 1776/3883 [11:36<07:05,  4.95it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  46%|████████████████████▋                        | 1784/3883 [11:39<07:51,  4.45it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  46%|████████████████████▊                        | 1792/3883 [11:41<08:03,  4.33it/s]
# ...
# Folder: train_nrm/PNEUMONIA_nrm:  90%|████████████████████████████████████████▍    | 3488/3883 [20:27<01:23,  4.72it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|████████████████████████████████████████▌    | 3496/3883 [20:29<01:19,  4.89it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|████████████████████████████████████████▌    | 3504/3883 [20:31<01:28,  4.30it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|████████████████████████████████████████▋    | 3512/3883 [20:33<01:27,  4.24it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|████████████████████████████████████████▊    | 3520/3883 [20:35<01:23,  4.33it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|████████████████████████████████████████▉    | 3528/3883 [20:38<01:33,  3.78it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|████████████████████████████████████████▉    | 3536/3883 [20:44<02:26,  2.37it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|█████████████████████████████████████████    | 3544/3883 [20:47<02:17,  2.46it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|█████████████████████████████████████████▏   | 3552/3883 [20:50<02:13,  2.47it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|█████████████████████████████████████████▎   | 3560/3883 [20:54<02:15,  2.38it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|█████████████████████████████████████████▎   | 3568/3883 [20:58<02:18,  2.27it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|█████████████████████████████████████████▍   | 3576/3883 [21:03<02:31,  2.03it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|█████████████████████████████████████████▌   | 3584/3883 [21:06<02:22,  2.10it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|█████████████████████████████████████████▋   | 3592/3883 [21:11<02:30,  1.94it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|█████████████████████████████████████████▋   | 3600/3883 [21:13<02:03,  2.29it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|█████████████████████████████████████████▊   | 3608/3883 [21:15<01:44,  2.63it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|█████████████████████████████████████████▉   | 3616/3883 [21:18<01:38,  2.71it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|█████████████████████████████████████████▉   | 3624/3883 [21:20<01:26,  3.01it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|██████████████████████████████████████████   | 3632/3883 [21:22<01:17,  3.22it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|██████████████████████████████████████████▏  | 3640/3883 [21:25<01:23,  2.91it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|██████████████████████████████████████████▎  | 3648/3883 [21:30<01:36,  2.44it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|██████████████████████████████████████████▎  | 3656/3883 [21:32<01:24,  2.69it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|██████████████████████████████████████████▍  | 3664/3883 [21:35<01:23,  2.62it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|██████████████████████████████████████████▌  | 3672/3883 [21:39<01:29,  2.36it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|██████████████████████████████████████████▋  | 3680/3883 [21:42<01:23,  2.42it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|██████████████████████████████████████████▋  | 3688/3883 [21:45<01:17,  2.52it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|██████████████████████████████████████████▊  | 3696/3883 [21:49<01:14,  2.50it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|██████████████████████████████████████████▉  | 3704/3883 [21:50<01:02,  2.88it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|███████████████████████████████████████████  | 3712/3883 [21:56<01:18,  2.18it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|███████████████████████████████████████████  | 3720/3883 [21:58<01:03,  2.57it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|███████████████████████████████████████████▏ | 3728/3883 [22:00<00:54,  2.85it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|███████████████████████████████████████████▎ | 3736/3883 [22:03<00:51,  2.88it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|███████████████████████████████████████████▍ | 3744/3883 [22:05<00:42,  3.23it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|███████████████████████████████████████████▍ | 3752/3883 [22:08<00:46,  2.83it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|███████████████████████████████████████████▌ | 3760/3883 [22:10<00:39,  3.11it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|███████████████████████████████████████████▋ | 3768/3883 [22:13<00:38,  2.96it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|███████████████████████████████████████████▊ | 3776/3883 [22:15<00:33,  3.23it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|███████████████████████████████████████████▊ | 3784/3883 [22:17<00:29,  3.32it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|███████████████████████████████████████████▉ | 3792/3883 [22:21<00:33,  2.73it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|████████████████████████████████████████████ | 3800/3883 [22:24<00:30,  2.73it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|████████████████████████████████████████████▏| 3808/3883 [22:27<00:25,  2.95it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|████████████████████████████████████████████▏| 3816/3883 [22:30<00:25,  2.68it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|████████████████████████████████████████████▎| 3824/3883 [22:32<00:19,  2.97it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|████████████████████████████████████████████▍| 3832/3883 [22:35<00:16,  3.09it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|████████████████████████████████████████████▌| 3840/3883 [22:39<00:17,  2.47it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|████████████████████████████████████████████▌| 3848/3883 [22:42<00:13,  2.65it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|████████████████████████████████████████████▋| 3856/3883 [22:46<00:11,  2.40it/s]
# Folder: train_nrm/PNEUMONIA_nrm: 100%|████████████████████████████████████████████▊| 3864/3883 [22:49<00:07,  2.39it/s]
# Folder: train_nrm/PNEUMONIA_nrm: 100%|████████████████████████████████████████████▊| 3872/3883 [22:52<00:04,  2.44it/s]
# Folder: train_nrm/PNEUMONIA_nrm: 100%|█████████████████████████████████████████████| 3883/3883 [22:54<00:00,  2.82it/s]
# Extracting second-order features GLRLM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm
# Folder: test_nrm/NORMAL_nrm:   0%|                                                             | 0/234 [00:00<?, ?it/s]
# Folder: test_nrm/NORMAL_nrm:   7%|███▌                                                | 16/234 [00:02<00:31,  6.86it/s]
# Folder: test_nrm/NORMAL_nrm:  10%|█████▎                                              | 24/234 [00:06<01:05,  3.19it/s]
# Folder: test_nrm/NORMAL_nrm:  14%|███████                                             | 32/234 [00:11<01:20,  2.52it/s]
# Folder: test_nrm/NORMAL_nrm:  17%|████████▉                                           | 40/234 [00:17<01:44,  1.86it/s]
# Folder: test_nrm/NORMAL_nrm:  21%|██████████▋                                         | 48/234 [00:23<01:50,  1.68it/s]
# Folder: test_nrm/NORMAL_nrm:  24%|████████████▍                                       | 56/234 [00:27<01:43,  1.71it/s]
# Folder: test_nrm/NORMAL_nrm:  27%|██████████████▏                                     | 64/234 [00:32<01:41,  1.68it/s]
# Folder: test_nrm/NORMAL_nrm:  31%|████████████████                                    | 72/234 [00:38<01:43,  1.57it/s]
# Folder: test_nrm/NORMAL_nrm:  34%|█████████████████▊                                  | 80/234 [00:42<01:34,  1.62it/s]
# Folder: test_nrm/NORMAL_nrm:  38%|███████████████████▌                                | 88/234 [00:56<02:17,  1.06it/s]
# Folder: test_nrm/NORMAL_nrm:  41%|█████████████████████▎                              | 96/234 [01:10<02:41,  1.17s/it]
# Folder: test_nrm/NORMAL_nrm:  44%|██████████████████████▋                            | 104/234 [01:29<03:21,  1.55s/it]
# Folder: test_nrm/NORMAL_nrm:  48%|████████████████████████▍                          | 112/234 [01:53<04:03,  2.00s/it]
# Folder: test_nrm/NORMAL_nrm:  51%|██████████████████████████▏                        | 120/234 [02:10<03:53,  2.04s/it]
# Folder: test_nrm/NORMAL_nrm:  55%|███████████████████████████▉                       | 128/234 [02:20<03:11,  1.80s/it]
# Folder: test_nrm/NORMAL_nrm:  58%|█████████████████████████████▋                     | 136/234 [02:26<02:24,  1.47s/it]
# Folder: test_nrm/NORMAL_nrm:  62%|███████████████████████████████▍                   | 144/234 [02:31<01:50,  1.22s/it]
# Folder: test_nrm/NORMAL_nrm:  65%|█████████████████████████████████▏                 | 152/234 [02:34<01:19,  1.03it/s]
# Folder: test_nrm/NORMAL_nrm:  68%|██████████████████████████████████▊                | 160/234 [02:38<00:59,  1.24it/s]
# Folder: test_nrm/NORMAL_nrm:  72%|████████████████████████████████████▌              | 168/234 [02:44<00:52,  1.26it/s]
# Folder: test_nrm/NORMAL_nrm:  75%|██████████████████████████████████████▎            | 176/234 [02:48<00:41,  1.40it/s]
# Folder: test_nrm/NORMAL_nrm:  79%|████████████████████████████████████████           | 184/234 [02:57<00:42,  1.18it/s]
# Folder: test_nrm/NORMAL_nrm:  82%|█████████████████████████████████████████▊         | 192/234 [03:04<00:35,  1.19it/s]
# Folder: test_nrm/NORMAL_nrm:  85%|███████████████████████████████████████████▌       | 200/234 [03:10<00:28,  1.21it/s]
# Folder: test_nrm/NORMAL_nrm:  89%|█████████████████████████████████████████████▎     | 208/234 [03:17<00:21,  1.19it/s]
# Folder: test_nrm/NORMAL_nrm:  92%|███████████████████████████████████████████████    | 216/234 [03:25<00:15,  1.14it/s]
# Folder: test_nrm/NORMAL_nrm:  96%|████████████████████████████████████████████████▊  | 224/234 [03:32<00:08,  1.13it/s]
# Folder: test_nrm/NORMAL_nrm: 100%|███████████████████████████████████████████████████| 234/234 [03:36<00:00,  1.08it/s]
# Extracting second-order features GLRLM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm
# Folder: test_nrm/PNEUMONIA_nrm:   0%|                                                          | 0/390 [00:00<?, ?it/s]
# Folder: test_nrm/PNEUMONIA_nrm:   4%|██                                               | 16/390 [00:00<00:09, 39.48it/s]
# Folder: test_nrm/PNEUMONIA_nrm:   6%|███                                              | 24/390 [00:01<00:18, 19.27it/s]
# Folder: test_nrm/PNEUMONIA_nrm:   8%|████                                             | 32/390 [00:02<00:31, 11.47it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  10%|█████                                            | 40/390 [00:03<00:43,  8.01it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  12%|██████                                           | 48/390 [00:06<01:11,  4.80it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  14%|███████                                          | 56/390 [00:08<01:12,  4.61it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  16%|████████                                         | 64/390 [00:11<01:20,  4.05it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  18%|█████████                                        | 72/390 [00:14<01:36,  3.31it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  21%|██████████                                       | 80/390 [00:16<01:24,  3.67it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  23%|███████████                                      | 88/390 [00:18<01:22,  3.65it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  25%|████████████                                     | 96/390 [00:19<01:11,  4.10it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  27%|████████████▊                                   | 104/390 [00:22<01:16,  3.76it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  29%|█████████████▊                                  | 112/390 [00:24<01:12,  3.82it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  31%|██████████████▊                                 | 120/390 [00:26<01:07,  4.01it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  33%|███████████████▊                                | 128/390 [00:28<01:04,  4.04it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  35%|████████████████▋                               | 136/390 [00:29<00:54,  4.69it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  37%|█████████████████▋                              | 144/390 [00:30<00:49,  4.93it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  39%|██████████████████▋                             | 152/390 [00:32<00:50,  4.72it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  41%|███████████████████▋                            | 160/390 [00:35<00:56,  4.10it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  43%|████████████████████▋                           | 168/390 [00:37<00:56,  3.95it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  45%|█████████████████████▋                          | 176/390 [00:39<00:57,  3.74it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  47%|██████████████████████▋                         | 184/390 [00:42<00:57,  3.60it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  49%|███████████████████████▋                        | 192/390 [00:44<00:57,  3.44it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  51%|████████████████████████▌                       | 200/390 [00:47<01:01,  3.08it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  53%|█████████████████████████▌                      | 208/390 [00:51<01:06,  2.74it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  55%|██████████████████████████▌                     | 216/390 [00:54<01:01,  2.82it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  57%|███████████████████████████▌                    | 224/390 [00:57<00:58,  2.82it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  59%|████████████████████████████▌                   | 232/390 [01:00<01:02,  2.53it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  62%|█████████████████████████████▌                  | 240/390 [01:03<00:57,  2.59it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  64%|██████████████████████████████▌                 | 248/390 [01:08<01:02,  2.29it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  66%|███████████████████████████████▌                | 256/390 [01:11<00:56,  2.36it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  68%|████████████████████████████████▍               | 264/390 [01:15<00:55,  2.28it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  70%|█████████████████████████████████▍              | 272/390 [01:16<00:43,  2.73it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  72%|██████████████████████████████████▍             | 280/390 [01:20<00:44,  2.48it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  74%|███████████████████████████████████▍            | 288/390 [01:23<00:39,  2.60it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████████▍           | 296/390 [01:26<00:36,  2.55it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████████▍          | 304/390 [01:29<00:33,  2.56it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████████▍         | 312/390 [01:33<00:32,  2.41it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████████▍        | 320/390 [01:35<00:26,  2.64it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████████▎       | 328/390 [01:39<00:23,  2.64it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  86%|█████████████████████████████████████████▎      | 336/390 [01:40<00:17,  3.05it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  88%|██████████████████████████████████████████▎     | 344/390 [01:42<00:13,  3.54it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  90%|███████████████████████████████████████████▎    | 352/390 [01:44<00:11,  3.40it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  92%|████████████████████████████████████████████▎   | 360/390 [01:45<00:07,  4.03it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  94%|█████████████████████████████████████████████▎  | 368/390 [01:47<00:05,  4.02it/s]
# Folder: test_nrm/PNEUMONIA_nrm:  96%|██████████████████████████████████████████████▎ | 376/390 [01:49<00:03,  4.44it/s]
# Folder: test_nrm/PNEUMONIA_nrm: 100%|████████████████████████████████████████████████| 390/390 [01:50<00:00,  3.52it/s]
# All first-order features are extracted to the Excel file: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_glrlm.xlsx
# Please check the Excel file for further analysis and interpretation

# %% [markdown]
# ### GLDM Features
#
# The following GLDM (Gray Level Dependence Matrix) features are extracted from the given image:
#
# #### 1. Small Dependence Emphasis (SDE)
#
# *Definition:* Measures the distribution of small dependencies in the image.
# *Formula:* $$\text{SDE} = \frac{\sum_{i=0}^{1} \sum_{j=0}^{G-1} p(i,j)}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 2. Large Dependence Emphasis (LDE)
#
# *Definition:* Measures the distribution of large dependencies in the image.
# *Formula:* $$\text{LDE} = \frac{\sum_{i=G-2}^{G-1} \sum_{j=0}^{G-1} p(i,j)}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 3. Gray Level Non-Uniformity (GLN)
#
# *Definition:* Measures the non-uniformity of gray levels in the image.
# *Formula:* $$\text{GLN} = \frac{\sum_{i=0}^{G-1} (\sum_{j=0}^{G-1} p(i,j))^2}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 4. Dependence Count Non-Uniformity (DCN)
#
# *Definition:* Measures the non-uniformity of dependence counts in the image.
# *Formula:* $$\text{DCN} = \frac{\sum_{j=0}^{G-1} (\sum_{i=0}^{G-1} p(i,j))^2}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 5. Dependence Count Entropy (DCE)
#
# *Definition:* Measures the entropy of dependence counts in the image.
# *Formula:* $$\text{DCE} = -\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j) \log_2 p(i,j)$$
#
# #### 6. Gray Level Entropy (GLE)
#
# *Definition:* Measures the entropy of gray levels in the image.
# *Formula:* $$\text{GLE} = -\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j) \log_2 p(i,j)$$
#
# #### 7. Dependence Count Mean (DCM)
#
# *Definition:* Measures the mean of dependence counts in the image.
# *Formula:* $$\text{DCM} = \frac{\sum_{j=0}^{G-1} \sum_{i=0}^{G-1} p(i,j) \cdot j}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 8. Gray Level Mean (GLM)
#
# *Definition:* Measures the mean of gray levels in the image.
# *Formula:* $$\text{GLM} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j) \cdot i}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 9. Dependence Count Variance (DCV)
#
# *Definition:* Measures the variance of dependence counts in the image.
# *Formula:* $$\text{DCV} = \frac{\sum_{j=0}^{G-1} (\sum_{i=0}^{G-1} p(i,j) \cdot j - \text{DCM})^2}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 10. Gray Level Variance (GLV)
#
# *Definition:* Measures the variance of gray levels in the image.
# *Formula:* $$\text{GLV} = \frac{\sum_{i=0}^{G-1} (\sum_{j=0}^{G-1} p(i,j) \cdot i - \text{GLM})^2}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)}$$
#
# #### 11. Dependence Count Energy (DCE)
#
# *Definition:* Measures the energy of dependence counts in the image.
# *Formula:* $$\text{DCE} = \sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)^2$$
#
# #### 12. Gray Level Energy (GLE)
#
# *Definition:* Measures the energy of gray levels in the image.
# *Formula:* $$\text{GLE} = \sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)^2$$
#
# #### 13. Dependence Count Maximum (DCM)
#
# *Definition:* Measures the maximum dependence count in the image.
# *Formula:* $$\text{DCM} = \max_{j=0}^{G-1} \sum_{i=0}^{G-1} p(i,j)$$
#
# #### 14. Gray Level Maximum (GLM)
#
# *Definition:* Measures the maximum gray level in the image.
# *Formula:* $$\text{GLM} = \max_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)$$
#
# #### 15. Dependence Count Contrast (DCC)
#
# *Definition:* Measures the contrast of dependence counts in the image.
# *Formula:* $$\text{DCC} = \sum_{i=0}^{G-1} \sum_{j=0}^{G-1} |i-j| \cdot p(i,j)$$
#
# #### 16. Gray Level Contrast (GLC)
#
# *Definition:* Measures the contrast of gray levels in the image.
# *Formula:* $$\text{GLC} = \sum_{i=0}^{G-1} \sum_{j=0}^{G-1} |i-j| \cdot p(i,j)$$
#
# #### 17. Dependence Count Correlation (DCC)
#
# *Definition:* Measures the correlation of dependence counts in the image.
# *Formula:* $$\text{DCC} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} (i-\mu_i)(j-\mu_j) \cdot p(i,j)}{\sigma_i \sigma_j}$$
#
# #### 18. Gray Level Correlation (GLC)
#
# *Definition:* Measures the correlation of gray levels in the image.
# *Formula:* $$\text{GLC} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} (i-\mu_i)(j-\mu_j) \cdot p(i,j)}{\sigma_i \sigma_j}$$
#
# #### 19. Dependence Count Homogeneity (DCH)
#
# *Definition:* Measures the homogeneity of dependence counts in the image.
# *Formula:* $$\text{DCH} = \sum_{i=0}^{G-1} \sum_{j=0}^{G-1} \frac{p(i,j)}{1+|i-j|}$$
#
# #### 20. Gray Level Homogeneity (GLH)
#
# *Definition:* Measures the homogeneity of gray levels in the image.
# *Formula:* $$\text{GLH} = \sum_{i=0}^{G-1} \sum_{j=0}^{G-1} \frac{p(i,j)}{1+|i-j|}$$
#
# #### 21. Dependence Count Sum (DCS)
#
# *Definition:* Measures the sum of dependence counts in the image.
# *Formula:* $$\text{DCS} = \sum_{j=0}^{G-1} \sum_{i=0}^{G-1} p(i,j)$$
#
# #### 22. Gray Level Sum (GLS)
#
# *Definition:* Measures the sum of gray levels in the image.
# *Formula:* $$\text{GLS} = \sum_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)$$
#
# #### 23. Dependence Count Range (DCR)
#
# *Definition:* Measures the range of dependence counts in the image.
# *Formula:* $$\text{DCR} = \max_{j=0}^{G-1} \sum_{i=0}^{G-1} p(i,j) - \min_{j=0}^{G-1} \sum_{i=0}^{G-1} p(i,j)$$
#
# 24. Gray Level Range (GLR)
#
# Definition: Measures the range of gray levels in the image. Formula: $$\text{GLR} = \max_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j) - \min_{i=0}^{G-1} \sum_{j=0}^{G-1} p(i,j)$$
#
# Where $G$ is the maximum gray level in the image, and $p(i,j)$ is the probability of occurrence of gray level $i$ and its neighboring gray level $j$ in the image.

# %%
image_feature_extraction.update_second_order_gldm_features_to_excel_file(folders=image_normalized_folders)
# Out:
# Extracted GLDM features will be saved to - /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_gldm.xlsx
#
#
# Extracting second-order features GLDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm
# Folder: train_nrm/NORMAL_nrm:   0%|                                                           | 0/1349 [00:00<?, ?it/s]
# Folder: train_nrm/NORMAL_nrm:   1%|▎                                                  | 8/1349 [00:00<00:16, 79.08it/s]
# Folder: train_nrm/NORMAL_nrm:   1%|▎                                                  | 8/1349 [00:16<00:16, 79.08it/s]
# Folder: train_nrm/NORMAL_nrm:   1%|▌                                                 | 16/1349 [00:21<35:19,  1.59s/it]
# Folder: train_nrm/NORMAL_nrm:   2%|▉                                                 | 24/1349 [00:40<43:27,  1.97s/it]
# Folder: train_nrm/NORMAL_nrm:   2%|█▏                                                | 32/1349 [01:04<51:25,  2.34s/it]
# Folder: train_nrm/NORMAL_nrm:   3%|█▍                                              | 40/1349 [01:32<1:00:34,  2.78s/it]
# Folder: train_nrm/NORMAL_nrm:   4%|█▋                                              | 48/1349 [02:05<1:10:16,  3.24s/it]
# Folder: train_nrm/NORMAL_nrm:   4%|█▉                                              | 56/1349 [02:40<1:17:11,  3.58s/it]
# Folder: train_nrm/NORMAL_nrm:   5%|██▎                                             | 64/1349 [02:56<1:05:50,  3.07s/it]
# Folder: train_nrm/NORMAL_nrm:   5%|██▌                                             | 72/1349 [03:25<1:09:19,  3.26s/it]
# Folder: train_nrm/NORMAL_nrm:   6%|██▊                                             | 80/1349 [03:51<1:09:04,  3.27s/it]
# Folder: train_nrm/NORMAL_nrm:   7%|███▏                                            | 88/1349 [04:15<1:07:11,  3.20s/it]
# Folder: train_nrm/NORMAL_nrm:   7%|███▍                                            | 96/1349 [04:42<1:07:57,  3.25s/it]
# Folder: train_nrm/NORMAL_nrm:   8%|███▌                                           | 104/1349 [05:12<1:10:21,  3.39s/it]
# Folder: train_nrm/NORMAL_nrm:   8%|███▉                                           | 112/1349 [05:33<1:05:22,  3.17s/it]
# Folder: train_nrm/NORMAL_nrm:   9%|████▏                                          | 120/1349 [06:04<1:08:38,  3.35s/it]
# Folder: train_nrm/NORMAL_nrm:   9%|████▍                                          | 128/1349 [06:33<1:09:59,  3.44s/it]
# Folder: train_nrm/NORMAL_nrm:  10%|████▋                                          | 136/1349 [07:02<1:10:47,  3.50s/it]
# Folder: train_nrm/NORMAL_nrm:  11%|█████                                          | 144/1349 [07:19<1:02:23,  3.11s/it]
# Folder: train_nrm/NORMAL_nrm:  11%|█████▎                                         | 152/1349 [07:42<1:00:00,  3.01s/it]
# Folder: train_nrm/NORMAL_nrm:  12%|█████▌                                         | 160/1349 [08:07<1:00:45,  3.07s/it]
# Folder: train_nrm/NORMAL_nrm:  12%|█████▊                                         | 168/1349 [08:32<1:00:22,  3.07s/it]
# Folder: train_nrm/NORMAL_nrm:  13%|██████▏                                        | 176/1349 [08:58<1:01:03,  3.12s/it]
# Folder: train_nrm/NORMAL_nrm:  14%|██████▋                                          | 184/1349 [09:17<56:09,  2.89s/it]
# Folder: train_nrm/NORMAL_nrm:  14%|██████▉                                          | 192/1349 [09:43<58:20,  3.03s/it]
# Folder: train_nrm/NORMAL_nrm:  15%|██████▉                                        | 200/1349 [10:12<1:00:45,  3.17s/it]
# Folder: train_nrm/NORMAL_nrm:  15%|███████▌                                         | 208/1349 [10:35<59:20,  3.12s/it]
# Folder: train_nrm/NORMAL_nrm:  15%|███████▌                                         | 209/1349 [10:36<56:22,  2.97s/it]
# Folder: train_nrm/NORMAL_nrm:  15%|███████▌                                         | 209/1349 [10:47<56:22,  2.97s/it]
# Folder: train_nrm/NORMAL_nrm:  16%|███████▊                                         | 216/1349 [10:59<58:10,  3.08s/it]
# Folder: train_nrm/NORMAL_nrm:  17%|████████▏                                        | 224/1349 [11:25<58:42,  3.13s/it]
# Folder: train_nrm/NORMAL_nrm:  17%|████████                                       | 232/1349 [11:53<1:01:14,  3.29s/it]
# Folder: train_nrm/NORMAL_nrm:  18%|████████▋                                        | 240/1349 [12:18<59:53,  3.24s/it]
# Folder: train_nrm/NORMAL_nrm:  18%|████████▋                                      | 248/1349 [12:52<1:05:20,  3.56s/it]
# Folder: train_nrm/NORMAL_nrm:  19%|████████▉                                      | 256/1349 [13:14<1:00:07,  3.30s/it]
# Folder: train_nrm/NORMAL_nrm:  20%|█████████▏                                     | 264/1349 [13:43<1:01:33,  3.40s/it]
# Folder: train_nrm/NORMAL_nrm:  20%|█████████▍                                     | 272/1349 [14:20<1:07:50,  3.78s/it]
# Folder: train_nrm/NORMAL_nrm:  21%|█████████▊                                     | 280/1349 [14:51<1:07:42,  3.80s/it]
# Folder: train_nrm/NORMAL_nrm:  21%|██████████                                     | 288/1349 [15:21<1:06:30,  3.76s/it]
# Folder: train_nrm/NORMAL_nrm:  22%|██████████▎                                    | 296/1349 [15:43<1:01:02,  3.48s/it]
# Folder: train_nrm/NORMAL_nrm:  23%|██████████▌                                    | 304/1349 [16:11<1:00:54,  3.50s/it]
# Folder: train_nrm/NORMAL_nrm:  23%|██████████▊                                    | 312/1349 [16:50<1:07:27,  3.90s/it]
# Folder: train_nrm/NORMAL_nrm:  24%|███████████▌                                     | 320/1349 [17:10<59:44,  3.48s/it]
# Folder: train_nrm/NORMAL_nrm:  24%|███████████▍                                   | 328/1349 [17:44<1:02:44,  3.69s/it]
# Folder: train_nrm/NORMAL_nrm:  25%|████████████▏                                    | 336/1349 [18:07<58:05,  3.44s/it]
# Folder: train_nrm/NORMAL_nrm:  25%|████████████▏                                    | 337/1349 [18:07<55:10,  3.27s/it]
# Folder: train_nrm/NORMAL_nrm:  25%|████████████▏                                    | 337/1349 [18:17<55:10,  3.27s/it]
# Folder: train_nrm/NORMAL_nrm:  26%|███████████▉                                   | 344/1349 [18:38<1:01:51,  3.69s/it]
# Folder: train_nrm/NORMAL_nrm:  26%|████████████▎                                  | 352/1349 [19:18<1:09:05,  4.16s/it]
# Folder: train_nrm/NORMAL_nrm:  27%|████████████▌                                  | 360/1349 [19:40<1:00:42,  3.68s/it]
# Folder: train_nrm/NORMAL_nrm:  27%|████████████▊                                  | 368/1349 [20:10<1:00:35,  3.71s/it]
# Folder: train_nrm/NORMAL_nrm:  28%|█████████████                                  | 376/1349 [20:42<1:01:18,  3.78s/it]
# Folder: train_nrm/NORMAL_nrm:  28%|█████████████▉                                   | 384/1349 [21:09<59:02,  3.67s/it]
# Folder: train_nrm/NORMAL_nrm:  29%|██████████████▏                                  | 392/1349 [21:30<53:24,  3.35s/it]
# Folder: train_nrm/NORMAL_nrm:  30%|██████████████▌                                  | 400/1349 [22:05<57:44,  3.65s/it]
# Folder: train_nrm/NORMAL_nrm:  30%|██████████████▊                                  | 408/1349 [22:36<58:32,  3.73s/it]
# Folder: train_nrm/NORMAL_nrm:  31%|██████████████▍                                | 416/1349 [23:22<1:07:09,  4.32s/it]
# Folder: train_nrm/NORMAL_nrm:  31%|██████████████▊                                | 424/1349 [23:49<1:02:30,  4.05s/it]
# Folder: train_nrm/NORMAL_nrm:  32%|███████████████                                | 432/1349 [24:19<1:00:30,  3.96s/it]
# Folder: train_nrm/NORMAL_nrm:  33%|███████████████▉                                 | 440/1349 [24:46<57:02,  3.76s/it]
# Folder: train_nrm/NORMAL_nrm:  33%|████████████████▎                                | 448/1349 [25:15<56:01,  3.73s/it]
# Folder: train_nrm/NORMAL_nrm:  34%|████████████████▌                                | 456/1349 [25:46<56:28,  3.79s/it]
# Folder: train_nrm/NORMAL_nrm:  34%|████████████████▊                                | 464/1349 [26:17<56:15,  3.81s/it]
# Folder: train_nrm/NORMAL_nrm:  35%|█████████████████▏                               | 472/1349 [26:44<53:51,  3.68s/it]
# Folder: train_nrm/NORMAL_nrm:  36%|█████████████████▍                               | 480/1349 [27:17<55:20,  3.82s/it]
# Folder: train_nrm/NORMAL_nrm:  36%|█████████████████▋                               | 488/1349 [27:37<49:07,  3.42s/it]
# Folder: train_nrm/NORMAL_nrm:  37%|██████████████████                               | 496/1349 [27:58<44:54,  3.16s/it]
# Folder: train_nrm/NORMAL_nrm:  37%|██████████████████▎                              | 504/1349 [28:32<49:16,  3.50s/it]
# Folder: train_nrm/NORMAL_nrm:  38%|██████████████████▌                              | 512/1349 [29:03<50:23,  3.61s/it]
# Folder: train_nrm/NORMAL_nrm:  39%|██████████████████▉                              | 520/1349 [29:27<47:22,  3.43s/it]
# Folder: train_nrm/NORMAL_nrm:  39%|███████████████████▏                             | 528/1349 [29:56<47:52,  3.50s/it]
# Folder: train_nrm/NORMAL_nrm:  40%|███████████████████▍                             | 536/1349 [30:23<46:31,  3.43s/it]
# Folder: train_nrm/NORMAL_nrm:  40%|███████████████████▊                             | 544/1349 [30:53<47:46,  3.56s/it]
# Folder: train_nrm/NORMAL_nrm:  41%|████████████████████                             | 552/1349 [31:17<44:54,  3.38s/it]
# Folder: train_nrm/NORMAL_nrm:  42%|████████████████████▎                            | 560/1349 [31:48<46:26,  3.53s/it]
# Folder: train_nrm/NORMAL_nrm:  42%|████████████████████▋                            | 568/1349 [32:09<42:31,  3.27s/it]
# Folder: train_nrm/NORMAL_nrm:  43%|████████████████████▉                            | 576/1349 [32:38<43:23,  3.37s/it]
# Folder: train_nrm/NORMAL_nrm:  43%|█████████████████████▏                           | 584/1349 [33:04<42:15,  3.31s/it]
# Folder: train_nrm/NORMAL_nrm:  44%|█████████████████████▌                           | 592/1349 [33:23<38:19,  3.04s/it]
# Folder: train_nrm/NORMAL_nrm:  44%|█████████████████████▊                           | 600/1349 [33:46<37:25,  3.00s/it]
# Folder: train_nrm/NORMAL_nrm:  45%|██████████████████████                           | 608/1349 [34:11<37:17,  3.02s/it]
# Folder: train_nrm/NORMAL_nrm:  46%|██████████████████████▍                          | 616/1349 [34:36<37:21,  3.06s/it]
# Folder: train_nrm/NORMAL_nrm:  46%|██████████████████████▋                          | 624/1349 [34:56<34:50,  2.88s/it]
# Folder: train_nrm/NORMAL_nrm:  47%|██████████████████████▉                          | 632/1349 [35:31<39:59,  3.35s/it]
# Folder: train_nrm/NORMAL_nrm:  47%|███████████████████████▏                         | 640/1349 [36:01<40:45,  3.45s/it]
# Folder: train_nrm/NORMAL_nrm:  48%|███████████████████████▌                         | 648/1349 [36:28<40:20,  3.45s/it]
# Folder: train_nrm/NORMAL_nrm:  49%|███████████████████████▊                         | 656/1349 [36:50<37:13,  3.22s/it]
# Folder: train_nrm/NORMAL_nrm:  49%|████████████████████████                         | 664/1349 [37:18<37:52,  3.32s/it]
# Folder: train_nrm/NORMAL_nrm:  50%|████████████████████████▍                        | 672/1349 [37:41<35:41,  3.16s/it]
# Folder: train_nrm/NORMAL_nrm:  50%|████████████████████████▋                        | 680/1349 [37:59<32:35,  2.92s/it]
# Folder: train_nrm/NORMAL_nrm:  51%|████████████████████████▉                        | 688/1349 [38:30<35:19,  3.21s/it]
# Folder: train_nrm/NORMAL_nrm:  52%|█████████████████████████▎                       | 696/1349 [38:56<35:02,  3.22s/it]
# Folder: train_nrm/NORMAL_nrm:  52%|█████████████████████████▌                       | 704/1349 [39:16<31:58,  2.97s/it]
# Folder: train_nrm/NORMAL_nrm:  53%|█████████████████████████▊                       | 712/1349 [39:44<33:28,  3.15s/it]
# Folder: train_nrm/NORMAL_nrm:  53%|██████████████████████████▏                      | 720/1349 [40:15<35:17,  3.37s/it]
# Folder: train_nrm/NORMAL_nrm:  54%|██████████████████████████▍                      | 728/1349 [40:46<36:24,  3.52s/it]
# Folder: train_nrm/NORMAL_nrm:  55%|██████████████████████████▋                      | 736/1349 [41:25<39:59,  3.91s/it]
# Folder: train_nrm/NORMAL_nrm:  55%|███████████████████████████                      | 744/1349 [41:49<36:48,  3.65s/it]
# Folder: train_nrm/NORMAL_nrm:  56%|███████████████████████████▎                     | 752/1349 [42:16<35:38,  3.58s/it]
# Folder: train_nrm/NORMAL_nrm:  56%|███████████████████████████▌                     | 760/1349 [42:49<36:39,  3.73s/it]
# Folder: train_nrm/NORMAL_nrm:  57%|███████████████████████████▉                     | 768/1349 [43:23<37:33,  3.88s/it]
# Folder: train_nrm/NORMAL_nrm:  58%|████████████████████████████▏                    | 776/1349 [43:47<34:36,  3.62s/it]
# Folder: train_nrm/NORMAL_nrm:  58%|████████████████████████████▍                    | 784/1349 [44:26<37:34,  3.99s/it]
# Folder: train_nrm/NORMAL_nrm:  59%|████████████████████████████▊                    | 792/1349 [45:01<37:58,  4.09s/it]
# Folder: train_nrm/NORMAL_nrm:  59%|█████████████████████████████                    | 800/1349 [45:17<31:52,  3.48s/it]
# Folder: train_nrm/NORMAL_nrm:  60%|█████████████████████████████▎                   | 808/1349 [45:46<31:54,  3.54s/it]
# Folder: train_nrm/NORMAL_nrm:  60%|█████████████████████████████▋                   | 816/1349 [46:11<30:21,  3.42s/it]
# Folder: train_nrm/NORMAL_nrm:  61%|█████████████████████████████▉                   | 824/1349 [46:43<31:15,  3.57s/it]
# Folder: train_nrm/NORMAL_nrm:  62%|██████████████████████████████▏                  | 832/1349 [47:05<28:50,  3.35s/it]
# Folder: train_nrm/NORMAL_nrm:  62%|██████████████████████████████▌                  | 840/1349 [47:23<25:29,  3.00s/it]
# Folder: train_nrm/NORMAL_nrm:  63%|██████████████████████████████▊                  | 848/1349 [48:03<29:55,  3.58s/it]
# Folder: train_nrm/NORMAL_nrm:  63%|███████████████████████████████                  | 856/1349 [48:20<25:51,  3.15s/it]
# Folder: train_nrm/NORMAL_nrm:  64%|███████████████████████████████▍                 | 864/1349 [48:40<23:58,  2.97s/it]
# Folder: train_nrm/NORMAL_nrm:  65%|███████████████████████████████▋                 | 872/1349 [49:13<26:26,  3.33s/it]
# Folder: train_nrm/NORMAL_nrm:  65%|███████████████████████████████▉                 | 880/1349 [49:40<26:08,  3.35s/it]
# Folder: train_nrm/NORMAL_nrm:  66%|████████████████████████████████▎                | 888/1349 [50:08<25:48,  3.36s/it]
# Folder: train_nrm/NORMAL_nrm:  66%|████████████████████████████████▌                | 896/1349 [50:33<24:53,  3.30s/it]
# Folder: train_nrm/NORMAL_nrm:  67%|████████████████████████████████▊                | 904/1349 [50:55<23:16,  3.14s/it]
# Folder: train_nrm/NORMAL_nrm:  68%|█████████████████████████████████▏               | 912/1349 [51:24<24:02,  3.30s/it]
# Folder: train_nrm/NORMAL_nrm:  68%|█████████████████████████████████▍               | 920/1349 [51:52<23:54,  3.34s/it]
# Folder: train_nrm/NORMAL_nrm:  69%|█████████████████████████████████▋               | 928/1349 [52:15<22:32,  3.21s/it]
# Folder: train_nrm/NORMAL_nrm:  69%|█████████████████████████████████▉               | 936/1349 [52:44<22:53,  3.32s/it]
# Folder: train_nrm/NORMAL_nrm:  70%|██████████████████████████████████▎              | 944/1349 [53:02<20:19,  3.01s/it]
# Folder: train_nrm/NORMAL_nrm:  71%|██████████████████████████████████▌              | 952/1349 [53:24<19:22,  2.93s/it]
# Folder: train_nrm/NORMAL_nrm:  71%|██████████████████████████████████▊              | 960/1349 [53:56<21:01,  3.24s/it]
# Folder: train_nrm/NORMAL_nrm:  72%|███████████████████████████████████▏             | 968/1349 [54:19<20:00,  3.15s/it]
# Folder: train_nrm/NORMAL_nrm:  72%|███████████████████████████████████▍             | 976/1349 [54:50<20:53,  3.36s/it]
# Folder: train_nrm/NORMAL_nrm:  73%|███████████████████████████████████▋             | 984/1349 [55:20<21:04,  3.46s/it]
# Folder: train_nrm/NORMAL_nrm:  74%|████████████████████████████████████             | 992/1349 [55:48<20:50,  3.50s/it]
# Folder: train_nrm/NORMAL_nrm:  74%|███████████████████████████████████▌            | 1000/1349 [56:17<20:31,  3.53s/it]
# Folder: train_nrm/NORMAL_nrm:  75%|███████████████████████████████████▊            | 1008/1349 [56:54<21:57,  3.86s/it]
# Folder: train_nrm/NORMAL_nrm:  75%|████████████████████████████████████▏           | 1016/1349 [57:12<18:37,  3.36s/it]
# Folder: train_nrm/NORMAL_nrm:  76%|████████████████████████████████████▍           | 1024/1349 [57:41<18:37,  3.44s/it]
# Folder: train_nrm/NORMAL_nrm:  77%|████████████████████████████████████▋           | 1032/1349 [58:07<17:55,  3.39s/it]
# Folder: train_nrm/NORMAL_nrm:  77%|█████████████████████████████████████           | 1040/1349 [58:32<17:01,  3.31s/it]
# Folder: train_nrm/NORMAL_nrm:  78%|█████████████████████████████████████▎          | 1048/1349 [58:54<15:47,  3.15s/it]
# Folder: train_nrm/NORMAL_nrm:  78%|█████████████████████████████████████▌          | 1056/1349 [59:27<16:49,  3.45s/it]
# Folder: train_nrm/NORMAL_nrm:  79%|█████████████████████████████████████▊          | 1064/1349 [59:49<15:17,  3.22s/it]
# Folder: train_nrm/NORMAL_nrm:  79%|████████████████████████████████████▌         | 1072/1349 [1:00:22<16:10,  3.50s/it]
# Folder: train_nrm/NORMAL_nrm:  80%|████████████████████████████████████▊         | 1080/1349 [1:00:49<15:35,  3.48s/it]
# Folder: train_nrm/NORMAL_nrm:  81%|█████████████████████████████████████         | 1088/1349 [1:01:17<15:02,  3.46s/it]
# Folder: train_nrm/NORMAL_nrm:  81%|█████████████████████████████████████▎        | 1096/1349 [1:01:49<15:19,  3.64s/it]
# Folder: train_nrm/NORMAL_nrm:  82%|█████████████████████████████████████▋        | 1104/1349 [1:02:17<14:37,  3.58s/it]
# Folder: train_nrm/NORMAL_nrm:  82%|█████████████████████████████████████▉        | 1112/1349 [1:02:37<12:49,  3.25s/it]
# Folder: train_nrm/NORMAL_nrm:  83%|██████████████████████████████████████▏       | 1120/1349 [1:03:05<12:47,  3.35s/it]
# Folder: train_nrm/NORMAL_nrm:  84%|██████████████████████████████████████▍       | 1128/1349 [1:03:35<12:47,  3.47s/it]
# Folder: train_nrm/NORMAL_nrm:  84%|██████████████████████████████████████▍       | 1129/1349 [1:03:35<12:06,  3.30s/it]
# Folder: train_nrm/NORMAL_nrm:  84%|██████████████████████████████████████▍       | 1129/1349 [1:03:49<12:06,  3.30s/it]
# Folder: train_nrm/NORMAL_nrm:  84%|██████████████████████████████████████▋       | 1136/1349 [1:04:09<13:33,  3.82s/it]
# Folder: train_nrm/NORMAL_nrm:  85%|███████████████████████████████████████       | 1144/1349 [1:04:35<12:15,  3.59s/it]
# Folder: train_nrm/NORMAL_nrm:  85%|███████████████████████████████████████▎      | 1152/1349 [1:04:59<11:14,  3.42s/it]
# Folder: train_nrm/NORMAL_nrm:  86%|███████████████████████████████████████▌      | 1160/1349 [1:05:21<10:05,  3.20s/it]
# Folder: train_nrm/NORMAL_nrm:  87%|███████████████████████████████████████▊      | 1168/1349 [1:05:45<09:27,  3.14s/it]
# Folder: train_nrm/NORMAL_nrm:  87%|████████████████████████████████████████      | 1176/1349 [1:06:10<09:01,  3.13s/it]
# Folder: train_nrm/NORMAL_nrm:  88%|████████████████████████████████████████▎     | 1184/1349 [1:06:44<09:33,  3.47s/it]
# Folder: train_nrm/NORMAL_nrm:  88%|████████████████████████████████████████▋     | 1192/1349 [1:07:06<08:27,  3.23s/it]
# Folder: train_nrm/NORMAL_nrm:  89%|████████████████████████████████████████▉     | 1200/1349 [1:07:36<08:28,  3.41s/it]
# Folder: train_nrm/NORMAL_nrm:  90%|█████████████████████████████████████████▏    | 1208/1349 [1:08:02<07:53,  3.36s/it]
# Folder: train_nrm/NORMAL_nrm:  90%|█████████████████████████████████████████▍    | 1216/1349 [1:08:27<07:16,  3.28s/it]
# Folder: train_nrm/NORMAL_nrm:  91%|█████████████████████████████████████████▋    | 1224/1349 [1:08:56<07:02,  3.38s/it]
# Folder: train_nrm/NORMAL_nrm:  91%|██████████████████████████████████████████    | 1232/1349 [1:09:19<06:19,  3.24s/it]
# Folder: train_nrm/NORMAL_nrm:  92%|██████████████████████████████████████████▎   | 1240/1349 [1:09:41<05:34,  3.07s/it]
# Folder: train_nrm/NORMAL_nrm:  92%|██████████████████████████████████████████▎   | 1241/1349 [1:09:41<05:15,  2.92s/it]
# Folder: train_nrm/NORMAL_nrm:  92%|██████████████████████████████████████████▎   | 1241/1349 [1:09:59<05:15,  2.92s/it]
# Folder: train_nrm/NORMAL_nrm:  93%|██████████████████████████████████████████▌   | 1248/1349 [1:10:14<05:59,  3.56s/it]
# Folder: train_nrm/NORMAL_nrm:  93%|██████████████████████████████████████████▊   | 1256/1349 [1:10:42<05:29,  3.54s/it]
# Folder: train_nrm/NORMAL_nrm:  94%|███████████████████████████████████████████   | 1264/1349 [1:11:11<05:00,  3.53s/it]
# Folder: train_nrm/NORMAL_nrm:  94%|███████████████████████████████████████████▎  | 1272/1349 [1:11:42<04:41,  3.65s/it]
# Folder: train_nrm/NORMAL_nrm:  95%|███████████████████████████████████████████▋  | 1280/1349 [1:12:08<04:04,  3.54s/it]
# Folder: train_nrm/NORMAL_nrm:  95%|███████████████████████████████████████████▉  | 1288/1349 [1:12:37<03:37,  3.56s/it]
# Folder: train_nrm/NORMAL_nrm:  96%|████████████████████████████████████████████▏ | 1296/1349 [1:12:56<02:49,  3.21s/it]
# Folder: train_nrm/NORMAL_nrm:  97%|████████████████████████████████████████████▍ | 1304/1349 [1:13:34<02:44,  3.66s/it]
# Folder: train_nrm/NORMAL_nrm:  97%|████████████████████████████████████████████▋ | 1312/1349 [1:13:58<02:08,  3.46s/it]
# Folder: train_nrm/NORMAL_nrm:  97%|████████████████████████████████████████████▊ | 1313/1349 [1:13:58<01:58,  3.29s/it]
# Folder: train_nrm/NORMAL_nrm:  97%|████████████████████████████████████████████▊ | 1313/1349 [1:14:09<01:58,  3.29s/it]
# Folder: train_nrm/NORMAL_nrm:  98%|█████████████████████████████████████████████ | 1320/1349 [1:14:25<01:40,  3.47s/it]
# Folder: train_nrm/NORMAL_nrm:  98%|█████████████████████████████████████████████▎| 1328/1349 [1:14:44<01:04,  3.08s/it]
# Folder: train_nrm/NORMAL_nrm:  99%|█████████████████████████████████████████████▌| 1336/1349 [1:15:14<00:42,  3.30s/it]
# Folder: train_nrm/NORMAL_nrm: 100%|██████████████████████████████████████████████| 1349/1349 [1:15:37<00:00,  3.36s/it]
# Extracting second-order features GLDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm
# Folder: train_nrm/PNEUMONIA_nrm:   0%|                                                        | 0/3883 [00:00<?, ?it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   0%|▏                                              | 16/3883 [00:03<14:08,  4.56it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▎                                              | 24/3883 [00:16<50:24,  1.28it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▍                                              | 32/3883 [00:25<59:44,  1.07it/s]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▍                                            | 40/3883 [00:41<1:24:09,  1.31s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▌                                            | 48/3883 [01:03<1:53:24,  1.77s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▋                                            | 56/3883 [01:16<1:50:11,  1.73s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▋                                            | 64/3883 [01:26<1:39:52,  1.57s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▊                                            | 72/3883 [01:37<1:37:22,  1.53s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▉                                            | 80/3883 [01:51<1:41:05,  1.59s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|█                                            | 88/3883 [02:06<1:45:33,  1.67s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   2%|█                                            | 96/3883 [02:18<1:42:18,  1.62s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▏                                          | 104/3883 [02:29<1:38:25,  1.56s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▎                                          | 112/3883 [02:39<1:31:47,  1.46s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▎                                          | 120/3883 [02:51<1:30:47,  1.45s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▍                                          | 128/3883 [03:01<1:27:43,  1.40s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▌                                          | 136/3883 [03:12<1:26:18,  1.38s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▋                                          | 144/3883 [03:24<1:29:00,  1.43s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▋                                          | 152/3883 [03:37<1:32:13,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▊                                          | 160/3883 [03:47<1:28:36,  1.43s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▉                                          | 168/3883 [03:59<1:29:03,  1.44s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|█▉                                          | 176/3883 [04:12<1:31:54,  1.49s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██                                          | 184/3883 [04:29<1:43:23,  1.68s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▏                                         | 192/3883 [04:40<1:39:11,  1.61s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▎                                         | 200/3883 [04:49<1:28:15,  1.44s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▎                                         | 208/3883 [05:02<1:32:31,  1.51s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▍                                         | 216/3883 [05:13<1:30:15,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▌                                         | 224/3883 [05:23<1:26:18,  1.42s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▋                                         | 232/3883 [05:40<1:38:10,  1.61s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▋                                         | 240/3883 [05:52<1:34:52,  1.56s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▋                                         | 241/3883 [05:52<1:30:20,  1.49s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▊                                         | 248/3883 [05:59<1:20:47,  1.33s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|██▉                                         | 256/3883 [06:14<1:32:01,  1.52s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|██▉                                         | 264/3883 [06:23<1:24:47,  1.41s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███                                         | 272/3883 [06:30<1:14:29,  1.24s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▏                                        | 280/3883 [06:45<1:25:23,  1.42s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▎                                        | 288/3883 [07:04<1:44:20,  1.74s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▎                                        | 296/3883 [07:17<1:41:23,  1.70s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▍                                        | 304/3883 [07:28<1:35:23,  1.60s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▌                                        | 312/3883 [07:39<1:29:51,  1.51s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▋                                        | 320/3883 [07:52<1:32:08,  1.55s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▋                                        | 328/3883 [08:04<1:31:59,  1.55s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|███▊                                        | 336/3883 [08:15<1:27:25,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|███▉                                        | 344/3883 [08:33<1:41:25,  1.72s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|███▉                                        | 352/3883 [08:39<1:24:50,  1.44s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████                                        | 360/3883 [08:52<1:26:28,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████▏                                       | 368/3883 [08:59<1:15:52,  1.30s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▎                                       | 376/3883 [09:16<1:31:34,  1.57s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▎                                       | 384/3883 [09:32<1:39:04,  1.70s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▍                                       | 392/3883 [09:44<1:34:06,  1.62s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▌                                       | 400/3883 [09:55<1:29:56,  1.55s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▌                                       | 408/3883 [10:05<1:25:40,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▋                                       | 416/3883 [10:26<1:43:19,  1.79s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▊                                       | 424/3883 [10:38<1:39:35,  1.73s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▉                                       | 432/3883 [10:46<1:26:06,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▉                                       | 440/3883 [10:58<1:25:40,  1.49s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████                                       | 448/3883 [11:12<1:31:19,  1.60s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▏                                      | 456/3883 [11:22<1:23:52,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▎                                      | 464/3883 [11:31<1:17:38,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▎                                      | 472/3883 [11:40<1:13:13,  1.29s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▍                                      | 480/3883 [11:53<1:18:28,  1.38s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▌                                      | 488/3883 [12:10<1:32:14,  1.63s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▌                                      | 496/3883 [12:24<1:34:19,  1.67s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▋                                      | 504/3883 [12:33<1:23:40,  1.49s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▊                                      | 512/3883 [12:45<1:23:59,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▉                                      | 520/3883 [12:58<1:27:13,  1.56s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|█████▉                                      | 528/3883 [13:05<1:13:38,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████                                      | 536/3883 [13:17<1:18:31,  1.41s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▏                                     | 544/3883 [13:31<1:22:14,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▎                                     | 552/3883 [13:39<1:15:24,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▎                                     | 560/3883 [13:53<1:20:57,  1.46s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▍                                     | 568/3883 [14:02<1:15:06,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▌                                     | 576/3883 [14:14<1:16:43,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▌                                     | 584/3883 [14:25<1:16:39,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▋                                     | 592/3883 [14:40<1:24:56,  1.55s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▊                                     | 600/3883 [14:53<1:25:33,  1.56s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|██████▉                                     | 608/3883 [15:01<1:16:38,  1.40s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|██████▉                                     | 616/3883 [15:11<1:14:16,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████                                     | 624/3883 [15:26<1:21:34,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▏                                    | 632/3883 [15:37<1:19:21,  1.46s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▎                                    | 640/3883 [15:54<1:30:54,  1.68s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▎                                    | 648/3883 [16:03<1:21:21,  1.51s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▍                                    | 656/3883 [16:25<1:41:32,  1.89s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▌                                    | 664/3883 [16:41<1:42:28,  1.91s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▌                                    | 672/3883 [16:48<1:24:43,  1.58s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▋                                    | 680/3883 [17:08<1:40:46,  1.89s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▊                                    | 688/3883 [17:19<1:30:52,  1.71s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▉                                    | 696/3883 [17:31<1:27:53,  1.65s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▉                                    | 704/3883 [17:45<1:28:49,  1.68s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  18%|████████                                    | 712/3883 [17:55<1:21:16,  1.54s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▏                                   | 720/3883 [18:07<1:22:23,  1.56s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▏                                   | 728/3883 [18:17<1:15:29,  1.44s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▎                                   | 736/3883 [18:30<1:19:11,  1.51s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▍                                   | 744/3883 [18:49<1:32:39,  1.77s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▌                                   | 752/3883 [18:59<1:25:02,  1.63s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▌                                   | 760/3883 [19:16<1:31:18,  1.75s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▋                                   | 768/3883 [19:27<1:25:33,  1.65s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▊                                   | 776/3883 [19:39<1:22:19,  1.59s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▉                                   | 784/3883 [19:50<1:20:14,  1.55s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▉                                   | 792/3883 [20:15<1:43:32,  2.01s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████                                   | 800/3883 [20:27<1:34:59,  1.85s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▏                                  | 808/3883 [20:39<1:30:28,  1.77s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▏                                  | 816/3883 [20:54<1:30:49,  1.78s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▎                                  | 824/3883 [21:04<1:22:04,  1.61s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▍                                  | 832/3883 [21:19<1:26:05,  1.69s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▌                                  | 840/3883 [21:35<1:31:49,  1.81s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▌                                  | 848/3883 [21:49<1:29:31,  1.77s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▋                                  | 856/3883 [22:02<1:28:02,  1.74s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▊                                  | 864/3883 [22:22<1:39:02,  1.97s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▉                                  | 872/3883 [22:52<2:04:26,  2.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|█████████▉                                  | 880/3883 [23:11<2:03:35,  2.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████                                  | 888/3883 [23:21<1:45:28,  2.11s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▏                                 | 896/3883 [23:36<1:41:31,  2.04s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▏                                 | 904/3883 [23:50<1:35:27,  1.92s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▎                                 | 912/3883 [23:58<1:23:16,  1.68s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▍                                 | 920/3883 [24:21<1:40:42,  2.04s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▌                                 | 928/3883 [24:29<1:23:23,  1.69s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▌                                 | 936/3883 [24:41<1:21:42,  1.66s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▋                                 | 944/3883 [24:53<1:18:41,  1.61s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|██████████▊                                 | 952/3883 [25:14<1:32:45,  1.90s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|██████████▉                                 | 960/3883 [25:27<1:28:59,  1.83s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|██████████▉                                 | 968/3883 [25:39<1:24:24,  1.74s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████                                 | 976/3883 [25:49<1:16:42,  1.58s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████▏                                | 984/3883 [25:57<1:08:43,  1.42s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▏                                | 992/3883 [26:09<1:09:47,  1.45s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████                                | 1000/3883 [26:26<1:18:10,  1.63s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▏                               | 1008/3883 [26:35<1:10:23,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▎                               | 1016/3883 [26:47<1:11:33,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▎                               | 1024/3883 [27:02<1:15:38,  1.59s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▍                               | 1032/3883 [27:11<1:10:23,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▌                               | 1040/3883 [27:35<1:31:55,  1.94s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▌                               | 1048/3883 [27:49<1:27:18,  1.85s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▋                               | 1056/3883 [27:57<1:15:12,  1.60s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▊                               | 1064/3883 [28:09<1:14:05,  1.58s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|███████████▊                               | 1072/3883 [28:25<1:19:59,  1.71s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|███████████▉                               | 1080/3883 [28:40<1:23:03,  1.78s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████                               | 1088/3883 [28:51<1:16:18,  1.64s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▏                              | 1096/3883 [29:06<1:18:48,  1.70s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▏                              | 1104/3883 [29:16<1:12:07,  1.56s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▎                              | 1112/3883 [29:27<1:09:33,  1.51s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▍                              | 1120/3883 [29:42<1:14:59,  1.63s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▍                              | 1128/3883 [30:01<1:24:39,  1.84s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▌                              | 1136/3883 [30:20<1:33:02,  2.03s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▋                              | 1144/3883 [30:35<1:30:00,  1.97s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|████████████▊                              | 1152/3883 [30:46<1:21:36,  1.79s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|████████████▊                              | 1160/3883 [31:03<1:25:10,  1.88s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|████████████▉                              | 1168/3883 [31:12<1:15:31,  1.67s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████                              | 1176/3883 [31:24<1:12:00,  1.60s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████                              | 1184/3883 [31:32<1:03:38,  1.41s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▏                             | 1192/3883 [31:49<1:14:30,  1.66s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▎                             | 1200/3883 [32:02<1:12:45,  1.63s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▍                             | 1208/3883 [32:23<1:25:39,  1.92s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▍                             | 1216/3883 [32:47<1:39:37,  2.24s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▌                             | 1224/3883 [32:58<1:27:49,  1.98s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▋                             | 1232/3883 [33:14<1:28:31,  2.00s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▋                             | 1240/3883 [33:30<1:28:19,  2.01s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▊                             | 1248/3883 [33:46<1:27:44,  2.00s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▉                             | 1256/3883 [34:00<1:24:14,  1.92s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|█████████████▉                             | 1264/3883 [34:12<1:17:49,  1.78s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████                             | 1272/3883 [34:24<1:15:15,  1.73s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▏                            | 1280/3883 [34:35<1:10:06,  1.62s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▎                            | 1288/3883 [34:50<1:13:00,  1.69s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▎                            | 1296/3883 [35:11<1:25:27,  1.98s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▍                            | 1304/3883 [35:38<1:42:07,  2.38s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▌                            | 1312/3883 [35:54<1:38:05,  2.29s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▌                            | 1320/3883 [36:06<1:27:10,  2.04s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▋                            | 1328/3883 [36:18<1:19:18,  1.86s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▊                            | 1336/3883 [36:31<1:16:25,  1.80s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|██████████████▉                            | 1344/3883 [36:41<1:09:44,  1.65s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|██████████████▉                            | 1352/3883 [36:56<1:12:19,  1.71s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████                            | 1360/3883 [37:09<1:11:00,  1.69s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████▏                           | 1368/3883 [37:28<1:18:24,  1.87s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  35%|███████████████▏                           | 1376/3883 [37:43<1:19:10,  1.89s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|███████████████▎                           | 1384/3883 [37:53<1:10:56,  1.70s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████▏                            | 1392/3883 [38:00<59:49,  1.44s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████▏                            | 1400/3883 [38:10<57:06,  1.38s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|███████████████▌                           | 1408/3883 [38:25<1:03:27,  1.54s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  36%|████████████████▍                            | 1416/3883 [38:30<51:09,  1.24s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▌                            | 1424/3883 [38:42<55:14,  1.35s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▌                            | 1432/3883 [38:47<46:14,  1.13s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▋                            | 1440/3883 [38:55<43:21,  1.07s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▊                            | 1448/3883 [38:58<35:55,  1.13it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████▊                            | 1456/3883 [39:11<43:50,  1.08s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|████████████████▉                            | 1464/3883 [39:24<51:13,  1.27s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|█████████████████                            | 1472/3883 [39:29<42:36,  1.06s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|█████████████████▏                           | 1480/3883 [39:37<42:04,  1.05s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  38%|█████████████████▏                           | 1488/3883 [39:47<44:22,  1.11s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▎                           | 1496/3883 [39:52<37:46,  1.05it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▍                           | 1504/3883 [39:59<36:37,  1.08it/s]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▌                           | 1512/3883 [40:10<42:36,  1.08s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▌                           | 1520/3883 [40:30<58:24,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  39%|█████████████████▋                           | 1528/3883 [40:40<55:23,  1.41s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|█████████████████▊                           | 1536/3883 [40:49<52:14,  1.34s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|█████████████████▉                           | 1544/3883 [40:57<48:40,  1.25s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|█████████████████▉                           | 1552/3883 [41:10<52:23,  1.35s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|██████████████████                           | 1560/3883 [41:18<48:59,  1.27s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  40%|██████████████████▏                          | 1568/3883 [41:31<52:48,  1.37s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|█████████████████▍                         | 1576/3883 [41:56<1:13:00,  1.90s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|█████████████████▌                         | 1584/3883 [42:06<1:05:03,  1.70s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|█████████████████▋                         | 1592/3883 [42:22<1:08:07,  1.78s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|█████████████████▋                         | 1600/3883 [42:31<1:00:34,  1.59s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  41%|█████████████████▊                         | 1608/3883 [42:45<1:01:28,  1.62s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|██████████████████▋                          | 1616/3883 [42:55<56:47,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|█████████████████▉                         | 1624/3883 [43:14<1:07:40,  1.80s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|██████████████████                         | 1632/3883 [43:28<1:06:28,  1.77s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|███████████████████                          | 1640/3883 [43:36<57:41,  1.54s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  42%|███████████████████                          | 1648/3883 [43:43<50:16,  1.35s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▏                         | 1656/3883 [43:52<47:03,  1.27s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▎                         | 1664/3883 [44:08<54:42,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▍                         | 1672/3883 [44:20<55:10,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▍                         | 1680/3883 [44:28<49:59,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  43%|███████████████████▌                         | 1688/3883 [44:38<48:17,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  44%|███████████████████▋                         | 1696/3883 [44:45<42:51,  1.18s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  44%|███████████████████▋                         | 1704/3883 [44:52<39:10,  1.08s/it]
# ...
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████           | 2896/3883 [1:12:27<22:18,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████▏          | 2904/3883 [1:12:36<21:05,  1.29s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████▏          | 2912/3883 [1:12:45<19:56,  1.23s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████▎          | 2920/3883 [1:13:07<27:01,  1.68s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████▍          | 2928/3883 [1:13:15<23:23,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▌          | 2936/3883 [1:13:25<22:17,  1.41s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▌          | 2944/3883 [1:13:36<21:49,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▋          | 2952/3883 [1:13:47<21:42,  1.40s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▊          | 2960/3883 [1:13:58<21:25,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▊          | 2968/3883 [1:14:12<22:40,  1.49s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  77%|████████████████████████████████▉          | 2976/3883 [1:14:23<22:04,  1.46s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████          | 2984/3883 [1:14:33<20:51,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████▏         | 2992/3883 [1:14:40<18:42,  1.26s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████▏         | 3000/3883 [1:14:50<18:29,  1.26s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████▎         | 3008/3883 [1:14:57<16:21,  1.12s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▍         | 3016/3883 [1:15:07<16:37,  1.15s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▍         | 3024/3883 [1:15:14<15:47,  1.10s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▌         | 3032/3883 [1:15:26<17:14,  1.22s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▋         | 3040/3883 [1:15:33<15:26,  1.10s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▊         | 3048/3883 [1:15:41<14:48,  1.06s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  79%|█████████████████████████████████▊         | 3056/3883 [1:16:00<20:06,  1.46s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  79%|█████████████████████████████████▉         | 3064/3883 [1:16:11<19:33,  1.43s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  79%|██████████████████████████████████         | 3072/3883 [1:16:16<16:25,  1.22s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  79%|██████████████████████████████████         | 3080/3883 [1:16:26<16:04,  1.20s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▏        | 3088/3883 [1:16:36<16:10,  1.22s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▎        | 3096/3883 [1:16:46<16:03,  1.22s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▎        | 3104/3883 [1:16:56<16:08,  1.24s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▍        | 3112/3883 [1:17:04<14:59,  1.17s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▌        | 3120/3883 [1:17:12<14:07,  1.11s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▋        | 3128/3883 [1:17:23<14:51,  1.18s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▋        | 3136/3883 [1:17:30<13:33,  1.09s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▊        | 3144/3883 [1:17:38<13:03,  1.06s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▉        | 3152/3883 [1:17:50<14:49,  1.22s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▉        | 3160/3883 [1:17:58<13:57,  1.16s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████        | 3168/3883 [1:18:16<17:26,  1.46s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▏       | 3176/3883 [1:18:28<17:40,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▎       | 3184/3883 [1:18:42<18:21,  1.58s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▎       | 3192/3883 [1:18:52<16:55,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▍       | 3200/3883 [1:19:06<17:37,  1.55s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▌       | 3208/3883 [1:19:12<14:50,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▌       | 3216/3883 [1:19:26<15:48,  1.42s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▋       | 3224/3883 [1:19:39<16:26,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▊       | 3232/3883 [1:19:45<13:45,  1.27s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▉       | 3240/3883 [1:19:57<14:10,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  84%|███████████████████████████████████▉       | 3248/3883 [1:20:05<13:13,  1.25s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████       | 3256/3883 [1:20:15<13:05,  1.25s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████▏      | 3264/3883 [1:20:27<13:36,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████▏      | 3272/3883 [1:20:33<11:51,  1.16s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████▎      | 3280/3883 [1:20:44<12:06,  1.21s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▍      | 3288/3883 [1:20:56<13:03,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▍      | 3296/3883 [1:21:07<12:42,  1.30s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▌      | 3304/3883 [1:21:16<12:17,  1.27s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▋      | 3312/3883 [1:21:25<11:27,  1.20s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  86%|████████████████████████████████████▊      | 3320/3883 [1:21:30<09:53,  1.05s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  86%|████████████████████████████████████▊      | 3328/3883 [1:21:42<11:01,  1.19s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  86%|████████████████████████████████████▉      | 3336/3883 [1:21:52<11:02,  1.21s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  86%|█████████████████████████████████████      | 3344/3883 [1:22:01<10:29,  1.17s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  86%|█████████████████████████████████████      | 3352/3883 [1:22:08<09:44,  1.10s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▏     | 3360/3883 [1:22:17<09:40,  1.11s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▎     | 3368/3883 [1:22:32<11:11,  1.30s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▍     | 3376/3883 [1:22:42<11:06,  1.31s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▍     | 3384/3883 [1:22:50<10:07,  1.22s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▌     | 3392/3883 [1:22:56<08:36,  1.05s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▋     | 3400/3883 [1:23:03<08:06,  1.01s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▋     | 3408/3883 [1:23:13<08:31,  1.08s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▊     | 3416/3883 [1:23:28<10:15,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▉     | 3424/3883 [1:23:39<10:26,  1.37s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  88%|██████████████████████████████████████     | 3432/3883 [1:23:51<10:21,  1.38s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████     | 3440/3883 [1:24:02<10:16,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▏    | 3448/3883 [1:24:09<09:01,  1.24s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▎    | 3456/3883 [1:24:17<08:10,  1.15s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▎    | 3464/3883 [1:24:23<07:20,  1.05s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▍    | 3472/3883 [1:24:34<07:39,  1.12s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▌    | 3480/3883 [1:24:45<08:04,  1.20s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▋    | 3488/3883 [1:24:54<07:43,  1.17s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▋    | 3496/3883 [1:25:04<07:50,  1.22s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▊    | 3504/3883 [1:25:18<08:42,  1.38s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▉    | 3512/3883 [1:25:27<08:01,  1.30s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|██████████████████████████████████████▉    | 3520/3883 [1:25:34<07:02,  1.16s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████    | 3528/3883 [1:25:44<07:00,  1.19s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████▏   | 3536/3883 [1:25:59<08:02,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████▏   | 3544/3883 [1:26:14<08:43,  1.55s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████▎   | 3552/3883 [1:26:27<08:36,  1.56s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▍   | 3560/3883 [1:26:40<08:31,  1.58s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▌   | 3568/3883 [1:26:55<08:53,  1.69s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▌   | 3576/3883 [1:27:10<08:56,  1.75s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▋   | 3584/3883 [1:27:26<08:56,  1.79s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|███████████████████████████████████████▊   | 3592/3883 [1:27:37<08:04,  1.66s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|███████████████████████████████████████▊   | 3600/3883 [1:27:45<06:58,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|███████████████████████████████████████▉   | 3608/3883 [1:27:55<06:24,  1.40s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|████████████████████████████████████████   | 3616/3883 [1:28:06<06:12,  1.39s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  93%|████████████████████████████████████████▏  | 3624/3883 [1:28:16<05:53,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▏  | 3632/3883 [1:28:29<05:59,  1.43s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▎  | 3640/3883 [1:28:41<05:58,  1.48s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▍  | 3648/3883 [1:28:50<05:22,  1.37s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▍  | 3656/3883 [1:29:02<05:19,  1.41s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▌  | 3664/3883 [1:29:15<05:17,  1.45s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▋  | 3672/3883 [1:29:24<04:47,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▊  | 3680/3883 [1:29:35<04:36,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▊  | 3688/3883 [1:29:43<04:07,  1.27s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▉  | 3696/3883 [1:30:00<04:46,  1.53s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  95%|█████████████████████████████████████████  | 3704/3883 [1:30:11<04:22,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████  | 3712/3883 [1:30:24<04:16,  1.50s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▏ | 3720/3883 [1:30:31<03:34,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▎ | 3728/3883 [1:30:41<03:21,  1.30s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▎ | 3736/3883 [1:30:49<02:58,  1.21s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▍ | 3744/3883 [1:31:00<02:56,  1.27s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▌ | 3752/3883 [1:31:08<02:33,  1.17s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▋ | 3760/3883 [1:31:19<02:34,  1.25s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▋ | 3768/3883 [1:31:31<02:31,  1.32s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▊ | 3776/3883 [1:31:42<02:24,  1.35s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▉ | 3784/3883 [1:31:51<02:06,  1.28s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|█████████████████████████████████████████▉ | 3792/3883 [1:32:11<02:28,  1.63s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████ | 3800/3883 [1:32:20<02:01,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████▏| 3808/3883 [1:32:30<01:47,  1.43s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████▎| 3816/3883 [1:32:44<01:42,  1.53s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████▎| 3824/3883 [1:32:52<01:19,  1.34s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▍| 3832/3883 [1:33:03<01:09,  1.36s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▌| 3840/3883 [1:33:18<01:06,  1.54s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▌| 3848/3883 [1:33:30<00:52,  1.49s/it]
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▋| 3856/3883 [1:33:42<00:40,  1.51s/it]
# Folder: train_nrm/PNEUMONIA_nrm: 100%|██████████████████████████████████████████▊| 3864/3883 [1:33:56<00:30,  1.60s/it]
# Folder: train_nrm/PNEUMONIA_nrm: 100%|██████████████████████████████████████████▉| 3872/3883 [1:34:06<00:16,  1.47s/it]
# Folder: train_nrm/PNEUMONIA_nrm: 100%|███████████████████████████████████████████| 3883/3883 [1:34:17<00:00,  1.46s/it]
# Folder: train_nrm/NORMAL_nrm:   1%|▍                                         | 15/1349 [4:13:41<376:02:10, 1014.79s/it]
# Extracting second-order features GLDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm
# Folder: test_nrm/NORMAL_nrm: 100%|███████████████████████████████████████████████████| 234/234 [13:19<00:00,  3.42s/it]
# Extracting second-order features GLDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm
# Folder: test_nrm/PNEUMONIA_nrm: 100%|████████████████████████████████████████████████| 390/390 [07:40<00:00,  1.18s/it]
# All first-order features are extracted to the Excel file: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_gldm.xlsx
# Please check the Excel file for further analysis and interpretation
