# %% [markdown]
# ### Authors: Prof. Dr. Soumi Ray, Ravi Teja Kothuru and Abhay Srivastav
#
# ### Acknowledgements:
# I would like to thank my team mates Prof. Dr. Soumi Ray and Abhay Srivastav for their guidance and support throughout this project.
#
# **Title of the Project:** Comparative Analysis of Image-Based and Feature-Based Approaches for Pneumonia Detection in Chest X-rays
#
# **Description of the Project:** This project focuses on detecting pneumonia from chest X-ray images using Advanced Machine Learning and Deep Learning techniques (Rajpurkar et al., 2017; Wang et al., 2017). By leveraging a comprehensive dataset, including annotated images of pneumonia and normal cases, we aim to develop and compare image-based and feature-based approaches. Our goal is to identify the most effective method for accurate and interpretable pneumonia detection, contributing to improved patient outcomes through early diagnosis and treatment. This model will classify patients based on their chest X-ray images as either having pneumonia (1) or not having pneumonia (0).
#
# **Objectives of the Project:**
#
# - **Image Analysis:** Develop and evaluate deep learning models to classify chest X-rays directly. This approach leverages deep learning models, particularly Convolutional Neural Networks (CNNs), to perform end-to-end image classification. The models directly process raw chest X-ray images to classify them as normal or pneumonia.
#
# - **Feature Analysis:** Extract meaningful features from the images and use them to train and evaluate traditional machine learning models. In this approach, we first extract features from the chest X-ray images. These features are then used as inputs for traditional machine learning algorithms. The process includes steps such as feature extraction, selection, and transformation, followed by the application of machine learning techniques like Support Vector Machines (SVM), Random Forests.
#
# **Name of the Dataset:** The dataset used in this project is the Chest X-ray dataset considered from the Research paper named **Labeled Optical Coherence Tomography (OCT) and Chest X-Ray Images for Classification**.
#
# **Description of the Dataset:** The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy.
#
# **Dataset Source:**
#
# - https://data.mendeley.com/datasets/rscbjbr9sj/2
#
# **Type of the Dataset:**
#
# - X-ray Images
#
# **Description of Dataset:**
# The considered dataset has the following information for better reference:
# - Separate folders to train and validate/test the model.
# - Enough number of Chest X-ray images to train the model to detect and diagnose Pneumonia.
# - The target variable for classification is whether patient has pneumonia or not.
#
# **Goal of the Project using this Dataset:**
# The goal of this project is to conduct a comprehensive comparative analysis of image-based and feature-based approaches for pneumonia detection using chest X-ray images. By evaluating the performance, robustness, and interpretability of deep learning and traditional machine learning models, we aim to identify the most effective method for accurately classifying chest X-rays as normal or pneumonia. This comparison will provide valuable insights into the strengths and limitations of each approach, ultimately contributing to improved detection and diagnosis of pneumonia, which can enhance patient outcomes and survival rates.
#
# **Why did we choose this dataset?**
# We selected this dataset based on several factors. For more detailed information, please refer to the following:
# - The dataset is extensive, providing a large number of images suitable for evaluating and training deep learning models.
# - It aligns well with the project's objectives by offering a challenging and realistic scenario for developing an image classification model using deep learning, specifically for Chest X-ray images.
# - The dataset is annotated with images of two different diseases, enabling the development of a binary-class classification model.
# - It is publicly available, facilitating easy access for research and development purposes.
#
# **Size of dataset:**
# - Total images size = 1.27 GB
# - Dataset has 2 folders:
#   -  **Train:**
#     -  Normal (without Pneumonia) = 1349 images
#     -  Pneumonia = 3884 images
#   -  **Test:**
#     -  Normal (without Pneumonia) = 234 images
#     -  Pneumonia = 390 images
#
# **Expected Behaviors and Problem Handling:**
# - Classify Chest X-ray images with high accuracy.
# - Handle variations in image quality, resolution, and orientation.
# - Be robust to noise and artifacts in the images.
# - Provide interpretable results.
#
# **Issues to focus on:**
# - Improving model interpretability and explainability.
# - Optimizing model performance on a held-out test set.
# - Following AI Ethics and Data Safety practices.

# %% [markdown]
# # Import all the required files and libraries

# %%
import os
import ssl

# Disable SSL certificate verification
ssl._create_default_https_context = ssl._create_unverified_context

# Automatically reload imported modules when their source code changes
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# Import python files from local to use the corresponding function
from cxr_image_features_extraction import CxrImageFeatureExtraction

# %% [markdown]
# # Perform Chest X-ray Images Feature Extraction

# %% [markdown]
# ## Create an object of the Image Feature Extraction class

# %%
image_feature_extraction = CxrImageFeatureExtraction()

# %% [markdown]
# ## Fetch the absolute paths of the normalized image dataset

# %%
# Define the path to the dataset
dataset_path = image_feature_extraction.get_base_path_of_dataset() + "_nrm"
print(f"Normalized Dataset Path = {dataset_path}")

# Fetch train, test, NORMAL and PNEUMONIA folder names
train_folder_name = str(image_feature_extraction.train_test_image_dirs[0])
test_folder_name = str(image_feature_extraction.train_test_image_dirs[1])

normal_img_folder_name = str(image_feature_extraction.normal_pneumonia_image_dirs[0])
pneumonia_img_folder_name = str(image_feature_extraction.normal_pneumonia_image_dirs[1])

# Define the paths to the train and test datasets
# Train
train_normal = os.path.join(dataset_path, train_folder_name + "_nrm", normal_img_folder_name + "_nrm")
train_pneumonia = os.path.join(dataset_path, train_folder_name + "_nrm", pneumonia_img_folder_name + "_nrm")

# Test
test_normal = os.path.join(dataset_path, test_folder_name + "_nrm", normal_img_folder_name + "_nrm")
test_pneumonia = os.path.join(dataset_path, test_folder_name + "_nrm", pneumonia_img_folder_name + "_nrm")

# Print the paths to the train and test datasets
print("\nNormalized Train Images")
print("************************")
print(f"NORMAL = {train_normal}")
print(f"\nPNEUMONIA = {train_pneumonia}")

print("\n\nNormalized Test Images")
print("***************************")
print(f"NORMAL = {test_normal}")
print(f"\nPNEUMONIA = {test_pneumonia}")
# Out:
# Normalized Dataset Path = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm
#
# Normalized Train Images
# ************************
# NORMAL = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm
#
# PNEUMONIA = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm
#
#
# Normalized Test Images
# ***************************
# NORMAL = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm
#
# PNEUMONIA = /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm

# %% [markdown]
# ## Convert all Normalized image folder absolute paths to a list

# %%
image_normalized_folders = [
    train_normal, train_pneumonia,
    test_normal, test_pneumonia
]

image_normalized_folders
# Out:
# ['/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm',
#  '/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm',
#  '/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm',
#  '/Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm']

# %% [markdown]
# ### Extract Second Order NGTDM Features of all the images and write into the existing Excel file
#
# 1. Coarseness
#
# Definition: Coarseness is a measure of the texture coarseness, which is the sum of the NGTDM matrix divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_Coarseness} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}{N \times M}$$
#
# where $G$ is the number of gray levels, $N$ and $M$ are the dimensions of the image, and $ngtdm(i,j)$ is the value of the NGTDM matrix at position $(i,j)$.
#
# 2. Contrast
#
# Definition: Contrast is a measure of the texture contrast, which is the sum of the squared NGTDM matrix divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_Contrast} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)^2}{N \times M}$$
#
# 3. Busyness
#
# Definition: Busyness is a measure of the texture busyness, which is the sum of the NGTDM matrix divided by the product of the total number of pixels in the image and the sum of the absolute differences between the image pixels and the mean image pixel value.
#
# Formula: $$\text{NGTDM_Busyness} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}{(N \times M) \times \sum_{i=0}^{N-1} \sum_{j=0}^{M-1} |I(i,j) - \mu|}$$
#
# where $I(i,j)$ is the value of the image pixel at position $(i,j)$, and $\mu$ is the mean image pixel value.
#
# 4. Complexity
#
# Definition: Complexity is a measure of the texture complexity, which is the sum of the product of the NGTDM matrix and the logarithm of the NGTDM matrix plus 1, divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_Complexity} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j) \times \log_2(ngtdm(i,j)+1)}{N \times M}$$
#
# 5. Dissimilarity
#
# Definition: Dissimilarity is a measure of the texture dissimilarity, which is the sum of the absolute differences between the NGTDM matrix and the mean NGTDM value.
#
# Formula: $$\text{NGTDM_Dissimilarity} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} |ngtdm(i,j) - \mu_{ngtdm}|}{N \times M}$$
#
# where $\mu_{ngtdm}$ is the mean NGTDM value.
#
# 6. Joint Energy
#
# Definition: Joint energy is a measure of the texture joint energy, which is the sum of the squared NGTDM matrix divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_JointEnergy} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)^2}{N \times M}$$
#
# 7. Joint Entropy
#
# Definition: Joint entropy is a measure of the texture joint entropy, which is the sum of the product of the NGTDM matrix and the logarithm of the NGTDM matrix plus 1, divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_JointEntropy} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j) \times \log_2(ngtdm(i,j)+1)}{N \times M}$$
#
# 8. Informational Measure of Correlation 1
#
# Definition: Informational measure of correlation 1 is a measure of the texture informational measure of correlation 1, which is a measure of the correlation between the image pixels and the mean image pixel value.
#
# Formula: $$\text{NGTDM_InformationalMeasureOfCorrelation1} = \frac{HXY - HXY1}{HXY}$$
#
# where:
#
# $HXY$ is the joint entropy of the NGTDM matrix, calculated as:
# $$HXY = -\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j) \times \log_2(ngtdm(i,j))$$
#
# $HXY1$ is the joint entropy of the NGTDM matrix with one pixel shifted, calculated as:
# $$HXY1 = -\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j) \times \log_2(ngtdm(i+1,j))$$
#
# Note that $ngtdm(i,j)$ is the value of the NGTDM matrix at position $(i,j)$, and $G$ is the number of gray levels in the image.
#
# 9. Inverse Difference Moment
#
# Definition: Inverse difference moment is a measure of the texture inverse difference moment, which is the sum of the NGTDM matrix divided by the sum of the absolute differences between the image pixels and the mean image pixel value.
#
# Formula: $$\text{NGTDM_InverseDifferenceMoment} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}{\sum_{i=0}^{N-1} \sum_{j=0}^{M-1} |I(i,j) - \mu|}$$
#
# 10. Inverse Difference Moment Normalized
#
# Definition: Inverse difference moment normalized is a measure of the texture inverse difference moment normalized, which is the sum of the NGTDM matrix divided by the product of the sum of the absolute differences between the image pixels and the mean image pixel value and the maximum gray level.
#
# Formula: $$\text{NGTDM_InverseDifferenceMomentNormalized} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}{(\sum_{i=0}^{N-1} \sum_{j=0}^{M-1} |I(i,j) - \mu|) \times G}$$
#
# 11. Inverse Difference
#
# Definition: Inverse difference is a measure of the texture inverse difference, which is the sum of the NGTDM matrix divided by the sum of the absolute differences between the image pixels and the mean image pixel value.
#
# Formula: $$\text{NGTDM_InverseDifference} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}{\sum_{i=0}^{N-1} \sum_{j=0}^{M-1} |I(i,j) - \mu|}$$
#
# 12. Inverse Variance
#
# Definition: Inverse variance is a measure of the texture inverse variance, which is the sum of the NGTDM matrix divided by the variance of the image.
#
# Formula: $$\text{NGTDM_InverseVariance} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}{\sigma^2}$$
#
# where $\sigma^2$ is the variance of the image.
#
# 13. Maximum Probability
#
# Definition: Maximum probability is a measure of the texture maximum probability, which is the maximum value in the NGTDM matrix.
#
# Formula: $$\text{NGTDM_MaximumProbability} = \max_{i,j} ngtdm(i,j)$$
#
# 14. Sum Average
#
# Definition: Sum average is a measure of the texture sum average, which is the sum of the NGTDM matrix divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_SumAverage} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}{N \times M}$$
#
# 15. Sum Entropy
#
# Definition: Sum entropy is a measure of the texture sum entropy, which is the sum of the product of the NGTDM matrix and the logarithm of the NGTDM matrix plus 1, divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_SumEntropy} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j) \times \log_2(ngtdm(i,j)+1)}{N \times M}$$
#
# 16. Sum of Squares
#
# Definition: Sum of squares is a measure of the texture sum of squares, which is the sum of the squared NGTDM matrix divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_SumOfSquares} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)^2}{N \times M}$$
#
# 17. Auto-Correlation
#
# Definition: Auto-correlation is a measure of the texture auto-correlation, which is the sum of the product of the NGTDM matrix and the NGTDM matrix shifted by one position, divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_AutoCorrelation} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j) \times ngtdm(i+1,j)}{N \times M}$$
#
# 18. Cluster Prominence
#
# Definition: Cluster prominence is a measure of the texture cluster prominence, which is the sum of the squared NGTDM matrix divided by the sum of the NGTDM matrix.
#
# Formula: $$\text{NGTDM_ClusterProminence} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)^2}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}$$
#
# 19. Cluster Shade
#
# Definition: Cluster shade is a measure of the texture cluster shade, which is the sum of the cubed NGTDM matrix divided by the sum of the NGTDM matrix.
#
# Formula: $$\text{NGTDM_ClusterShade} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)^3}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}$$
#
# 20. Cluster Tendency
#
# Definition: Cluster tendency is a measure of the texture cluster tendency, which is the sum of the fourth power of the NGTDM matrix divided by the sum of the NGTDM matrix.
#
# Formula: $$\text{NGTDM_ClusterTendency} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)^4}{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j)}$$
#
# 21. Correlation
#
# Definition: Correlation is a measure of the texture correlation, which is the sum of the product of the NGTDM matrix and the NGTDM matrix shifted by one position, divided by the total number of pixels in the image.
#
# Formula: $$\text{NGTDM_Correlation} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} ngtdm(i,j) \times ngtdm(i+1,j)}{N \times M}$$
#
# 22. Variance
#
# Definition: Variance is a measure of the texture variance, which is the sum of the squared differences between the NGTDM matrix and the mean NGTDM value.
#
# Formula: $$\text{NGTDM_Variance} = \frac{\sum_{i=0}^{G-1} \sum_{j=0}^{G-1} (ngtdm(i,j) - \mu_{ngtdm})^2}{N \times M}$$
#
# where $\mu_{ngtdm}$ is the mean NGTDM value.
#
# These are the 22 features that can be extracted from the NGTDM matrix. Each feature provides a unique perspective on the texture of the image, and can be used in various applications such as image classification, segmentation, and retrieval.

# %%
image_feature_extraction.update_second_order_ngtdm_features_to_excel_file(folders=image_normalized_folders)
# Out:
# Extracted NGTDM features will be saved to - /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_ngtdm.xlsx
#
#
# Extracting second-order features NGTDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/NORMAL_nrm
# Folder: train_nrm/NORMAL_nrm:   0%|                                                           | 0/1349 [00:00<?, ?it/s]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   1%|▌                                                 | 16/1349 [00:33<45:55,  2.07s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   2%|▊                                               | 24/1349 [01:03<1:01:48,  2.80s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   2%|█▏                                              | 32/1349 [01:44<1:19:51,  3.64s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   3%|█▍                                              | 40/1349 [02:24<1:30:29,  4.15s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   4%|█▋                                              | 48/1349 [03:33<2:01:24,  5.60s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   4%|█▉                                              | 56/1349 [04:26<2:08:06,  5.94s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   5%|██▎                                             | 64/1349 [04:52<1:48:46,  5.08s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   5%|██▌                                             | 72/1349 [05:38<1:52:49,  5.30s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   6%|██▊                                             | 80/1349 [06:25<1:55:54,  5.48s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   7%|███▏                                            | 88/1349 [07:12<1:57:37,  5.60s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   7%|███▍                                            | 96/1349 [07:55<1:55:40,  5.54s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   8%|███▌                                           | 104/1349 [08:45<1:58:56,  5.73s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   8%|███▉                                           | 112/1349 [09:17<1:47:41,  5.22s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   9%|████▏                                          | 120/1349 [10:06<1:52:28,  5.49s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   9%|████▍                                          | 128/1349 [10:50<1:51:47,  5.49s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  10%|████▋                                          | 136/1349 [11:35<1:52:10,  5.55s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  11%|█████                                          | 144/1349 [12:08<1:42:35,  5.11s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  11%|█████▎                                         | 152/1349 [12:47<1:40:40,  5.05s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  12%|█████▌                                         | 160/1349 [13:27<1:39:35,  5.03s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  12%|█████▊                                         | 168/1349 [14:04<1:36:51,  4.92s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  13%|██████▏                                        | 176/1349 [14:46<1:38:01,  5.01s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  14%|██████▍                                        | 184/1349 [15:14<1:28:29,  4.56s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  14%|██████▋                                        | 192/1349 [15:56<1:31:38,  4.75s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  15%|██████▉                                        | 200/1349 [16:41<1:36:29,  5.04s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  15%|███████▏                                       | 208/1349 [17:20<1:34:23,  4.96s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  16%|███████▌                                       | 216/1349 [17:56<1:31:03,  4.82s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  17%|███████▊                                       | 224/1349 [18:38<1:32:56,  4.96s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  17%|████████                                       | 232/1349 [19:20<1:34:01,  5.05s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  18%|████████▎                                      | 240/1349 [20:03<1:35:02,  5.14s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  18%|████████▋                                      | 248/1349 [20:54<1:41:07,  5.51s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  19%|████████▉                                      | 256/1349 [21:28<1:33:51,  5.15s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  20%|█████████▏                                     | 264/1349 [22:13<1:35:30,  5.28s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  20%|█████████▍                                     | 272/1349 [23:07<1:42:50,  5.73s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  21%|█████████▊                                     | 280/1349 [23:54<1:43:02,  5.78s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  21%|██████████                                     | 288/1349 [24:39<1:41:18,  5.73s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  22%|██████████▎                                    | 296/1349 [25:14<1:33:13,  5.31s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  23%|██████████▌                                    | 304/1349 [26:02<1:36:03,  5.52s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  23%|██████████▊                                    | 312/1349 [26:58<1:43:18,  5.98s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  24%|███████████▏                                   | 320/1349 [27:32<1:33:10,  5.43s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  24%|███████████▍                                   | 328/1349 [28:25<1:38:55,  5.81s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  25%|███████████▋                                   | 336/1349 [29:00<1:30:46,  5.38s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  26%|███████████▉                                   | 344/1349 [29:46<1:31:37,  5.47s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  26%|████████████▎                                  | 352/1349 [30:46<1:41:11,  6.09s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  27%|████████████▌                                  | 360/1349 [31:21<1:32:02,  5.58s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  27%|████████████▊                                  | 368/1349 [32:20<1:39:46,  6.10s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  28%|█████████████                                  | 376/1349 [33:10<1:39:59,  6.17s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  28%|█████████████▍                                 | 384/1349 [33:56<1:36:52,  6.02s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  29%|█████████████▋                                 | 392/1349 [34:40<1:33:43,  5.88s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  30%|█████████████▉                                 | 400/1349 [35:32<1:36:00,  6.07s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  30%|██████████████▏                                | 408/1349 [36:19<1:34:08,  6.00s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  31%|██████████████▍                                | 416/1349 [37:31<1:47:12,  6.89s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  31%|██████████████▊                                | 424/1349 [38:21<1:43:23,  6.71s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  32%|███████████████                                | 432/1349 [39:18<1:44:30,  6.84s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  33%|███████████████▎                               | 440/1349 [40:00<1:36:07,  6.35s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  33%|███████████████▌                               | 448/1349 [40:44<1:31:44,  6.11s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  34%|███████████████▉                               | 456/1349 [41:43<1:36:36,  6.49s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  34%|████████████████▏                              | 464/1349 [42:31<1:33:36,  6.35s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  35%|████████████████▍                              | 472/1349 [43:10<1:26:21,  5.91s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  36%|████████████████▋                              | 480/1349 [43:59<1:26:38,  5.98s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  36%|█████████████████                              | 488/1349 [44:37<1:20:07,  5.58s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  37%|█████████████████▎                             | 496/1349 [45:05<1:10:50,  4.98s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  37%|█████████████████▌                             | 504/1349 [45:55<1:15:22,  5.35s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  38%|█████████████████▊                             | 512/1349 [46:46<1:19:04,  5.67s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  39%|██████████████████                             | 520/1349 [47:22<1:13:03,  5.29s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  39%|██████████████████▍                            | 528/1349 [48:07<1:13:48,  5.39s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  40%|██████████████████▋                            | 536/1349 [48:45<1:10:34,  5.21s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  40%|██████████████████▉                            | 544/1349 [49:33<1:13:12,  5.46s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  41%|███████████████████▏                           | 552/1349 [50:09<1:08:26,  5.15s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  42%|███████████████████▌                           | 560/1349 [50:54<1:09:49,  5.31s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  42%|███████████████████▊                           | 568/1349 [51:28<1:04:44,  4.97s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  43%|████████████████████                           | 576/1349 [52:09<1:04:56,  5.04s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  43%|████████████████████▎                          | 584/1349 [52:48<1:03:39,  4.99s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  44%|█████████████████████▌                           | 592/1349 [53:17<57:51,  4.59s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  44%|█████████████████████▊                           | 600/1349 [53:52<56:15,  4.51s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  45%|██████████████████████                           | 608/1349 [54:29<55:55,  4.53s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  46%|██████████████████████▍                          | 616/1349 [55:06<55:45,  4.56s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  46%|██████████████████████▋                          | 624/1349 [55:37<52:44,  4.37s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  47%|██████████████████████▉                          | 632/1349 [56:29<59:58,  5.02s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  47%|██████████████████████▎                        | 640/1349 [57:21<1:04:30,  5.46s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  48%|██████████████████████▌                        | 648/1349 [58:00<1:01:50,  5.29s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  49%|███████████████████████▊                         | 656/1349 [58:35<57:45,  5.00s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  49%|███████████████████████▏                       | 664/1349 [59:23<1:00:23,  5.29s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  50%|██████████████████████▍                      | 672/1349 [1:00:06<1:00:01,  5.32s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  50%|███████████████████████▋                       | 680/1349 [1:00:32<52:34,  4.71s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  51%|███████████████████████▉                       | 688/1349 [1:01:24<57:34,  5.23s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  52%|████████████████████████▏                      | 696/1349 [1:02:04<56:11,  5.16s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  52%|████████████████████████▌                      | 704/1349 [1:02:40<53:25,  4.97s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  53%|████████████████████████▊                      | 712/1349 [1:03:22<53:48,  5.07s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  53%|█████████████████████████                      | 720/1349 [1:04:14<57:35,  5.49s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  54%|█████████████████████████▎                     | 728/1349 [1:04:54<55:23,  5.35s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  55%|████████████████████████▌                    | 736/1349 [1:05:53<1:00:43,  5.94s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  55%|█████████████████████████▉                     | 744/1349 [1:06:31<56:21,  5.59s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  56%|██████████████████████████▏                    | 752/1349 [1:07:14<55:01,  5.53s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  56%|██████████████████████████▍                    | 760/1349 [1:08:10<58:44,  5.98s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  57%|█████████████████████████▌                   | 768/1349 [1:09:04<1:00:08,  6.21s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  58%|███████████████████████████                    | 776/1349 [1:09:45<55:53,  5.85s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  58%|██████████████████████████▏                  | 784/1349 [1:10:47<1:00:39,  6.44s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  59%|██████████████████████████▍                  | 792/1349 [1:11:39<1:00:01,  6.47s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  59%|███████████████████████████▊                   | 800/1349 [1:12:11<52:16,  5.71s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  60%|████████████████████████████▏                  | 808/1349 [1:13:01<53:02,  5.88s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  60%|████████████████████████████▍                  | 816/1349 [1:13:56<54:54,  6.18s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  61%|███████████████████████████▍                 | 824/1349 [1:15:15<1:03:53,  7.30s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  61%|███████████████████████████▌                 | 825/1349 [1:15:16<1:00:34,  6.94s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  62%|████████████████████████████▉                  | 832/1349 [1:15:51<54:11,  6.29s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  62%|█████████████████████████████▎                 | 840/1349 [1:16:29<49:00,  5.78s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  63%|█████████████████████████████▌                 | 848/1349 [1:17:37<55:47,  6.68s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  63%|█████████████████████████████▊                 | 856/1349 [1:18:14<49:21,  6.01s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  64%|██████████████████████████████                 | 864/1349 [1:18:56<46:40,  5.77s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  65%|██████████████████████████████▍                | 872/1349 [1:19:51<48:25,  6.09s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  65%|██████████████████████████████▋                | 880/1349 [1:20:48<50:16,  6.43s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  66%|██████████████████████████████▉                | 888/1349 [1:21:34<47:41,  6.21s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  66%|███████████████████████████████                | 892/1349 [1:21:34<38:50,  5.10s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  66%|███████████████████████████████                | 892/1349 [1:21:51<38:50,  5.10s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  66%|███████████████████████████████▏               | 896/1349 [1:22:20<48:26,  6.42s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  67%|███████████████████████████████▍               | 904/1349 [1:23:02<44:16,  5.97s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  68%|███████████████████████████████▊               | 912/1349 [1:23:57<45:58,  6.31s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  68%|████████████████████████████████               | 920/1349 [1:24:46<44:33,  6.23s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  69%|████████████████████████████████▎              | 928/1349 [1:25:27<41:13,  5.88s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  69%|████████████████████████████████▌              | 936/1349 [1:26:23<42:51,  6.23s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  69%|████████████████████████████████▋              | 937/1349 [1:26:23<40:31,  5.90s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  69%|████████████████████████████████▋              | 937/1349 [1:26:41<40:31,  5.90s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  70%|████████████████████████████████▉              | 944/1349 [1:26:58<37:41,  5.58s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  71%|█████████████████████████████████▏             | 952/1349 [1:27:32<33:57,  5.13s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  71%|█████████████████████████████████▍             | 960/1349 [1:28:30<37:44,  5.82s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  72%|█████████████████████████████████▋             | 968/1349 [1:29:17<37:09,  5.85s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  72%|██████████████████████████████████             | 976/1349 [1:30:14<38:55,  6.26s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  73%|██████████████████████████████████▎            | 984/1349 [1:31:11<39:43,  6.53s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  73%|██████████████████████████████████▎            | 985/1349 [1:31:11<37:33,  6.19s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  73%|██████████████████████████████████▎            | 985/1349 [1:31:21<37:33,  6.19s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  74%|██████████████████████████████████▌            | 992/1349 [1:32:01<38:39,  6.50s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  74%|██████████████████████████████████            | 1000/1349 [1:32:57<38:54,  6.69s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  75%|██████████████████████████████████▎           | 1008/1349 [1:33:57<39:37,  6.97s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  75%|██████████████████████████████████▋           | 1016/1349 [1:34:29<33:17,  6.00s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  76%|██████████████████████████████████▉           | 1024/1349 [1:35:20<33:10,  6.12s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  77%|███████████████████████████████████▏          | 1032/1349 [1:36:03<31:05,  5.88s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  77%|███████████████████████████████████▍          | 1040/1349 [1:36:41<28:27,  5.52s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  78%|███████████████████████████████████▋          | 1048/1349 [1:37:15<25:47,  5.14s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  78%|████████████████████████████████████          | 1056/1349 [1:38:12<28:06,  5.76s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  79%|████████████████████████████████████▎         | 1064/1349 [1:38:50<25:46,  5.43s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  79%|████████████████████████████████████▌         | 1072/1349 [1:39:44<26:59,  5.85s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  80%|████████████████████████████████████▊         | 1080/1349 [1:40:36<26:58,  6.02s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  81%|█████████████████████████████████████         | 1088/1349 [1:41:17<25:05,  5.77s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  81%|█████████████████████████████████████▎        | 1096/1349 [1:42:16<26:18,  6.24s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  82%|█████████████████████████████████████▋        | 1104/1349 [1:43:00<24:34,  6.02s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  82%|█████████████████████████████████████▉        | 1112/1349 [1:43:33<21:29,  5.44s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  83%|██████████████████████████████████████▏       | 1120/1349 [1:44:14<20:29,  5.37s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  84%|██████████████████████████████████████▍       | 1128/1349 [1:45:07<21:11,  5.75s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  84%|██████████████████████████████████████▋       | 1136/1349 [1:46:06<22:05,  6.22s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  85%|███████████████████████████████████████       | 1144/1349 [1:46:47<20:06,  5.88s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  85%|███████████████████████████████████████▎      | 1152/1349 [1:47:28<18:35,  5.66s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  86%|███████████████████████████████████████▌      | 1160/1349 [1:48:03<16:37,  5.28s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  87%|███████████████████████████████████████▊      | 1168/1349 [1:48:41<15:30,  5.14s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  87%|████████████████████████████████████████      | 1176/1349 [1:49:24<14:58,  5.19s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  88%|████████████████████████████████████████▎     | 1184/1349 [1:50:22<15:57,  5.80s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  88%|████████████████████████████████████████▋     | 1192/1349 [1:50:57<14:06,  5.39s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  89%|████████████████████████████████████████▉     | 1200/1349 [1:51:43<13:39,  5.50s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  90%|█████████████████████████████████████████▏    | 1208/1349 [1:52:27<12:56,  5.51s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  90%|█████████████████████████████████████████▍    | 1216/1349 [1:53:10<12:07,  5.47s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  91%|█████████████████████████████████████████▋    | 1224/1349 [1:53:53<11:19,  5.43s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  91%|██████████████████████████████████████████    | 1232/1349 [1:54:30<10:04,  5.17s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  92%|██████████████████████████████████████████▎   | 1240/1349 [1:55:02<08:46,  4.83s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  93%|██████████████████████████████████████████▌   | 1248/1349 [1:55:52<08:50,  5.26s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  93%|██████████████████████████████████████████▊   | 1256/1349 [1:56:37<08:20,  5.38s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  94%|███████████████████████████████████████████   | 1264/1349 [1:57:31<08:10,  5.77s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  94%|███████████████████████████████████████████▎  | 1272/1349 [1:58:15<07:19,  5.71s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  95%|███████████████████████████████████████████▋  | 1280/1349 [1:59:00<06:32,  5.69s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  95%|███████████████████████████████████████████▉  | 1288/1349 [1:59:51<05:59,  5.89s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  96%|████████████████████████████████████████████▏ | 1296/1349 [2:00:21<04:37,  5.23s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  97%|████████████████████████████████████████████▍ | 1304/1349 [2:01:23<04:28,  5.98s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  97%|████████████████████████████████████████████▋ | 1312/1349 [2:02:00<03:27,  5.60s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  98%|█████████████████████████████████████████████ | 1320/1349 [2:02:44<02:41,  5.57s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  98%|█████████████████████████████████████████████▎| 1328/1349 [2:03:16<01:47,  5.10s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:  99%|█████████████████████████████████████████████▌| 1336/1349 [2:04:05<01:10,  5.39s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm: 100%|██████████████████████████████████████████████| 1349/1349 [2:04:41<00:00,  5.55s/it]
# Extracting second-order features NGTDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/train_nrm/PNEUMONIA_nrm
# Folder: train_nrm/PNEUMONIA_nrm:   0%|                                                        | 0/3883 [00:00<?, ?it/s]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   0%|▏                                              | 16/3883 [00:05<23:48,  2.71it/s]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▎                                            | 24/3883 [00:26<1:24:22,  1.31s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▎                                            | 32/3883 [00:43<1:41:18,  1.58s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▍                                            | 40/3883 [01:08<2:17:01,  2.14s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▌                                            | 48/3883 [01:40<2:55:06,  2.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   1%|▋                                            | 56/3883 [02:03<2:58:46,  2.80s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▋                                            | 64/3883 [02:19<2:42:46,  2.56s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▊                                            | 72/3883 [02:38<2:38:51,  2.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   2%|▉                                            | 80/3883 [02:58<2:38:24,  2.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   2%|█                                            | 88/3883 [03:19<2:39:21,  2.52s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   2%|█                                            | 96/3883 [03:39<2:38:46,  2.52s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▏                                          | 104/3883 [04:00<2:39:53,  2.54s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▎                                          | 112/3883 [04:15<2:26:36,  2.33s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▎                                          | 120/3883 [04:34<2:27:25,  2.35s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   3%|█▍                                          | 128/3883 [04:50<2:20:56,  2.25s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▌                                          | 136/3883 [05:06<2:15:05,  2.16s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▋                                          | 144/3883 [05:27<2:24:16,  2.32s/it]
#
#
#
# Folder: train_nrm/NORMAL_nrm:   0%|                                                         | 0/1349 [2:21:02<?, ?it/s]
# Folder: train_nrm/NORMAL_nrm:   1%|▍                                          | 15/1349 [2:19:26<206:41:08, 557.77s/it]
# Exception ignored in: <function ZipFile.__del__ at 0x1062a4220>
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/zipfile.py", line 1870, in __del__
#     self.close()
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/zipfile.py", line 1887, in close
#     self.fp.seek(self.start_dir)
# ValueError: seek of closed file
# Folder: train_nrm/NORMAL_nrm:   1%|▍                                          | 15/1349 [2:15:39<201:04:19, 542.62s/it]
#
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▊                                          | 160/3883 [06:05<2:23:14,  2.31s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   4%|█▉                                          | 168/3883 [06:25<2:26:22,  2.36s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   5%|█▉                                          | 176/3883 [06:46<2:30:22,  2.43s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██                                          | 184/3883 [07:13<2:48:44,  2.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▏                                         | 192/3883 [07:34<2:44:53,  2.68s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▎                                         | 200/3883 [07:46<2:23:26,  2.34s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   5%|██▎                                         | 208/3883 [08:09<2:34:13,  2.52s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▍                                         | 216/3883 [08:29<2:32:35,  2.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▌                                         | 224/3883 [08:47<2:26:59,  2.41s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▋                                         | 232/3883 [09:15<2:47:10,  2.75s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▋                                         | 240/3883 [09:33<2:39:04,  2.62s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   6%|██▊                                         | 248/3883 [09:45<2:17:16,  2.27s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   7%|██▉                                         | 256/3883 [10:11<2:34:44,  2.56s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   7%|██▉                                         | 264/3883 [10:25<2:20:44,  2.33s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███                                         | 272/3883 [10:38<2:07:40,  2.12s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▏                                        | 280/3883 [11:02<2:22:46,  2.38s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   7%|███▎                                        | 288/3883 [11:34<2:50:02,  2.84s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▎                                        | 296/3883 [11:54<2:44:34,  2.75s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▍                                        | 304/3883 [12:12<2:35:12,  2.60s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▌                                        | 312/3883 [12:29<2:25:39,  2.45s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▋                                        | 320/3883 [12:49<2:27:22,  2.48s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   8%|███▋                                        | 328/3883 [13:11<2:30:52,  2.55s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   9%|███▊                                        | 336/3883 [13:28<2:22:51,  2.42s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   9%|███▉                                        | 344/3883 [13:55<2:39:52,  2.71s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   9%|███▉                                        | 352/3883 [14:04<2:11:23,  2.23s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████                                        | 360/3883 [14:23<2:14:06,  2.28s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:   9%|████▏                                       | 368/3883 [14:34<1:58:48,  2.03s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▎                                       | 376/3883 [15:02<2:23:46,  2.46s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▎                                       | 384/3883 [15:27<2:34:46,  2.65s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▍                                       | 392/3883 [15:46<2:29:01,  2.56s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  10%|████▌                                       | 400/3883 [16:04<2:22:53,  2.46s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▌                                       | 408/3883 [16:21<2:18:08,  2.39s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▋                                       | 416/3883 [16:50<2:39:46,  2.77s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▊                                       | 424/3883 [17:11<2:36:18,  2.71s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▉                                       | 432/3883 [17:25<2:18:45,  2.41s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  11%|████▉                                       | 440/3883 [17:42<2:13:04,  2.32s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████                                       | 448/3883 [18:07<2:27:25,  2.57s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▏                                      | 456/3883 [18:21<2:13:03,  2.33s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▎                                      | 464/3883 [18:36<2:04:26,  2.18s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▎                                      | 472/3883 [18:50<1:56:33,  2.05s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  12%|█████▍                                      | 480/3883 [19:10<2:05:17,  2.21s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▌                                      | 488/3883 [19:39<2:28:36,  2.63s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▌                                      | 496/3883 [20:03<2:35:06,  2.75s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▋                                      | 504/3883 [20:17<2:17:52,  2.45s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▊                                      | 512/3883 [20:36<2:14:54,  2.40s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  13%|█████▉                                      | 520/3883 [20:58<2:21:24,  2.52s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  14%|█████▉                                      | 528/3883 [21:09<2:01:06,  2.17s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████                                      | 536/3883 [21:30<2:09:11,  2.32s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▏                                     | 544/3883 [21:52<2:14:55,  2.42s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▎                                     | 552/3883 [22:04<2:00:48,  2.18s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  14%|██████▎                                     | 560/3883 [22:27<2:10:41,  2.36s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▍                                     | 568/3883 [22:42<2:01:52,  2.21s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▌                                     | 576/3883 [23:04<2:10:36,  2.37s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▌                                     | 584/3883 [23:21<2:06:49,  2.31s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▋                                     | 592/3883 [23:44<2:16:51,  2.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  15%|██████▊                                     | 600/3883 [24:05<2:17:28,  2.51s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  16%|██████▉                                     | 608/3883 [24:18<2:03:34,  2.26s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  16%|██████▉                                     | 616/3883 [24:36<2:03:38,  2.27s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████                                     | 624/3883 [24:58<2:10:13,  2.40s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▏                                    | 632/3883 [25:17<2:10:23,  2.41s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  16%|███████▎                                    | 640/3883 [25:42<2:21:17,  2.61s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▎                                    | 648/3883 [25:57<2:08:24,  2.38s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▍                                    | 656/3883 [26:35<2:46:31,  3.10s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▌                                    | 664/3883 [27:00<2:46:09,  3.10s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  17%|███████▌                                    | 672/3883 [27:11<2:18:57,  2.60s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▋                                    | 680/3883 [27:45<2:43:55,  3.07s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▊                                    | 688/3883 [28:00<2:25:42,  2.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▉                                    | 696/3883 [28:18<2:16:51,  2.58s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  18%|███████▉                                    | 704/3883 [28:42<2:23:58,  2.72s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  18%|████████                                    | 712/3883 [28:57<2:10:25,  2.47s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▏                                   | 720/3883 [29:21<2:18:17,  2.62s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▏                                   | 728/3883 [29:34<2:00:50,  2.30s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▎                                   | 736/3883 [29:57<2:10:18,  2.48s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▍                                   | 744/3883 [30:27<2:29:31,  2.86s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  19%|████████▌                                   | 752/3883 [30:42<2:13:45,  2.56s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▌                                   | 760/3883 [31:10<2:27:49,  2.84s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▋                                   | 768/3883 [31:28<2:18:39,  2.67s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▊                                   | 776/3883 [31:47<2:13:54,  2.59s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▉                                   | 784/3883 [32:06<2:09:39,  2.51s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  20%|████████▉                                   | 792/3883 [32:46<2:49:14,  3.29s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████                                   | 800/3883 [33:05<2:34:53,  3.01s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▏                                  | 808/3883 [33:27<2:28:40,  2.90s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▏                                  | 816/3883 [33:50<2:28:37,  2.91s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▎                                  | 824/3883 [34:05<2:13:07,  2.61s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  21%|█████████▍                                  | 832/3883 [34:31<2:21:45,  2.79s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▌                                  | 840/3883 [34:57<2:29:01,  2.94s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▌                                  | 848/3883 [35:19<2:25:35,  2.88s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▋                                  | 856/3883 [35:42<2:25:11,  2.88s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▊                                  | 864/3883 [36:16<2:44:21,  3.27s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  22%|█████████▉                                  | 872/3883 [37:03<3:23:40,  4.06s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  23%|█████████▉                                  | 880/3883 [37:38<3:28:06,  4.16s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████                                  | 888/3883 [37:54<2:54:50,  3.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▏                                 | 896/3883 [38:19<2:48:26,  3.38s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▏                                 | 904/3883 [38:41<2:39:12,  3.21s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  23%|██████████▎                                 | 912/3883 [38:57<2:21:27,  2.86s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▍                                 | 920/3883 [39:34<2:47:03,  3.38s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▌                                 | 928/3883 [39:48<2:21:50,  2.88s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▌                                 | 936/3883 [40:05<2:10:53,  2.66s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  24%|██████████▋                                 | 944/3883 [40:26<2:10:09,  2.66s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  25%|██████████▊                                 | 952/3883 [41:00<2:33:41,  3.15s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  25%|██████████▉                                 | 960/3883 [41:21<2:25:14,  2.98s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  25%|██████████▉                                 | 968/3883 [41:42<2:19:12,  2.87s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████                                 | 976/3883 [41:57<2:05:15,  2.59s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  25%|███████████▏                                | 984/3883 [42:12<1:52:56,  2.34s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▏                                | 992/3883 [42:32<1:55:06,  2.39s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████                                | 1000/3883 [42:59<2:09:10,  2.69s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▏                               | 1008/3883 [43:13<1:55:22,  2.41s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▎                               | 1016/3883 [43:33<1:56:54,  2.45s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  26%|███████████▎                               | 1024/3883 [43:56<2:02:19,  2.57s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▍                               | 1032/3883 [44:13<1:55:26,  2.43s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▌                               | 1040/3883 [44:52<2:29:57,  3.16s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▌                               | 1048/3883 [45:14<2:24:15,  3.05s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▋                               | 1056/3883 [45:27<2:03:48,  2.63s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  27%|███████████▊                               | 1064/3883 [45:46<1:58:51,  2.53s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  28%|███████████▊                               | 1072/3883 [46:12<2:09:03,  2.75s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  28%|███████████▉                               | 1080/3883 [46:36<2:12:41,  2.84s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████                               | 1088/3883 [46:53<2:01:47,  2.61s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▏                              | 1096/3883 [47:18<2:08:43,  2.77s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  28%|████████████▏                              | 1104/3883 [47:32<1:54:20,  2.47s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▎                              | 1112/3883 [47:50<1:50:48,  2.40s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▍                              | 1120/3883 [48:15<2:00:39,  2.62s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▍                              | 1128/3883 [48:46<2:18:23,  3.01s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▌                              | 1136/3883 [49:20<2:33:21,  3.35s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  29%|████████████▋                              | 1144/3883 [49:40<2:22:40,  3.13s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  30%|████████████▊                              | 1152/3883 [49:58<2:10:25,  2.87s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  30%|████████████▊                              | 1160/3883 [50:26<2:18:07,  3.04s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  30%|████████████▉                              | 1168/3883 [50:42<2:02:52,  2.72s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████                              | 1176/3883 [50:59<1:54:58,  2.55s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  30%|█████████████                              | 1184/3883 [51:13<1:44:40,  2.33s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▏                             | 1192/3883 [51:39<1:55:50,  2.58s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▎                             | 1200/3883 [51:56<1:49:54,  2.46s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▍                             | 1208/3883 [52:29<2:11:06,  2.94s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  31%|█████████████▍                             | 1216/3883 [53:07<2:35:21,  3.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▌                             | 1224/3883 [53:22<2:12:58,  3.00s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▋                             | 1232/3883 [53:52<2:22:11,  3.22s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▋                             | 1240/3883 [54:13<2:15:13,  3.07s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▊                             | 1248/3883 [54:43<2:23:27,  3.27s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  32%|█████████████▉                             | 1256/3883 [55:05<2:16:37,  3.12s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  33%|█████████████▉                             | 1264/3883 [55:24<2:05:34,  2.88s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████                             | 1272/3883 [55:45<2:01:54,  2.80s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▏                            | 1280/3883 [56:02<1:52:59,  2.60s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▎                            | 1288/3883 [56:25<1:55:31,  2.67s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  33%|██████████████▎                            | 1296/3883 [57:00<2:18:01,  3.20s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▍                            | 1304/3883 [57:45<2:47:41,  3.90s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▌                            | 1312/3883 [58:09<2:36:09,  3.64s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▌                            | 1320/3883 [58:29<2:21:20,  3.31s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▋                            | 1328/3883 [58:47<2:08:02,  3.01s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  34%|██████████████▊                            | 1336/3883 [59:10<2:04:29,  2.93s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  35%|██████████████▉                            | 1344/3883 [59:26<1:53:19,  2.68s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  35%|██████████████▉                            | 1352/3883 [59:50<1:57:04,  2.78s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  35%|██████████████▎                          | 1360/3883 [1:00:11<1:55:10,  2.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  35%|██████████████▍                          | 1368/3883 [1:00:42<2:08:04,  3.06s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  35%|██████████████▌                          | 1376/3883 [1:01:11<2:14:28,  3.22s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  36%|██████████████▌                          | 1384/3883 [1:01:24<1:54:25,  2.75s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  36%|██████████████▋                          | 1392/3883 [1:01:35<1:37:22,  2.35s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  36%|██████████████▊                          | 1400/3883 [1:01:52<1:34:15,  2.28s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  36%|██████████████▊                          | 1408/3883 [1:02:17<1:44:46,  2.54s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  36%|██████████████▉                          | 1416/3883 [1:02:25<1:24:57,  2.07s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  37%|███████████████                          | 1424/3883 [1:02:45<1:30:31,  2.21s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  37%|███████████████                          | 1432/3883 [1:02:53<1:14:55,  1.83s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  37%|███████████████▏                         | 1440/3883 [1:03:06<1:11:29,  1.76s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  37%|████████████████                           | 1448/3883 [1:03:12<59:53,  1.48s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  37%|███████████████▎                         | 1456/3883 [1:03:31<1:11:01,  1.76s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  38%|███████████████▍                         | 1464/3883 [1:03:53<1:22:55,  2.06s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  38%|███████████████▌                         | 1472/3883 [1:04:01<1:09:15,  1.72s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  38%|███████████████▋                         | 1480/3883 [1:04:15<1:09:11,  1.73s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  38%|███████████████▋                         | 1488/3883 [1:04:30<1:10:05,  1.76s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  39%|███████████████▊                         | 1496/3883 [1:04:38<1:01:25,  1.54s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  39%|████████████████▋                          | 1504/3883 [1:04:49<59:25,  1.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  39%|███████████████▉                         | 1512/3883 [1:05:07<1:08:35,  1.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  39%|████████████████                         | 1520/3883 [1:05:38<1:33:25,  2.37s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  39%|████████████████▏                        | 1528/3883 [1:05:56<1:31:45,  2.34s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  40%|████████████████▏                        | 1536/3883 [1:06:10<1:24:35,  2.16s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  40%|████████████████▎                        | 1544/3883 [1:06:23<1:17:37,  1.99s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  40%|████████████████▍                        | 1552/3883 [1:06:44<1:24:39,  2.18s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  40%|████████████████▍                        | 1560/3883 [1:06:59<1:20:40,  2.08s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  40%|████████████████▌                        | 1568/3883 [1:07:21<1:27:49,  2.28s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  41%|████████████████▋                        | 1576/3883 [1:08:02<2:01:31,  3.16s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  41%|████████████████▋                        | 1584/3883 [1:08:19<1:48:31,  2.83s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  41%|████████████████▊                        | 1592/3883 [1:08:46<1:54:23,  3.00s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  41%|████████████████▉                        | 1600/3883 [1:09:03<1:43:34,  2.72s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  41%|████████████████▉                        | 1608/3883 [1:09:22<1:39:55,  2.64s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  42%|█████████████████                        | 1616/3883 [1:09:41<1:36:19,  2.55s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  42%|█████████████████▏                       | 1624/3883 [1:10:11<1:49:44,  2.91s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  42%|█████████████████▏                       | 1632/3883 [1:10:35<1:49:32,  2.92s/it]
#
#
#
# ...
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████▏          | 2912/3883 [1:58:06<33:25,  2.07s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████▎          | 2920/3883 [1:58:42<44:46,  2.79s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  75%|████████████████████████████████▍          | 2928/3883 [1:58:54<38:12,  2.40s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▌          | 2936/3883 [1:59:09<35:41,  2.26s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▌          | 2944/3883 [1:59:28<36:03,  2.30s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▋          | 2952/3883 [1:59:48<36:16,  2.34s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▊          | 2960/3883 [2:00:04<34:33,  2.25s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  76%|████████████████████████████████▊          | 2968/3883 [2:00:28<37:35,  2.46s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  77%|████████████████████████████████▉          | 2976/3883 [2:00:45<36:01,  2.38s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████          | 2984/3883 [2:01:02<34:14,  2.29s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████▏         | 2992/3883 [2:01:15<30:52,  2.08s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████▏         | 3000/3883 [2:01:31<30:25,  2.07s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  77%|█████████████████████████████████▎         | 3008/3883 [2:01:40<26:19,  1.81s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▍         | 3016/3883 [2:01:56<26:47,  1.85s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▍         | 3024/3883 [2:02:09<25:30,  1.78s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▌         | 3032/3883 [2:02:29<28:31,  2.01s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▋         | 3040/3883 [2:02:40<25:16,  1.80s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  78%|█████████████████████████████████▊         | 3048/3883 [2:02:53<24:14,  1.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  79%|█████████████████████████████████▊         | 3056/3883 [2:03:23<32:32,  2.36s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  79%|█████████████████████████████████▉         | 3064/3883 [2:03:41<31:28,  2.31s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  79%|██████████████████████████████████         | 3072/3883 [2:03:50<26:48,  1.98s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  79%|██████████████████████████████████         | 3080/3883 [2:04:06<26:13,  1.96s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▏        | 3088/3883 [2:04:22<26:14,  1.98s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▎        | 3096/3883 [2:04:39<26:39,  2.03s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▎        | 3104/3883 [2:04:55<26:21,  2.03s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▍        | 3112/3883 [2:05:05<23:06,  1.80s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  80%|██████████████████████████████████▌        | 3120/3883 [2:05:17<21:41,  1.71s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▋        | 3128/3883 [2:05:36<23:46,  1.89s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▋        | 3136/3883 [2:05:48<22:14,  1.79s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▊        | 3144/3883 [2:06:00<20:57,  1.70s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▉        | 3152/3883 [2:06:22<24:19,  2.00s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  81%|██████████████████████████████████▉        | 3160/3883 [2:06:35<22:55,  1.90s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████        | 3168/3883 [2:07:03<28:22,  2.38s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▏       | 3176/3883 [2:07:25<29:25,  2.50s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▎       | 3184/3883 [2:07:47<29:57,  2.57s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▎       | 3192/3883 [2:08:05<28:23,  2.47s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  82%|███████████████████████████████████▍       | 3200/3883 [2:08:28<29:29,  2.59s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▌       | 3208/3883 [2:08:42<26:05,  2.32s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▌       | 3216/3883 [2:09:05<27:39,  2.49s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▋       | 3224/3883 [2:09:26<27:47,  2.53s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▊       | 3232/3883 [2:09:35<23:02,  2.12s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  83%|███████████████████████████████████▉       | 3240/3883 [2:09:54<23:23,  2.18s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  84%|███████████████████████████████████▉       | 3248/3883 [2:10:09<22:21,  2.11s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████       | 3256/3883 [2:10:27<22:18,  2.14s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████▏      | 3264/3883 [2:10:45<22:27,  2.18s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████▏      | 3272/3883 [2:10:55<19:25,  1.91s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  84%|████████████████████████████████████▎      | 3280/3883 [2:11:12<19:53,  1.98s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▍      | 3288/3883 [2:11:30<20:25,  2.06s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▍      | 3296/3883 [2:11:47<20:23,  2.08s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▌      | 3304/3883 [2:12:03<19:52,  2.06s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  85%|████████████████████████████████████▋      | 3312/3883 [2:12:18<18:59,  2.00s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  86%|████████████████████████████████████▊      | 3320/3883 [2:12:27<16:01,  1.71s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  86%|████████████████████████████████████▊      | 3328/3883 [2:12:44<17:10,  1.86s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  86%|████████████████████████████████████▉      | 3336/3883 [2:13:01<17:43,  1.94s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  86%|█████████████████████████████████████      | 3344/3883 [2:13:15<16:53,  1.88s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  86%|█████████████████████████████████████      | 3352/3883 [2:13:28<15:58,  1.81s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▏     | 3360/3883 [2:13:42<15:35,  1.79s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▎     | 3368/3883 [2:14:06<18:29,  2.15s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▍     | 3376/3883 [2:14:24<18:24,  2.18s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▍     | 3384/3883 [2:14:36<16:24,  1.97s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  87%|█████████████████████████████████████▌     | 3392/3883 [2:14:45<13:53,  1.70s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▋     | 3400/3883 [2:14:56<13:06,  1.63s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▋     | 3408/3883 [2:15:12<13:47,  1.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▊     | 3416/3883 [2:15:37<16:43,  2.15s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  88%|█████████████████████████████████████▉     | 3424/3883 [2:15:57<17:12,  2.25s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  88%|██████████████████████████████████████     | 3432/3883 [2:16:15<16:52,  2.24s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████     | 3440/3883 [2:16:35<17:02,  2.31s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▏    | 3448/3883 [2:16:46<14:42,  2.03s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▎    | 3456/3883 [2:16:58<13:18,  1.87s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▎    | 3464/3883 [2:17:09<12:07,  1.74s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  89%|██████████████████████████████████████▍    | 3472/3883 [2:17:26<12:43,  1.86s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▌    | 3480/3883 [2:17:43<13:04,  1.95s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▋    | 3488/3883 [2:17:57<12:21,  1.88s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▋    | 3496/3883 [2:18:14<12:34,  1.95s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▊    | 3504/3883 [2:18:38<14:13,  2.25s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  90%|██████████████████████████████████████▉    | 3512/3883 [2:18:53<13:12,  2.14s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  91%|██████████████████████████████████████▉    | 3520/3883 [2:19:04<11:38,  1.92s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████    | 3528/3883 [2:19:20<11:37,  1.96s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████▏   | 3536/3883 [2:19:45<13:10,  2.28s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████▏   | 3544/3883 [2:20:10<14:30,  2.57s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  91%|███████████████████████████████████████▎   | 3552/3883 [2:20:31<14:09,  2.57s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▍   | 3560/3883 [2:20:53<14:09,  2.63s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▌   | 3568/3883 [2:21:27<16:13,  3.09s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▌   | 3576/3883 [2:21:59<17:11,  3.36s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  92%|███████████████████████████████████████▋   | 3584/3883 [2:22:24<16:25,  3.29s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  93%|███████████████████████████████████████▊   | 3592/3883 [2:22:43<14:46,  3.05s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  93%|███████████████████████████████████████▊   | 3600/3883 [2:22:57<12:24,  2.63s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  93%|███████████████████████████████████████▉   | 3608/3883 [2:23:12<11:06,  2.42s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  93%|████████████████████████████████████████   | 3616/3883 [2:23:29<10:25,  2.34s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  93%|████████████████████████████████████████▏  | 3624/3883 [2:23:48<10:03,  2.33s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▏  | 3632/3883 [2:24:08<09:55,  2.37s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▎  | 3640/3883 [2:24:28<09:49,  2.43s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▍  | 3648/3883 [2:24:44<08:56,  2.28s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▍  | 3656/3883 [2:25:03<08:48,  2.33s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  94%|████████████████████████████████████████▌  | 3664/3883 [2:25:22<08:29,  2.33s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▋  | 3672/3883 [2:25:37<07:48,  2.22s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▊  | 3680/3883 [2:25:56<07:33,  2.23s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▊  | 3688/3883 [2:26:09<06:44,  2.07s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  95%|████████████████████████████████████████▉  | 3696/3883 [2:26:38<07:55,  2.54s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  95%|█████████████████████████████████████████  | 3704/3883 [2:26:54<07:04,  2.37s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████  | 3712/3883 [2:27:15<06:58,  2.45s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▏ | 3720/3883 [2:27:27<05:54,  2.18s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▎ | 3728/3883 [2:27:41<05:14,  2.03s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▎ | 3736/3883 [2:27:54<04:41,  1.92s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  96%|█████████████████████████████████████████▍ | 3744/3883 [2:28:13<04:45,  2.06s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▌ | 3752/3883 [2:28:25<04:08,  1.90s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▋ | 3760/3883 [2:28:42<04:01,  1.97s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▋ | 3768/3883 [2:29:04<04:10,  2.17s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▊ | 3776/3883 [2:29:22<03:56,  2.21s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  97%|█████████████████████████████████████████▉ | 3784/3883 [2:29:35<03:20,  2.03s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  98%|█████████████████████████████████████████▉ | 3792/3883 [2:29:59<03:31,  2.32s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████ | 3800/3883 [2:30:13<03:00,  2.17s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████▏| 3808/3883 [2:30:32<02:46,  2.21s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████▎| 3816/3883 [2:30:52<02:34,  2.30s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  98%|██████████████████████████████████████████▎| 3824/3883 [2:31:06<02:06,  2.15s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▍| 3832/3883 [2:31:23<01:49,  2.14s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▌| 3840/3883 [2:31:49<01:45,  2.45s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▌| 3848/3883 [2:32:07<01:23,  2.40s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm:  99%|██████████████████████████████████████████▋| 3856/3883 [2:32:26<01:04,  2.39s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm: 100%|██████████████████████████████████████████▊| 3864/3883 [2:32:50<00:48,  2.57s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm: 100%|██████████████████████████████████████████▉| 3872/3883 [2:33:06<00:26,  2.39s/it]
#
#
#
# Folder: train_nrm/PNEUMONIA_nrm: 100%|███████████████████████████████████████████| 3883/3883 [2:33:23<00:00,  2.37s/it]
# Extracting second-order features NGTDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/NORMAL_nrm
# Folder: test_nrm/NORMAL_nrm: 100%|███████████████████████████████████████████████████| 234/234 [21:33<00:00,  5.53s/it]
# Extracting second-order features NGTDM from: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/dataset/chest_xray_nrm/test_nrm/PNEUMONIA_nrm
# Folder: test_nrm/PNEUMONIA_nrm: 100%|████████████████████████████████████████████████| 390/390 [12:36<00:00,  1.94s/it]
# All first-order features are extracted to the Excel file: /Users/raviteja/Documents/Teja_Career/Master_Degree/USD/MS_AAI/AAI-501/Final_Project/pneumonia-detection-in-chest-X-rays/image_information/chest_xray_images_second_order_features_ngtdm.xlsx
# Please check the Excel file for further analysis and interpretation
