# %% [markdown]
# ### Authors: Prof. Dr. Soumi Ray, Ravi Teja Kothuru and Abhay Srivastav
#
# ### Acknowledgements:
# I would like to thank my team mates Prof. Dr. Soumi Ray and Abhay Srivastav for their guidance and support throughout this project.
#
# **Title of the Project:** Comparative Analysis of Image-Based and Feature-Based Approaches for Pneumonia Detection in Chest X-rays
#
# **Description of the Project:** This project focuses on detecting pneumonia from chest X-ray images using Advanced Machine Learning and Deep Learning techniques (Rajpurkar et al., 2017; Wang et al., 2017). By leveraging a comprehensive dataset, including annotated images of pneumonia and normal cases, we aim to develop and compare image-based and feature-based approaches. Our goal is to identify the most effective method for accurate and interpretable pneumonia detection, contributing to improved patient outcomes through early diagnosis and treatment. This model will classify patients based on their chest X-ray images as either having pneumonia (1) or not having pneumonia (0).
#
# **Objectives of the Project:**
#
# - **Image Analysis:** Develop and evaluate deep learning models to classify chest X-rays directly. This approach leverages deep learning models, particularly Convolutional Neural Networks (CNNs), to perform end-to-end image classification. The models directly process raw chest X-ray images to classify them as normal or pneumonia.
#
# - **Feature Analysis:** Extract meaningful features from the images and use them to train and evaluate traditional machine learning models. In this approach, we first extract features from the chest X-ray images. These features are then used as inputs for traditional machine learning algorithms. The process includes steps such as feature extraction, selection, and transformation, followed by the application of machine learning techniques like Support Vector Machines (SVM), Random Forests.
#
# **Name of the Dataset:** The dataset used in this project is the Chest X-ray dataset considered from the Research paper named **Labeled Optical Coherence Tomography (OCT) and Chest X-Ray Images for Classification**.
#
# **Description of the Dataset:** The Diabetes Health Indicators Dataset contains healthcare statistics and lifestyle survey information about people in general along with their diagnosis of diabetes. The 35 features consist of some demographics, lab test results, and answers to survey questions for each patient. The target variable for classification is whether a patient has diabetes, is pre-diabetic, or healthy.
#
# **Dataset Source:**
#
# - https://data.mendeley.com/datasets/rscbjbr9sj/2
#
# **Type of the Dataset:**
#
# - X-ray Images
#
# **Description of Dataset:**
# The considered dataset has the following information for better reference:
# - Separate folders to train and validate/test the model.
# - Enough number of Chest X-ray images to train the model to detect and diagnose Pneumonia.
# - The target variable for classification is whether patient has pneumonia or not.
#
# **Goal of the Project using this Dataset:**
# The goal of this project is to conduct a comprehensive comparative analysis of image-based and feature-based approaches for pneumonia detection using chest X-ray images. By evaluating the performance, robustness, and interpretability of deep learning and traditional machine learning models, we aim to identify the most effective method for accurately classifying chest X-rays as normal or pneumonia. This comparison will provide valuable insights into the strengths and limitations of each approach, ultimately contributing to improved detection and diagnosis of pneumonia, which can enhance patient outcomes and survival rates.
#
# **Why did we choose this dataset?**
# We selected this dataset based on several factors. For more detailed information, please refer to the following:
# - The dataset is extensive, providing a large number of images suitable for evaluating and training deep learning models.
# - It aligns well with the project's objectives by offering a challenging and realistic scenario for developing an image classification model using deep learning, specifically for Chest X-ray images.
# - The dataset is annotated with images of two different diseases, enabling the development of a binary-class classification model.
# - It is publicly available, facilitating easy access for research and development purposes.
#
# **Size of dataset:**
# - Total images size = 1.27 GB
# - Dataset has 2 folders:
#   -  **Train:**
#         -  Normal (without Pneumonia) = 1349 images
#         -  Pneumonia = 3883 images
#   -  **Test:**
#         -  Normal (without Pneumonia) = 234 images
#         -  Pneumonia = 390 images
#
# **Expected Behaviors and Problem Handling:**
# - Classify Chest X-ray images with high accuracy.
# - Handle variations in image quality, resolution, and orientation.
# - Be robust to noise and artifacts in the images.
# - Provide interpretable results.
#
# **Issues to focus on:**
# - Improving model interpretability and explainability.
# - Optimizing model performance on a held-out test set.
# - Following AI Ethics and Data Safety practices.

# %% [markdown]
# # Import all the required files and libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pycaret.classification import *
import ssl
import seaborn as sns
import time

from sklearn.decomposition import PCA

# Disable SSL certificate verification
ssl._create_default_https_context = ssl._create_unverified_context


# Automatically reload imported modules when their source code changes
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2

# Import python files from local to use the corresponding function
from extracted_features_classification import ExtractedFeaturesClassification
from pneumonia_detector_constants import pneumonia_detector_constants as pdconst

# %% [markdown]
# # Analyze all features and classify

# %% [markdown]
# ## Create an object of the ExtractedFeaturesClassification class

# %%
efc = ExtractedFeaturesClassification()

# %% [markdown]
# ## Read excel file into Dataframe

# %%
xls_file_name = efc.merge_excel_files()

print(f"Path to the merged excel file: {xls_file_name}")
# Out:
# Path to the merged excel file: /Users/ravkothu/Documents/Personal_items_at_Oracle/Master_Degree/University_of_San_Diego/Online_Masters/MS_in_Applied_AI/Subjects_and_Resources/AAI-501_Introduction_to_AI/AAI-501_Final_Team_Project/pneumonia_detection/image_information/images_features_merged.xlsx

# %%
excel_sheet_names = pdconst["excel_sheet_names"]

df_train_nrm = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[0])
df_train_pneu = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[1])
df_test_nrm = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[2])
df_test_pneu = efc.load_excel_file_into_dataframe(xls_file_name, excel_sheet_names[3])

# %% [markdown]
# ## Add Target Column to all Dataframes

# %%
df_train_nrm, df_train_pneu, df_test_nrm, df_test_pneu = efc.add_target_column_to_dataframes(df_train_nrm, 
                                                                                             df_train_pneu, 
                                                                                             df_test_nrm, 
                                                                                             df_test_pneu)

# %% [markdown]
# ## Concatenate Dataframes and form train and test dataframes

# %%
df_train = efc.concatenate_dataframes(df_train_nrm, df_train_pneu)
df_test = efc.concatenate_dataframes(df_test_nrm, df_test_pneu)

# %%
# Identify columns to ignore (e.g., 'column_to_ignore1', 'column_to_ignore2')
columns_to_ignore = ['Image Filename']

# Drop the specified columns
filtered_df_train = df_train.drop(columns=columns_to_ignore)
filtered_df_test = df_test.drop(columns=columns_to_ignore)

# %% [markdown]
# ## Check Missing Values for safer side

# %%
missing_values_in_train_df = efc.check_missing_values_of_dataframe(filtered_df_train)

missing_values_in_test_df = efc.check_missing_values_of_dataframe(filtered_df_test)

print(f"Missing values in Train dataframe:\n{missing_values_in_train_df}")
print(f"\n\nMissing values in Test dataframe:\n{missing_values_in_test_df}")
# Out:
# Missing values in Train dataframe:
# Mean                     0
# Median                   0
# Standard Deviation       0
# Variance                 0
# Skewness                 0
#                         ..
# NGTDM_ClusterShade       0
# NGTDM_ClusterTendency    0
# NGTDM_Correlation        0
# NGTDM_Variance           0
# Pneumonia                0
# Length: 97, dtype: int64
#
#
# Missing values in Test dataframe:
# Mean                     0
# Median                   0
# Standard Deviation       0
# Variance                 0
# Skewness                 0
#                         ..
# NGTDM_ClusterShade       0
# NGTDM_ClusterTendency    0
# NGTDM_Correlation        0
# NGTDM_Variance           0
# Pneumonia                0
# Length: 97, dtype: int64

# %% [markdown]
# ## Plot Heatmap of all the features

# %%
from ipywidgets import widgets
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns

# Compute the correlation matrix
correlation_matrix = filtered_df_train.corr()

# Plot the heatmap
fig, ax = plt.subplots(figsize=(20, 16))  # Adjust size as needed
heatmap = sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt='.2f', linewidths=0.5, ax=ax)

# Rotate labels for better readability
plt.xticks(rotation=90, fontsize=8)
plt.yticks(rotation=0, fontsize=8)
plt.title('Correlation Heatmap', fontsize=14)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# # Perform PCA (Principal Component Analysis)

# %% [markdown]
# ## Train baseline models with provided dataframes using all the ML algorithms.
# ## Execute the required steps to compare multiple models, print classification report and return the best ML model for the passed dataframes.

# %% [markdown]
# ### PCA = 5 and 10 for train dataframe

# %%
# Create two PCA objects with different number of components for train dataframe
pca_5 = PCA(n_components=5)
pca_10 = PCA(n_components=10)

# Drop target column and assign to other variable
X_train_pca5 = filtered_df_train.drop('Pneumonia', axis=1)
X_train_pca10 = filtered_df_train.drop('Pneumonia', axis=1)

y_train_pca5 = filtered_df_train['Pneumonia']
y_train_pca10 = filtered_df_train['Pneumonia']

# Fit and transform the data using each PCA object
pca_train_data_5 = pca_5.fit_transform(X_train_pca5)
pca_train_data_10 = pca_10.fit_transform(X_train_pca10)

# Convert the transformed data back into Pandas DataFrames
train_pca_df_5 = pd.DataFrame(pca_train_data_5, columns=[f"PC{i+1}" for i in range(pca_train_data_5.shape[1])])
train_pca_df_10 = pd.DataFrame(pca_train_data_10, columns=[f"PC{i+1}" for i in range(pca_train_data_10.shape[1])])

# Add the target column back into the PCA-transformed DataFrames
train_pca_df_5 = pd.concat([train_pca_df_5, y_train_pca5], axis=1)
train_pca_df_10 = pd.concat([train_pca_df_10, y_train_pca10], axis=1)

print(f"Train dataframe PCA=5 shape: {train_pca_df_5.shape}")
print(f"Train dataframe PCA=10 shape: {train_pca_df_10.shape}")
# Out:
# Train dataframe PCA=5 shape: (5232, 6)
# Train dataframe PCA=10 shape: (5232, 11)

# %% [markdown]
# ### PCA = 5 and 10 for test dataframe

# %%
X_test_pca5 = filtered_df_test.drop('Pneumonia', axis=1)
X_test_pca10 = filtered_df_test.drop('Pneumonia', axis=1)

y_test_pca5 = filtered_df_test['Pneumonia']
y_test_pca10 = filtered_df_test['Pneumonia']

# Fit and transform the data using each PCA object
pca_test_data_5 = pca_5.transform(X_test_pca5)
pca_test_data_10 = pca_10.transform(X_test_pca10)

# Convert the transformed data back into Pandas DataFrames
test_pca_df_5 = pd.DataFrame(pca_test_data_5, columns=[f"PC{i+1}" for i in range(pca_test_data_5.shape[1])])
test_pca_df_10 = pd.DataFrame(pca_test_data_10, columns=[f"PC{i+1}" for i in range(pca_test_data_10.shape[1])])

# Add the target column back into the PCA-transformed DataFrames
test_pca_df_5 = pd.concat([test_pca_df_5, y_test_pca5], axis=1)
test_pca_df_10 = pd.concat([test_pca_df_10, y_test_pca10], axis=1)

print(f"Test dataframe PCA=5 shape: {test_pca_df_5.shape}")
print(f"Test dataframe PCA=10 shape: {test_pca_df_10.shape}")
# Out:
# Test dataframe PCA=5 shape: (624, 6)
# Test dataframe PCA=10 shape: (624, 11)

# %% [markdown]
# ### PCA = 5 for train dataframe

# %%
start_time = time.time()

best_model_for_pca5 = efc.train_multiple_ml_models(train_pca_df_5)

end_time = time.time()

# Calculate the total time taken
total_time_seconds = end_time - start_time

# Convert the time to minutes and seconds
total_time_minutes = total_time_seconds // 60
total_time_seconds = total_time_seconds % 60

# Print the results
print(f"\nTotal time to execute: {int(total_time_minutes)} minutes and {total_time_seconds:.2f} seconds")
# Out:
# <style type="text/css">
# #T_e617d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e617d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e617d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e617d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e617d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e617d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e617d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e617d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e617d_row1_col1" class="data row1 col1" >Pneumonia</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e617d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e617d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e617d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e617d_row3_col1" class="data row3 col1" >(5232, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e617d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e617d_row4_col1" class="data row4 col1" >(5232, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e617d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e617d_row5_col1" class="data row5 col1" >(3662, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e617d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e617d_row6_col1" class="data row6 col1" >(1570, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e617d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_e617d_row7_col1" class="data row7 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e617d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_e617d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e617d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_e617d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e617d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_e617d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e617d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_e617d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e617d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_e617d_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e617d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_e617d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e617d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_e617d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e617d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_e617d_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e617d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_e617d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e617d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_e617d_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e617d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e617d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_e617d_row18_col1" class="data row18 col1" >3781</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_75256 th {
#   text-align: left;
# }
# #T_75256_row0_col0, #T_75256_row0_col2, #T_75256_row0_col3, #T_75256_row0_col4, #T_75256_row1_col0, #T_75256_row1_col1, #T_75256_row1_col2, #T_75256_row1_col3, #T_75256_row1_col5, #T_75256_row1_col6, #T_75256_row1_col7, #T_75256_row2_col0, #T_75256_row2_col1, #T_75256_row2_col2, #T_75256_row2_col3, #T_75256_row2_col4, #T_75256_row2_col5, #T_75256_row2_col6, #T_75256_row2_col7, #T_75256_row3_col0, #T_75256_row3_col1, #T_75256_row3_col3, #T_75256_row3_col4, #T_75256_row3_col5, #T_75256_row3_col6, #T_75256_row3_col7, #T_75256_row4_col0, #T_75256_row4_col1, #T_75256_row4_col2, #T_75256_row4_col3, #T_75256_row4_col4, #T_75256_row4_col5, #T_75256_row4_col6, #T_75256_row4_col7, #T_75256_row5_col0, #T_75256_row5_col1, #T_75256_row5_col2, #T_75256_row5_col3, #T_75256_row5_col4, #T_75256_row5_col5, #T_75256_row5_col6, #T_75256_row5_col7, #T_75256_row6_col0, #T_75256_row6_col1, #T_75256_row6_col2, #T_75256_row6_col3, #T_75256_row6_col4, #T_75256_row6_col5, #T_75256_row6_col6, #T_75256_row6_col7, #T_75256_row7_col0, #T_75256_row7_col1, #T_75256_row7_col2, #T_75256_row7_col3, #T_75256_row7_col4, #T_75256_row7_col5, #T_75256_row7_col6, #T_75256_row7_col7, #T_75256_row8_col0, #T_75256_row8_col1, #T_75256_row8_col2, #T_75256_row8_col3, #T_75256_row8_col4, #T_75256_row8_col5, #T_75256_row8_col6, #T_75256_row8_col7, #T_75256_row9_col0, #T_75256_row9_col1, #T_75256_row9_col2, #T_75256_row9_col3, #T_75256_row9_col4, #T_75256_row9_col5, #T_75256_row9_col6, #T_75256_row9_col7, #T_75256_row10_col0, #T_75256_row10_col1, #T_75256_row10_col2, #T_75256_row10_col4, #T_75256_row10_col5, #T_75256_row10_col6, #T_75256_row10_col7, #T_75256_row11_col0, #T_75256_row11_col1, #T_75256_row11_col2, #T_75256_row11_col3, #T_75256_row11_col4, #T_75256_row11_col5, #T_75256_row11_col6, #T_75256_row11_col7, #T_75256_row12_col0, #T_75256_row12_col1, #T_75256_row12_col2, #T_75256_row12_col3, #T_75256_row12_col4, #T_75256_row12_col5, #T_75256_row12_col6, #T_75256_row12_col7, #T_75256_row13_col0, #T_75256_row13_col1, #T_75256_row13_col2, #T_75256_row13_col3, #T_75256_row13_col4, #T_75256_row13_col5, #T_75256_row13_col6, #T_75256_row13_col7 {
#   text-align: left;
# }
# #T_75256_row0_col1, #T_75256_row0_col5, #T_75256_row0_col6, #T_75256_row0_col7, #T_75256_row1_col4, #T_75256_row3_col2, #T_75256_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_75256_row0_col8, #T_75256_row1_col8, #T_75256_row2_col8, #T_75256_row3_col8, #T_75256_row4_col8, #T_75256_row5_col8, #T_75256_row6_col8, #T_75256_row7_col8, #T_75256_row8_col8, #T_75256_row9_col8, #T_75256_row11_col8, #T_75256_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_75256_row10_col8, #T_75256_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_75256">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_75256_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_75256_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_75256_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_75256_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_75256_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_75256_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_75256_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_75256_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_75256_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_75256_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_75256_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_75256_row0_col1" class="data row0 col1" >0.9402</td>
#       <td id="T_75256_row0_col2" class="data row0 col2" >0.9779</td>
#       <td id="T_75256_row0_col3" class="data row0 col3" >0.9581</td>
#       <td id="T_75256_row0_col4" class="data row0 col4" >0.9613</td>
#       <td id="T_75256_row0_col5" class="data row0 col5" >0.9596</td>
#       <td id="T_75256_row0_col6" class="data row0 col6" >0.8445</td>
#       <td id="T_75256_row0_col7" class="data row0 col7" >0.8451</td>
#       <td id="T_75256_row0_col8" class="data row0 col8" >0.0650</td>
#     </tr>
#     <tr>
#       <th id="T_75256_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_75256_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_75256_row1_col1" class="data row1 col1" >0.9394</td>
#       <td id="T_75256_row1_col2" class="data row1 col2" >0.9782</td>
#       <td id="T_75256_row1_col3" class="data row1 col3" >0.9562</td>
#       <td id="T_75256_row1_col4" class="data row1 col4" >0.9620</td>
#       <td id="T_75256_row1_col5" class="data row1 col5" >0.9590</td>
#       <td id="T_75256_row1_col6" class="data row1 col6" >0.8428</td>
#       <td id="T_75256_row1_col7" class="data row1 col7" >0.8437</td>
#       <td id="T_75256_row1_col8" class="data row1 col8" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_75256_level0_row2" class="row_heading level0 row2" >gbc</th>
#       <td id="T_75256_row2_col0" class="data row2 col0" >Gradient Boosting Classifier</td>
#       <td id="T_75256_row2_col1" class="data row2 col1" >0.9383</td>
#       <td id="T_75256_row2_col2" class="data row2 col2" >0.9796</td>
#       <td id="T_75256_row2_col3" class="data row2 col3" >0.9569</td>
#       <td id="T_75256_row2_col4" class="data row2 col4" >0.9600</td>
#       <td id="T_75256_row2_col5" class="data row2 col5" >0.9583</td>
#       <td id="T_75256_row2_col6" class="data row2 col6" >0.8393</td>
#       <td id="T_75256_row2_col7" class="data row2 col7" >0.8402</td>
#       <td id="T_75256_row2_col8" class="data row2 col8" >0.1120</td>
#     </tr>
#     <tr>
#       <th id="T_75256_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_75256_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_75256_row3_col1" class="data row3 col1" >0.9369</td>
#       <td id="T_75256_row3_col2" class="data row3 col2" >0.9799</td>
#       <td id="T_75256_row3_col3" class="data row3 col3" >0.9562</td>
#       <td id="T_75256_row3_col4" class="data row3 col4" >0.9588</td>
#       <td id="T_75256_row3_col5" class="data row3 col5" >0.9574</td>
#       <td id="T_75256_row3_col6" class="data row3 col6" >0.8357</td>
#       <td id="T_75256_row3_col7" class="data row3 col7" >0.8365</td>
#       <td id="T_75256_row3_col8" class="data row3 col8" >0.2980</td>
#     </tr>
#     <tr>
#       <th id="T_75256_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_75256_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_75256_row4_col1" class="data row4 col1" >0.9334</td>
#       <td id="T_75256_row4_col2" class="data row4 col2" >0.9783</td>
#       <td id="T_75256_row4_col3" class="data row4 col3" >0.9536</td>
#       <td id="T_75256_row4_col4" class="data row4 col4" >0.9566</td>
#       <td id="T_75256_row4_col5" class="data row4 col5" >0.9550</td>
#       <td id="T_75256_row4_col6" class="data row4 col6" >0.8266</td>
#       <td id="T_75256_row4_col7" class="data row4 col7" >0.8273</td>
#       <td id="T_75256_row4_col8" class="data row4 col8" >0.0500</td>
#     </tr>
#     <tr>
#       <th id="T_75256_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_75256_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_75256_row5_col1" class="data row5 col1" >0.9320</td>
#       <td id="T_75256_row5_col2" class="data row5 col2" >0.9762</td>
#       <td id="T_75256_row5_col3" class="data row5 col3" >0.9559</td>
#       <td id="T_75256_row5_col4" class="data row5 col4" >0.9528</td>
#       <td id="T_75256_row5_col5" class="data row5 col5" >0.9542</td>
#       <td id="T_75256_row5_col6" class="data row5 col6" >0.8218</td>
#       <td id="T_75256_row5_col7" class="data row5 col7" >0.8224<
# Total time to execute: 0 minutes and 8.43 seconds

# %%
best_model_for_pca5
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %% [markdown]
# #### Train and evaluate the performance of Random Forest Classifier using cross validation as well as Hyperparameters

# %%
random_forest_all_pca5 = create_model('rf', bootstrap=True, ccp_alpha=0.0, class_weight=None,
                                      criterion='gini', max_depth=None, max_features='sqrt',
                                      max_leaf_nodes=None, max_samples=None,
                                      min_impurity_decrease=0.0, min_samples_leaf=1,
                                      min_samples_split=2, min_weight_fraction_leaf=0.0,
                                      monotonic_cst=None, n_estimators=100, n_jobs=-1,
                                      oob_score=False, random_state=123, verbose=True,
                                      warm_start=False)
# Out:
# <style type="text/css">
# #T_7b91a_row10_col0, #T_7b91a_row10_col1, #T_7b91a_row10_col2, #T_7b91a_row10_col3, #T_7b91a_row10_col4, #T_7b91a_row10_col5, #T_7b91a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7b91a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b91a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7b91a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7b91a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7b91a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7b91a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7b91a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7b91a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b91a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b91a_row0_col0" class="data row0 col0" >0.9482</td>
#       <td id="T_7b91a_row0_col1" class="data row0 col1" >0.9834</td>
#       <td id="T_7b91a_row0_col2" class="data row0 col2" >0.9596</td>
#       <td id="T_7b91a_row0_col3" class="data row0 col3" >0.9703</td>
#       <td id="T_7b91a_row0_col4" class="data row0 col4" >0.9649</td>
#       <td id="T_7b91a_row0_col5" class="data row0 col5" >0.8664</td>
#       <td id="T_7b91a_row0_col6" class="data row0 col6" >0.8666</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7b91a_row1_col0" class="data row1 col0" >0.9373</td>
#       <td id="T_7b91a_row1_col1" class="data row1 col1" >0.9780</td>
#       <td id="T_7b91a_row1_col2" class="data row1 col2" >0.9559</td>
#       <td id="T_7b91a_row1_col3" class="data row1 col3" >0.9594</td>
#       <td id="T_7b91a_row1_col4" class="data row1 col4" >0.9576</td>
#       <td id="T_7b91a_row1_col5" class="data row1 col5" >0.8372</td>
#       <td id="T_7b91a_row1_col6" class="data row1 col6" >0.8372</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7b91a_row2_col0" class="data row2 col0" >0.9372</td>
#       <td id="T_7b91a_row2_col1" class="data row2 col1" >0.9757</td>
#       <td id="T_7b91a_row2_col2" class="data row2 col2" >0.9485</td>
#       <td id="T_7b91a_row2_col3" class="data row2 col3" >0.9663</td>
#       <td id="T_7b91a_row2_col4" class="data row2 col4" >0.9573</td>
#       <td id="T_7b91a_row2_col5" class="data row2 col5" >0.8382</td>
#       <td id="T_7b91a_row2_col6" class="data row2 col6" >0.8387</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7b91a_row3_col0" class="data row3 col0" >0.9536</td>
#       <td id="T_7b91a_row3_col1" class="data row3 col1" >0.9835</td>
#       <td id="T_7b91a_row3_col2" class="data row3 col2" >0.9816</td>
#       <td id="T_7b91a_row3_col3" class="data row3 col3" >0.9570</td>
#       <td id="T_7b91a_row3_col4" class="data row3 col4" >0.9691</td>
#       <td id="T_7b91a_row3_col5" class="data row3 col5" >0.8753</td>
#       <td id="T_7b91a_row3_col6" class="data row3 col6" >0.8764</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7b91a_row4_col0" class="data row4 col0" >0.9344</td>
#       <td id="T_7b91a_row4_col1" class="data row4 col1" >0.9788</td>
#       <td id="T_7b91a_row4_col2" class="data row4 col2" >0.9596</td>
#       <td id="T_7b91a_row4_col3" class="data row4 col3" >0.9526</td>
#       <td id="T_7b91a_row4_col4" class="data row4 col4" >0.9560</td>
#       <td id="T_7b91a_row4_col5" class="data row4 col5" >0.8270</td>
#       <td id="T_7b91a_row4_col6" class="data row4 col6" >0.8271</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7b91a_row5_col0" class="data row5 col0" >0.9617</td>
#       <td id="T_7b91a_row5_col1" class="data row5 col1" >0.9881</td>
#       <td id="T_7b91a_row5_col2" class="data row5 col2" >0.9669</td>
#       <td id="T_7b91a_row5_col3" class="data row5 col3" >0.9813</td>
#       <td id="T_7b91a_row5_col4" class="data row5 col4" >0.9741</td>
#       <td id="T_7b91a_row5_col5" class="data row5 col5" >0.9012</td>
#       <td id="T_7b91a_row5_col6" class="data row5 col6" >0.9015</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7b91a_row6_col0" class="data row6 col0" >0.9098</td>
#       <td id="T_7b91a_row6_col1" class="data row6 col1" >0.9687</td>
#       <td id="T_7b91a_row6_col2" class="data row6 col2" >0.9228</td>
#       <td id="T_7b91a_row6_col3" class="data row6 col3" >0.9544</td>
#       <td id="T_7b91a_row6_col4" class="data row6 col4" >0.9383</td>
#       <td id="T_7b91a_row6_col5" class="data row6 col5" >0.7710</td>
#       <td id="T_7b91a_row6_col6" class="data row6 col6" >0.7725</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7b91a_row7_col0" class="data row7 col0" >0.9508</td>
#       <td id="T_7b91a_row7_col1" class="data row7 col1" >0.9713</td>
#       <td id="T_7b91a_row7_col2" class="data row7 col2" >0.9779</td>
#       <td id="T_7b91a_row7_col3" class="data row7 col3" >0.9568</td>
#       <td id="T_7b91a_row7_col4" class="data row7 col4" >0.9673</td>
#       <td id="T_7b91a_row7_col5" class="data row7 col5" >0.8684</td>
#       <td id="T_7b91a_row7_col6" class="data row7 col6" >0.8693</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7b91a_row8_col0" class="data row8 col0" >0.9372</td>
#       <td id="T_7b91a_row8_col1" class="data row8 col1" >0.9820</td>
#       <td id="T_7b91a_row8_col2" class="data row8 col2" >0.9668</td>
#       <td id="T_7b91a_row8_col3" class="data row8 col3" >0.9493</td>
#       <td id="T_7b91a_row8_col4" class="data row8 col4" >0.9580</td>
#       <td id="T_7b91a_row8_col5" class="data row8 col5" >0.8337</td>
#       <td id="T_7b91a_row8_col6" class="data row8 col6" >0.8342</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7b91a_row9_col0" class="data row9 col0" >0.9317</td>
#       <td id="T_7b91a_row9_col1" class="data row9 col1" >0.9691</td>
#       <td id="T_7b91a_row9_col2" class="data row9 col2" >0.9410</td>
#       <td id="T_7b91a_row9_col3" class="data row9 col3" >0.9659</td>
#       <td id="T_7b91a_row9_col4" class="data row9 col4" >0.9533</td>
#       <td id="T_7b91a_row9_col5" class="data row9 col5" >0.8264</td>
#       <td id="T_7b91a_row9_col6" class="data row9 col6" >0.8274</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7b91a_row10_col0" class="data row10 col0" >0.9402</td>
#       <td id="T_7b91a_row10_col1" class="data row10 col1" >0.9779</td>
#       <td id="T_7b91a_row10_col2" class="data row10 col2" >0.9581</td>
#       <td id="T_7b91a_row10_col3" class="data row10 col3" >0.9613</td>
#       <td id="T_7b91a_row10_col4" class="data row10 col4" >0.9596</td>
#       <td id="T_7b91a_row10_col5" class="data row10 col5" >0.8445</td>
#       <td id="T_7b91a_row10_col6" class="data row10 col6" >0.8451</td>
#     </tr>
#     <tr>
#       <th id="T_7b91a_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7b91a_row11_col0" class="data row11 col0" >0.0137</td>
#       <td id="T_7b91a_row11_col1" class="data row11 col1" >0.0063</td>
#       <td id="T_7b91a_row11_col2" class="data row11 col2" >0.0166</td>
#       <td id="T_7b91a_row11_col3" class="data row11 col3" >0.0092</td>
#       <td id="T_7b91a_row11_col4

# %%
tuned_random_forest_all_pca5 = tune_model(random_forest_all_pca5)
# Out:
# <style type="text/css">
# #T_9c41c_row10_col0, #T_9c41c_row10_col1, #T_9c41c_row10_col2, #T_9c41c_row10_col3, #T_9c41c_row10_col4, #T_9c41c_row10_col5, #T_9c41c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9c41c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c41c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9c41c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9c41c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9c41c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9c41c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9c41c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9c41c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c41c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9c41c_row0_col0" class="data row0 col0" >0.9346</td>
#       <td id="T_9c41c_row0_col1" class="data row0 col1" >0.9796</td>
#       <td id="T_9c41c_row0_col2" class="data row0 col2" >0.9632</td>
#       <td id="T_9c41c_row0_col3" class="data row0 col3" >0.9493</td>
#       <td id="T_9c41c_row0_col4" class="data row0 col4" >0.9562</td>
#       <td id="T_9c41c_row0_col5" class="data row0 col5" >0.8272</td>
#       <td id="T_9c41c_row0_col6" class="data row0 col6" >0.8275</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9c41c_row1_col0" class="data row1 col0" >0.9319</td>
#       <td id="T_9c41c_row1_col1" class="data row1 col1" >0.9673</td>
#       <td id="T_9c41c_row1_col2" class="data row1 col2" >0.9632</td>
#       <td id="T_9c41c_row1_col3" class="data row1 col3" >0.9458</td>
#       <td id="T_9c41c_row1_col4" class="data row1 col4" >0.9545</td>
#       <td id="T_9c41c_row1_col5" class="data row1 col5" >0.8194</td>
#       <td id="T_9c41c_row1_col6" class="data row1 col6" >0.8199</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9c41c_row2_col0" class="data row2 col0" >0.9098</td>
#       <td id="T_9c41c_row2_col1" class="data row2 col1" >0.9577</td>
#       <td id="T_9c41c_row2_col2" class="data row2 col2" >0.9301</td>
#       <td id="T_9c41c_row2_col3" class="data row2 col3" >0.9476</td>
#       <td id="T_9c41c_row2_col4" class="data row2 col4" >0.9388</td>
#       <td id="T_9c41c_row2_col5" class="data row2 col5" >0.7678</td>
#       <td id="T_9c41c_row2_col6" class="data row2 col6" >0.7683</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9c41c_row3_col0" class="data row3 col0" >0.9208</td>
#       <td id="T_9c41c_row3_col1" class="data row3 col1" >0.9636</td>
#       <td id="T_9c41c_row3_col2" class="data row3 col2" >0.9485</td>
#       <td id="T_9c41c_row3_col3" class="data row3 col3" >0.9451</td>
#       <td id="T_9c41c_row3_col4" class="data row3 col4" >0.9468</td>
#       <td id="T_9c41c_row3_col5" class="data row3 col5" >0.7917</td>
#       <td id="T_9c41c_row3_col6" class="data row3 col6" >0.7917</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9c41c_row4_col0" class="data row4 col0" >0.9262</td>
#       <td id="T_9c41c_row4_col1" class="data row4 col1" >0.9688</td>
#       <td id="T_9c41c_row4_col2" class="data row4 col2" >0.9596</td>
#       <td id="T_9c41c_row4_col3" class="data row4 col3" >0.9422</td>
#       <td id="T_9c41c_row4_col4" class="data row4 col4" >0.9508</td>
#       <td id="T_9c41c_row4_col5" class="data row4 col5" >0.8033</td>
#       <td id="T_9c41c_row4_col6" class="data row4 col6" >0.8039</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9c41c_row5_col0" class="data row5 col0" >0.9399</td>
#       <td id="T_9c41c_row5_col1" class="data row5 col1" >0.9803</td>
#       <td id="T_9c41c_row5_col2" class="data row5 col2" >0.9449</td>
#       <td id="T_9c41c_row5_col3" class="data row5 col3" >0.9735</td>
#       <td id="T_9c41c_row5_col4" class="data row5 col4" >0.9590</td>
#       <td id="T_9c41c_row5_col5" class="data row5 col5" >0.8468</td>
#       <td id="T_9c41c_row5_col6" class="data row5 col6" >0.8481</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9c41c_row6_col0" class="data row6 col0" >0.8907</td>
#       <td id="T_9c41c_row6_col1" class="data row6 col1" >0.9392</td>
#       <td id="T_9c41c_row6_col2" class="data row6 col2" >0.9154</td>
#       <td id="T_9c41c_row6_col3" class="data row6 col3" >0.9361</td>
#       <td id="T_9c41c_row6_col4" class="data row6 col4" >0.9257</td>
#       <td id="T_9c41c_row6_col5" class="data row6 col5" >0.7196</td>
#       <td id="T_9c41c_row6_col6" class="data row6 col6" >0.7202</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9c41c_row7_col0" class="data row7 col0" >0.9262</td>
#       <td id="T_9c41c_row7_col1" class="data row7 col1" >0.9528</td>
#       <td id="T_9c41c_row7_col2" class="data row7 col2" >0.9669</td>
#       <td id="T_9c41c_row7_col3" class="data row7 col3" >0.9359</td>
#       <td id="T_9c41c_row7_col4" class="data row7 col4" >0.9512</td>
#       <td id="T_9c41c_row7_col5" class="data row7 col5" >0.8005</td>
#       <td id="T_9c41c_row7_col6" class="data row7 col6" >0.8023</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9c41c_row8_col0" class="data row8 col0" >0.9153</td>
#       <td id="T_9c41c_row8_col1" class="data row8 col1" >0.9726</td>
#       <td id="T_9c41c_row8_col2" class="data row8 col2" >0.9631</td>
#       <td id="T_9c41c_row8_col3" class="data row8 col3" >0.9255</td>
#       <td id="T_9c41c_row8_col4" class="data row8 col4" >0.9439</td>
#       <td id="T_9c41c_row8_col5" class="data row8 col5" >0.7710</td>
#       <td id="T_9c41c_row8_col6" class="data row8 col6" >0.7736</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9c41c_row9_col0" class="data row9 col0" >0.9235</td>
#       <td id="T_9c41c_row9_col1" class="data row9 col1" >0.9598</td>
#       <td id="T_9c41c_row9_col2" class="data row9 col2" >0.9446</td>
#       <td id="T_9c41c_row9_col3" class="data row9 col3" >0.9517</td>
#       <td id="T_9c41c_row9_col4" class="data row9 col4" >0.9481</td>
#       <td id="T_9c41c_row9_col5" class="data row9 col5" >0.8023</td>
#       <td id="T_9c41c_row9_col6" class="data row9 col6" >0.8024</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9c41c_row10_col0" class="data row10 col0" >0.9219</td>
#       <td id="T_9c41c_row10_col1" class="data row10 col1" >0.9642</td>
#       <td id="T_9c41c_row10_col2" class="data row10 col2" >0.9500</td>
#       <td id="T_9c41c_row10_col3" class="data row10 col3" >0.9453</td>
#       <td id="T_9c41c_row10_col4" class="data row10 col4" >0.9475</td>
#       <td id="T_9c41c_row10_col5" class="data row10 col5" >0.7950</td>
#       <td id="T_9c41c_row10_col6" class="data row10 col6" >0.7958</td>
#     </tr>
#     <tr>
#       <th id="T_9c41c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9c41c_row11_col0" class="data row11 col0" >0.0134</td>
#       <td id="T_9c41c_row11_col1" class="data row11 col1" >0.0119</td>
#       <td id="T_9c41c_row11_col2" class="data row11 col2" >0.0160</td>
#       <td id="T_9c41c_row11_col3" class="data row11 col3" >0.0120</td>
#       <td id="T_9c41c_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# #### Analyze the performance of trained and tuned model on holdout set.
# #### Hyperparameters used to finetune the model

# %%
# Fetch the hyperparameters used in the tune_model method
hyperparameters = tuned_random_forest_all_pca5.get_params()
hyperparameters
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'oob_score': False,
#  'random_state': 123,
#  'verbose': 0,
#  'warm_start': False}

# %%
pred_holdout = predict_model(tuned_random_forest_all_pca5, data=test_pca_df_5)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ca4c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca4c9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ca4c9_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ca4c9_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ca4c9_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ca4c9_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ca4c9_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ca4c9_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ca4c9_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca4c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca4c9_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_ca4c9_row0_col1" class="data row0 col1" >0.7516</td>
#       <td id="T_ca4c9_row0_col2" class="data row0 col2" >0.9173</td>
#       <td id="T_ca4c9_row0_col3" class="data row0 col3" >0.9769</td>
#       <td id="T_ca4c9_row0_col4" class="data row0 col4" >0.7230</td>
#       <td id="T_ca4c9_row0_col5" class="data row0 col5" >0.8310</td>
#       <td id="T_ca4c9_row0_col6" class="data row0 col6" >0.3998</td>
#       <td id="T_ca4c9_row0_col7" class="data row0 col7" >0.4716</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### AUC-ROC Curve

# %%
print("\nAUC-ROC Curve")
plot_model(tuned_random_forest_all_pca5, plot='auc')
# Out:
# AUC-ROC Curve

# %% [markdown]
# #### Confusion Matrix

# %%
print("\nConfusion Matrix")
plot_model(tuned_random_forest_all_pca5, plot='confusion_matrix')
# Out:
# Confusion Matrix

# %% [markdown]
# #### Precision Recall Curve

# %%
print("\nPrecision Recall Curve")
plot_model(tuned_random_forest_all_pca5, plot='pr')
# Out:
# Precision Recall Curve

# %% [markdown]
# #### Decision Boundary

# %%
print("\n\nDecision Boundary\n")
plot_model(tuned_random_forest_all_pca5, plot='boundary')
# Out:
# Decision Boundary

# %% [markdown]
# #### Learning Curve

# %%
print("\n\nLearning Curve\n")
plot_model(tuned_random_forest_all_pca5, plot='learning')
# Out:
# Learning Curve

# %% [markdown]
# ### PCA = 10

# %%
start_time = time.time()

best_model_for_pca10 = efc.train_multiple_ml_models(train_pca_df_10)

end_time = time.time()

# Calculate the total time taken
total_time_seconds = end_time - start_time

# Convert the time to minutes and seconds
total_time_minutes = total_time_seconds // 60
total_time_seconds = total_time_seconds % 60

# Print the results
print(f"\nTotal time to execute: {int(total_time_minutes)} minutes and {total_time_seconds:.2f} seconds")
# Out:
# <style type="text/css">
# #T_f790d_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f790d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f790d_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f790d_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f790d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f790d_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f790d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f790d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f790d_row1_col1" class="data row1 col1" >Pneumonia</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f790d_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f790d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f790d_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f790d_row3_col1" class="data row3 col1" >(5232, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f790d_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f790d_row4_col1" class="data row4 col1" >(5232, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f790d_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f790d_row5_col1" class="data row5 col1" >(3662, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f790d_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f790d_row6_col1" class="data row6 col1" >(1570, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f790d_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f790d_row7_col1" class="data row7 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f790d_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f790d_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f790d_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f790d_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f790d_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f790d_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f790d_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f790d_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f790d_row12_col0" class="data row12 col0" >Fold Generator</td>
#       <td id="T_f790d_row12_col1" class="data row12 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f790d_row13_col0" class="data row13 col0" >Fold Number</td>
#       <td id="T_f790d_row13_col1" class="data row13 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f790d_row14_col0" class="data row14 col0" >CPU Jobs</td>
#       <td id="T_f790d_row14_col1" class="data row14 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f790d_row15_col0" class="data row15 col0" >Use GPU</td>
#       <td id="T_f790d_row15_col1" class="data row15 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f790d_row16_col0" class="data row16 col0" >Log Experiment</td>
#       <td id="T_f790d_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f790d_row17_col0" class="data row17 col0" >Experiment Name</td>
#       <td id="T_f790d_row17_col1" class="data row17 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f790d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f790d_row18_col0" class="data row18 col0" >USI</td>
#       <td id="T_f790d_row18_col1" class="data row18 col1" >f8a0</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_181b2 th {
#   text-align: left;
# }
# #T_181b2_row0_col0, #T_181b2_row0_col3, #T_181b2_row1_col0, #T_181b2_row1_col1, #T_181b2_row1_col2, #T_181b2_row1_col3, #T_181b2_row1_col4, #T_181b2_row1_col5, #T_181b2_row1_col6, #T_181b2_row1_col7, #T_181b2_row2_col0, #T_181b2_row2_col1, #T_181b2_row2_col2, #T_181b2_row2_col3, #T_181b2_row2_col4, #T_181b2_row2_col5, #T_181b2_row2_col6, #T_181b2_row2_col7, #T_181b2_row3_col0, #T_181b2_row3_col1, #T_181b2_row3_col2, #T_181b2_row3_col3, #T_181b2_row3_col4, #T_181b2_row3_col5, #T_181b2_row3_col6, #T_181b2_row3_col7, #T_181b2_row4_col0, #T_181b2_row4_col1, #T_181b2_row4_col2, #T_181b2_row4_col3, #T_181b2_row4_col4, #T_181b2_row4_col5, #T_181b2_row4_col6, #T_181b2_row4_col7, #T_181b2_row5_col0, #T_181b2_row5_col1, #T_181b2_row5_col2, #T_181b2_row5_col3, #T_181b2_row5_col4, #T_181b2_row5_col5, #T_181b2_row5_col6, #T_181b2_row5_col7, #T_181b2_row6_col0, #T_181b2_row6_col1, #T_181b2_row6_col2, #T_181b2_row6_col3, #T_181b2_row6_col4, #T_181b2_row6_col5, #T_181b2_row6_col6, #T_181b2_row6_col7, #T_181b2_row7_col0, #T_181b2_row7_col1, #T_181b2_row7_col2, #T_181b2_row7_col3, #T_181b2_row7_col4, #T_181b2_row7_col5, #T_181b2_row7_col6, #T_181b2_row7_col7, #T_181b2_row8_col0, #T_181b2_row8_col1, #T_181b2_row8_col2, #T_181b2_row8_col3, #T_181b2_row8_col4, #T_181b2_row8_col5, #T_181b2_row8_col6, #T_181b2_row8_col7, #T_181b2_row9_col0, #T_181b2_row9_col1, #T_181b2_row9_col2, #T_181b2_row9_col3, #T_181b2_row9_col4, #T_181b2_row9_col5, #T_181b2_row9_col6, #T_181b2_row9_col7, #T_181b2_row10_col0, #T_181b2_row10_col1, #T_181b2_row10_col2, #T_181b2_row10_col4, #T_181b2_row10_col5, #T_181b2_row10_col6, #T_181b2_row10_col7, #T_181b2_row11_col0, #T_181b2_row11_col1, #T_181b2_row11_col2, #T_181b2_row11_col3, #T_181b2_row11_col4, #T_181b2_row11_col5, #T_181b2_row11_col6, #T_181b2_row11_col7, #T_181b2_row12_col0, #T_181b2_row12_col1, #T_181b2_row12_col2, #T_181b2_row12_col3, #T_181b2_row12_col4, #T_181b2_row12_col5, #T_181b2_row12_col6, #T_181b2_row12_col7, #T_181b2_row13_col0, #T_181b2_row13_col1, #T_181b2_row13_col2, #T_181b2_row13_col3, #T_181b2_row13_col4, #T_181b2_row13_col5, #T_181b2_row13_col6, #T_181b2_row13_col7 {
#   text-align: left;
# }
# #T_181b2_row0_col1, #T_181b2_row0_col2, #T_181b2_row0_col4, #T_181b2_row0_col5, #T_181b2_row0_col6, #T_181b2_row0_col7, #T_181b2_row10_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_181b2_row0_col8, #T_181b2_row1_col8, #T_181b2_row2_col8, #T_181b2_row3_col8, #T_181b2_row4_col8, #T_181b2_row5_col8, #T_181b2_row6_col8, #T_181b2_row7_col8, #T_181b2_row8_col8, #T_181b2_row9_col8, #T_181b2_row11_col8, #T_181b2_row12_col8, #T_181b2_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_181b2_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_181b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_181b2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_181b2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_181b2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_181b2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_181b2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_181b2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_181b2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_181b2_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_181b2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_181b2_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_181b2_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_181b2_row0_col1" class="data row0 col1" >0.9623</td>
#       <td id="T_181b2_row0_col2" class="data row0 col2" >0.9883</td>
#       <td id="T_181b2_row0_col3" class="data row0 col3" >0.9765</td>
#       <td id="T_181b2_row0_col4" class="data row0 col4" >0.9730</td>
#       <td id="T_181b2_row0_col5" class="data row0 col5" >0.9747</td>
#       <td id="T_181b2_row0_col6" class="data row0 col6" >0.9011</td>
#       <td id="T_181b2_row0_col7" class="data row0 col7" >0.9014</td>
#       <td id="T_181b2_row0_col8" class="data row0 col8" >0.3010</td>
#     </tr>
#     <tr>
#       <th id="T_181b2_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_181b2_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_181b2_row1_col1" class="data row1 col1" >0.9601</td>
#       <td id="T_181b2_row1_col2" class="data row1 col2" >0.9878</td>
#       <td id="T_181b2_row1_col3" class="data row1 col3" >0.9753</td>
#       <td id="T_181b2_row1_col4" class="data row1 col4" >0.9712</td>
#       <td id="T_181b2_row1_col5" class="data row1 col5" >0.9732</td>
#       <td id="T_181b2_row1_col6" class="data row1 col6" >0.8954</td>
#       <td id="T_181b2_row1_col7" class="data row1 col7" >0.8959</td>
#       <td id="T_181b2_row1_col8" class="data row1 col8" >0.1040</td>
#     </tr>
#     <tr>
#       <th id="T_181b2_level0_row2" class="row_heading level0 row2" >et</th>
#       <td id="T_181b2_row2_col0" class="data row2 col0" >Extra Trees Classifier</td>
#       <td id="T_181b2_row2_col1" class="data row2 col1" >0.9593</td>
#       <td id="T_181b2_row2_col2" class="data row2 col2" >0.9876</td>
#       <td id="T_181b2_row2_col3" class="data row2 col3" >0.9724</td>
#       <td id="T_181b2_row2_col4" class="data row2 col4" >0.9729</td>
#       <td id="T_181b2_row2_col5" class="data row2 col5" >0.9726</td>
#       <td id="T_181b2_row2_col6" class="data row2 col6" >0.8937</td>
#       <td id="T_181b2_row2_col7" class="data row2 col7" >0.8940</td>
#       <td id="T_181b2_row2_col8" class="data row2 col8" >0.0370</td>
#     </tr>
#     <tr>
#       <th id="T_181b2_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_181b2_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_181b2_row3_col1" class="data row3 col1" >0.9588</td>
#       <td id="T_181b2_row3_col2" class="data row3 col2" >0.9844</td>
#       <td id="T_181b2_row3_col3" class="data row3 col3" >0.9753</td>
#       <td id="T_181b2_row3_col4" class="data row3 col4" >0.9694</td>
#       <td id="T_181b2_row3_col5" class="data row3 col5" >0.9723</td>
#       <td id="T_181b2_row3_col6" class="data row3 col6" >0.8915</td>
#       <td id="T_181b2_row3_col7" class="data row3 col7" >0.8921</td>
#       <td id="T_181b2_row3_col8" class="data row3 col8" >0.0920</td>
#     </tr>
#     <tr>
#       <th id="T_181b2_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_181b2_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_181b2_row4_col1" class="data row4 col1" >0.9560</td>
#       <td id="T_181b2_row4_col2" class="data row4 col2" >0.9860</td>
#       <td id="T_181b2_row4_col3" class="data row4 col3" >0.9713</td>
#       <td id="T_181b2_row4_col4" class="data row4 col4" >0.9696</td>
#       <td id="T_181b2_row4_col5" class="data row4 col5" >0.9704</td>
#       <td id="T_181b2_row4_col6" class="data row4 col6" >0.8850</td>
#       <td id="T_181b2_row4_col7" class="data row4 col7" >0.8855</td>
#       <td id="T_181b2_row4_col8" class="data row4 col8" >0.1890</td>
#     </tr>
#     <tr>
#       <th id="T_181b2_level0_row5" class="row_heading level0 row5" >ada</th>
#       <td id="T_181b2_row5_col0" class="data row5 col0" >Ada Boost Classifier</td>
#       <td id="T_181b2_row5_col1" class="data row5 col1" >0.9465</td>
#       <td id="T_181b2_row5_col2" class="data row5 col2" >0.9812</td>
#       <td id="T_181b2_row5_col3" class="data row5 col3" >0.9650</td>
#       <td id="T_181b2_row5_col4" class="data row5 col4" >0.9631</td>
#       <td id="T_181b2_row5_col5" class="data row5 col5" >0.9640</td>
#       <td id="T_181b2_row5_col6" class="data row5 col6" >0.8598</td>
#       <td id="T_181b2_row5_col7" class="data row5 col7" >0.8606<
# Total time to execute: 0 minutes and 11.14 seconds

# %%
best_model_for_pca10
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
#                subsample_for_bin=200000, subsample_freq=0)

# %% [markdown]
# #### Train and evaluate the performance of LGBM Classifier using cross validation as well as Hyperparameters

# %%
lightgbm_all_pca10 = create_model('lightgbm', boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
                                  importance_type='split', learning_rate=0.1, max_depth=-1,
                                  min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
                                  n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
                                  random_state=123, reg_alpha=0.0, reg_lambda=0.0, subsample=1.0,
                                  subsample_for_bin=200000, subsample_freq=0, verbose=True)
# Out:
# <style type="text/css">
# #T_7d825_row10_col0, #T_7d825_row10_col1, #T_7d825_row10_col2, #T_7d825_row10_col3, #T_7d825_row10_col4, #T_7d825_row10_col5, #T_7d825_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7d825">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d825_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7d825_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7d825_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7d825_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7d825_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7d825_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7d825_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d825_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d825_row0_col0" class="data row0 col0" >0.9782</td>
#       <td id="T_7d825_row0_col1" class="data row0 col1" >0.9959</td>
#       <td id="T_7d825_row0_col2" class="data row0 col2" >0.9816</td>
#       <td id="T_7d825_row0_col3" class="data row0 col3" >0.9889</td>
#       <td id="T_7d825_row0_col4" class="data row0 col4" >0.9852</td>
#       <td id="T_7d825_row0_col5" class="data row0 col5" >0.9436</td>
#       <td id="T_7d825_row0_col6" class="data row0 col6" >0.9437</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d825_row1_col0" class="data row1 col0" >0.9619</td>
#       <td id="T_7d825_row1_col1" class="data row1 col1" >0.9882</td>
#       <td id="T_7d825_row1_col2" class="data row1 col2" >0.9816</td>
#       <td id="T_7d825_row1_col3" class="data row1 col3" >0.9674</td>
#       <td id="T_7d825_row1_col4" class="data row1 col4" >0.9745</td>
#       <td id="T_7d825_row1_col5" class="data row1 col5" >0.8992</td>
#       <td id="T_7d825_row1_col6" class="data row1 col6" >0.8996</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d825_row2_col0" class="data row2 col0" >0.9536</td>
#       <td id="T_7d825_row2_col1" class="data row2 col1" >0.9869</td>
#       <td id="T_7d825_row2_col2" class="data row2 col2" >0.9669</td>
#       <td id="T_7d825_row2_col3" class="data row2 col3" >0.9705</td>
#       <td id="T_7d825_row2_col4" class="data row2 col4" >0.9687</td>
#       <td id="T_7d825_row2_col5" class="data row2 col5" >0.8787</td>
#       <td id="T_7d825_row2_col6" class="data row2 col6" >0.8788</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d825_row3_col0" class="data row3 col0" >0.9590</td>
#       <td id="T_7d825_row3_col1" class="data row3 col1" >0.9860</td>
#       <td id="T_7d825_row3_col2" class="data row3 col2" >0.9816</td>
#       <td id="T_7d825_row3_col3" class="data row3 col3" >0.9639</td>
#       <td id="T_7d825_row3_col4" class="data row3 col4" >0.9727</td>
#       <td id="T_7d825_row3_col5" class="data row3 col5" >0.8907</td>
#       <td id="T_7d825_row3_col6" class="data row3 col6" >0.8913</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7d825_row4_col0" class="data row4 col0" >0.9645</td>
#       <td id="T_7d825_row4_col1" class="data row4 col1" >0.9945</td>
#       <td id="T_7d825_row4_col2" class="data row4 col2" >0.9779</td>
#       <td id="T_7d825_row4_col3" class="data row4 col3" >0.9744</td>
#       <td id="T_7d825_row4_col4" class="data row4 col4" >0.9761</td>
#       <td id="T_7d825_row4_col5" class="data row4 col5" >0.9066</td>
#       <td id="T_7d825_row4_col6" class="data row4 col6" >0.9067</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7d825_row5_col0" class="data row5 col0" >0.9617</td>
#       <td id="T_7d825_row5_col1" class="data row5 col1" >0.9926</td>
#       <td id="T_7d825_row5_col2" class="data row5 col2" >0.9669</td>
#       <td id="T_7d825_row5_col3" class="data row5 col3" >0.9813</td>
#       <td id="T_7d825_row5_col4" class="data row5 col4" >0.9741</td>
#       <td id="T_7d825_row5_col5" class="data row5 col5" >0.9012</td>
#       <td id="T_7d825_row5_col6" class="data row5 col6" >0.9015</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7d825_row6_col0" class="data row6 col0" >0.9672</td>
#       <td id="T_7d825_row6_col1" class="data row6 col1" >0.9839</td>
#       <td id="T_7d825_row6_col2" class="data row6 col2" >0.9743</td>
#       <td id="T_7d825_row6_col3" class="data row6 col3" >0.9815</td>
#       <td id="T_7d825_row6_col4" class="data row6 col4" >0.9779</td>
#       <td id="T_7d825_row6_col5" class="data row6 col5" >0.9147</td>
#       <td id="T_7d825_row6_col6" class="data row6 col6" >0.9148</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7d825_row7_col0" class="data row7 col0" >0.9563</td>
#       <td id="T_7d825_row7_col1" class="data row7 col1" >0.9846</td>
#       <td id="T_7d825_row7_col2" class="data row7 col2" >0.9853</td>
#       <td id="T_7d825_row7_col3" class="data row7 col3" >0.9571</td>
#       <td id="T_7d825_row7_col4" class="data row7 col4" >0.9710</td>
#       <td id="T_7d825_row7_col5" class="data row7 col5" >0.8822</td>
#       <td id="T_7d825_row7_col6" class="data row7 col6" >0.8837</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7d825_row8_col0" class="data row8 col0" >0.9617</td>
#       <td id="T_7d825_row8_col1" class="data row8 col1" >0.9903</td>
#       <td id="T_7d825_row8_col2" class="data row8 col2" >0.9815</td>
#       <td id="T_7d825_row8_col3" class="data row8 col3" >0.9673</td>
#       <td id="T_7d825_row8_col4" class="data row8 col4" >0.9744</td>
#       <td id="T_7d825_row8_col5" class="data row8 col5" >0.8991</td>
#       <td id="T_7d825_row8_col6" class="data row8 col6" >0.8995</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7d825_row9_col0" class="data row9 col0" >0.9590</td>
#       <td id="T_7d825_row9_col1" class="data row9 col1" >0.9806</td>
#       <td id="T_7d825_row9_col2" class="data row9 col2" >0.9668</td>
#       <td id="T_7d825_row9_col3" class="data row9 col3" >0.9776</td>
#       <td id="T_7d825_row9_col4" class="data row9 col4" >0.9722</td>
#       <td id="T_7d825_row9_col5" class="data row9 col5" >0.8945</td>
#       <td id="T_7d825_row9_col6" class="data row9 col6" >0.8947</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_7d825_row10_col0" class="data row10 col0" >0.9623</td>
#       <td id="T_7d825_row10_col1" class="data row10 col1" >0.9883</td>
#       <td id="T_7d825_row10_col2" class="data row10 col2" >0.9765</td>
#       <td id="T_7d825_row10_col3" class="data row10 col3" >0.9730</td>
#       <td id="T_7d825_row10_col4" class="data row10 col4" >0.9747</td>
#       <td id="T_7d825_row10_col5" class="data row10 col5" >0.9011</td>
#       <td id="T_7d825_row10_col6" class="data row10 col6" >0.9014</td>
#     </tr>
#     <tr>
#       <th id="T_7d825_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_7d825_row11_col0" class="data row11 col0" >0.0065</td>
#       <td id="T_7d825_row11_col1" class="data row11 col1" >0.0047</td>
#       <td id="T_7d825_row11_col2" class="data row11 col2" >0.0068</td>
#       <td id="T_7d825_row11_col3" class="data row11 col3" >0.0091</td>
#       <td id="T_7d825_row11_col4

# %%
tuned_lightgbm_all_pca10 = tune_model(lightgbm_all_pca10)
# Out:
# <style type="text/css">
# #T_389dd_row10_col0, #T_389dd_row10_col1, #T_389dd_row10_col2, #T_389dd_row10_col3, #T_389dd_row10_col4, #T_389dd_row10_col5, #T_389dd_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_389dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_389dd_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_389dd_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_389dd_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_389dd_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_389dd_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_389dd_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_389dd_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_389dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_389dd_row0_col0" class="data row0 col0" >0.9782</td>
#       <td id="T_389dd_row0_col1" class="data row0 col1" >0.9955</td>
#       <td id="T_389dd_row0_col2" class="data row0 col2" >0.9779</td>
#       <td id="T_389dd_row0_col3" class="data row0 col3" >0.9925</td>
#       <td id="T_389dd_row0_col4" class="data row0 col4" >0.9852</td>
#       <td id="T_389dd_row0_col5" class="data row0 col5" >0.9440</td>
#       <td id="T_389dd_row0_col6" class="data row0 col6" >0.9443</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_389dd_row1_col0" class="data row1 col0" >0.9619</td>
#       <td id="T_389dd_row1_col1" class="data row1 col1" >0.9841</td>
#       <td id="T_389dd_row1_col2" class="data row1 col2" >0.9853</td>
#       <td id="T_389dd_row1_col3" class="data row1 col3" >0.9640</td>
#       <td id="T_389dd_row1_col4" class="data row1 col4" >0.9745</td>
#       <td id="T_389dd_row1_col5" class="data row1 col5" >0.8985</td>
#       <td id="T_389dd_row1_col6" class="data row1 col6" >0.8993</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_389dd_row2_col0" class="data row2 col0" >0.9508</td>
#       <td id="T_389dd_row2_col1" class="data row2 col1" >0.9886</td>
#       <td id="T_389dd_row2_col2" class="data row2 col2" >0.9706</td>
#       <td id="T_389dd_row2_col3" class="data row2 col3" >0.9635</td>
#       <td id="T_389dd_row2_col4" class="data row2 col4" >0.9670</td>
#       <td id="T_389dd_row2_col5" class="data row2 col5" >0.8703</td>
#       <td id="T_389dd_row2_col6" class="data row2 col6" >0.8704</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_389dd_row3_col0" class="data row3 col0" >0.9672</td>
#       <td id="T_389dd_row3_col1" class="data row3 col1" >0.9870</td>
#       <td id="T_389dd_row3_col2" class="data row3 col2" >0.9890</td>
#       <td id="T_389dd_row3_col3" class="data row3 col3" >0.9676</td>
#       <td id="T_389dd_row3_col4" class="data row3 col4" >0.9782</td>
#       <td id="T_389dd_row3_col5" class="data row3 col5" >0.9123</td>
#       <td id="T_389dd_row3_col6" class="data row3 col6" >0.9132</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_389dd_row4_col0" class="data row4 col0" >0.9754</td>
#       <td id="T_389dd_row4_col1" class="data row4 col1" >0.9935</td>
#       <td id="T_389dd_row4_col2" class="data row4 col2" >0.9779</td>
#       <td id="T_389dd_row4_col3" class="data row4 col3" >0.9888</td>
#       <td id="T_389dd_row4_col4" class="data row4 col4" >0.9834</td>
#       <td id="T_389dd_row4_col5" class="data row4 col5" >0.9362</td>
#       <td id="T_389dd_row4_col6" class="data row4 col6" >0.9365</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_389dd_row5_col0" class="data row5 col0" >0.9590</td>
#       <td id="T_389dd_row5_col1" class="data row5 col1" >0.9906</td>
#       <td id="T_389dd_row5_col2" class="data row5 col2" >0.9632</td>
#       <td id="T_389dd_row5_col3" class="data row5 col3" >0.9813</td>
#       <td id="T_389dd_row5_col4" class="data row5 col4" >0.9722</td>
#       <td id="T_389dd_row5_col5" class="data row5 col5" >0.8945</td>
#       <td id="T_389dd_row5_col6" class="data row5 col6" >0.8950</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_389dd_row6_col0" class="data row6 col0" >0.9563</td>
#       <td id="T_389dd_row6_col1" class="data row6 col1" >0.9838</td>
#       <td id="T_389dd_row6_col2" class="data row6 col2" >0.9596</td>
#       <td id="T_389dd_row6_col3" class="data row6 col3" >0.9812</td>
#       <td id="T_389dd_row6_col4" class="data row6 col4" >0.9703</td>
#       <td id="T_389dd_row6_col5" class="data row6 col5" >0.8878</td>
#       <td id="T_389dd_row6_col6" class="data row6 col6" >0.8886</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_389dd_row7_col0" class="data row7 col0" >0.9563</td>
#       <td id="T_389dd_row7_col1" class="data row7 col1" >0.9841</td>
#       <td id="T_389dd_row7_col2" class="data row7 col2" >0.9853</td>
#       <td id="T_389dd_row7_col3" class="data row7 col3" >0.9571</td>
#       <td id="T_389dd_row7_col4" class="data row7 col4" >0.9710</td>
#       <td id="T_389dd_row7_col5" class="data row7 col5" >0.8822</td>
#       <td id="T_389dd_row7_col6" class="data row7 col6" >0.8837</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_389dd_row8_col0" class="data row8 col0" >0.9590</td>
#       <td id="T_389dd_row8_col1" class="data row8 col1" >0.9879</td>
#       <td id="T_389dd_row8_col2" class="data row8 col2" >0.9815</td>
#       <td id="T_389dd_row8_col3" class="data row8 col3" >0.9638</td>
#       <td id="T_389dd_row8_col4" class="data row8 col4" >0.9726</td>
#       <td id="T_389dd_row8_col5" class="data row8 col5" >0.8915</td>
#       <td id="T_389dd_row8_col6" class="data row8 col6" >0.8921</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_389dd_row9_col0" class="data row9 col0" >0.9536</td>
#       <td id="T_389dd_row9_col1" class="data row9 col1" >0.9783</td>
#       <td id="T_389dd_row9_col2" class="data row9 col2" >0.9668</td>
#       <td id="T_389dd_row9_col3" class="data row9 col3" >0.9704</td>
#       <td id="T_389dd_row9_col4" class="data row9 col4" >0.9686</td>
#       <td id="T_389dd_row9_col5" class="data row9 col5" >0.8796</td>
#       <td id="T_389dd_row9_col6" class="data row9 col6" >0.8796</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_389dd_row10_col0" class="data row10 col0" >0.9618</td>
#       <td id="T_389dd_row10_col1" class="data row10 col1" >0.9873</td>
#       <td id="T_389dd_row10_col2" class="data row10 col2" >0.9757</td>
#       <td id="T_389dd_row10_col3" class="data row10 col3" >0.9730</td>
#       <td id="T_389dd_row10_col4" class="data row10 col4" >0.9743</td>
#       <td id="T_389dd_row10_col5" class="data row10 col5" >0.8997</td>
#       <td id="T_389dd_row10_col6" class="data row10 col6" >0.9003</td>
#     </tr>
#     <tr>
#       <th id="T_389dd_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_389dd_row11_col0" class="data row11 col0" >0.0087</td>
#       <td id="T_389dd_row11_col1" class="data row11 col1" >0.0048</td>
#       <td id="T_389dd_row11_col2" class="data row11 col2" >0.0096</td>
#       <td id="T_389dd_row11_col3" class="data row11 col3" >0.0115</td>
#       <td id="T_389dd_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).

# %% [markdown]
# #### Analyze the performance of trained and tuned model on holdout set.
# #### Hyperparameters used to finetune the model

# %%
# Fetch the hyperparameters used in the tune_model method
hyperparameters = tuned_lightgbm_all_pca10.get_params()
hyperparameters
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': 123,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %%
pred_holdout = predict_model(tuned_lightgbm_all_pca10, data=test_pca_df_10)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3bfd4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bfd4_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3bfd4_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_3bfd4_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_3bfd4_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_3bfd4_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_3bfd4_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_3bfd4_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_3bfd4_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bfd4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3bfd4_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3bfd4_row0_col1" class="data row0 col1" >0.7147</td>
#       <td id="T_3bfd4_row0_col2" class="data row0 col2" >0.9151</td>
#       <td id="T_3bfd4_row0_col3" class="data row0 col3" >0.9923</td>
#       <td id="T_3bfd4_row0_col4" class="data row0 col4" >0.6886</td>
#       <td id="T_3bfd4_row0_col5" class="data row0 col5" >0.8130</td>
#       <td id="T_3bfd4_row0_col6" class="data row0 col6" >0.2866</td>
#       <td id="T_3bfd4_row0_col7" class="data row0 col7" >0.3956</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### AUC-ROC Curve

# %%
print("\nAUC-ROC Curve")
plot_model(tuned_lightgbm_all_pca10, plot='auc')
# Out:
# AUC-ROC Curve

# %% [markdown]
# #### Confusion Matrix

# %%
print("\nConfusion Matrix")
plot_model(tuned_lightgbm_all_pca10, plot='confusion_matrix')
# Out:
# Confusion Matrix

# %% [markdown]
# #### Precision Recall Curve

# %%
print("\nPrecision Recall Curve")
plot_model(tuned_lightgbm_all_pca10, plot='pr')
# Out:
# Precision Recall Curve

# %% [markdown]
# #### Decision Boundary

# %%
print("\n\nDecision Boundary\n")
plot_model(tuned_lightgbm_all_pca10, plot='boundary')
# Out:
# Decision Boundary

# %% [markdown]
# #### Learning Curve

# %%
print("\n\nLearning Curve\n")
plot_model(tuned_lightgbm_all_pca10, plot='learning')
# Out:
# Learning Curve

# %%
model_file_name = 'all_features_pca5_lightgbm.pkl'
efc.save_trained_model(tuned_random_forest_all_pca5, model_file_name)
# Out:
# Model is saved to:  ['/Users/ravkothu/Documents/Personal_items_at_Oracle/Master_Degree/University_of_San_Diego/Online_Masters/MS_in_Applied_AI/Subjects_and_Resources/AAI-501_Introduction_to_AI/AAI-501_Final_Team_Project/pneumonia_detection/trained_models/all_features_pca5_lightgbm.pkl']

# %%
model_file_name = 'all_features_pca10_lightgbm.pkl'
efc.save_trained_model(tuned_lightgbm_all_pca10, model_file_name)
# Out:
# Model is saved to:  ['/Users/ravkothu/Documents/Personal_items_at_Oracle/Master_Degree/University_of_San_Diego/Online_Masters/MS_in_Applied_AI/Subjects_and_Resources/AAI-501_Introduction_to_AI/AAI-501_Final_Team_Project/pneumonia_detection/trained_models/all_features_pca10_lightgbm.pkl']
